# %%
from pymongo import MongoClient
import folium

# %%
def connectCollection(database, collection):
    client = MongoClient()
    db = client[database]
    coll = db[collection]
    return db, coll

# %%
db, coll = connectCollection('companies', 'companies')

# %%
print(coll.json)
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'companies'), 'companies.json')

# %%
comp = list(coll.find({'$and': [{"offices.latitude": { '$nin': [None] }}, {"offices.longitude":{ '$nin': [None] }}, {"offices.city": "Amsterdam"}, {'deadpooled_year': None}]}))

# %%
comp
# Out:
# [{'_id': ObjectId('52cdef7c4bab8bd675297de6'),
#   'name': 'Wakoopa',
#   'permalink': 'wakoopa',
#   'crunchbase_url': 'http://www.crunchbase.com/company/wakoopa',
#   'homepage_url': 'http://www.wakoopa.com',
#   'blog_url': 'http://blog.wakoopa.com',
#   'blog_feed_url': 'http://blog.wakoopa.com/feed/',
#   'twitter_username': 'wakoopa',
#   'category_code': 'web',
#   'number_of_employees': 8,
#   'founded_year': 2007,
#   'founded_month': 1,
#   'founded_day': 1,
#   'deadpooled_year': None,
#   'deadpooled_month': None,
#   'deadpooled_day': None,
#   'deadpooled_url': None,
#   'tag_list': 'socialnetwork, software, desktop, apps',
#   'alias_list': '',
#   'email_address': 'info@wakoopa.com',
#   'phone_number': '',
#   'description': 'Social network for desktop software',
#   'created_at': 'Tue Feb 05 22:28:16 UTC 2008',
#   'updated_at': 'Fri Sep 06 12:31:20 UTC 2013',
#   'overview': '<p>Wakoopa creates digital DNA of today&#8217;s consumer. In a privacy conscious way, our technology tracks what websites are visited, what ads are seen, or what apps are used. Analyze the data and optimize your digital strategy accordingly. Our new measurement dashboard, QD, is available now.</p>',
#   'image': {'available_sizes': [[[150, 37],
#      'assets/images/resized/0000/2467/2467v7-max-150x150.png'],
#     [[200, 50], 'assets/images/resized/0000/2467/2467v7-max-250x250.png'],
#     [[200, 50], 'assets/images/resized/0000/2467/2467v7-max-450x450.png']],
#    'attribution': None},
#   'products': [{'name': 'Wakoopa', 'permalink': 'wakoopa'},
#    {'name': 'QD', 'permalink': 'qd-tracking'}],
#   'relationships': [{'is_past': False,
#     'title': 'Co-founder',
#     'person': {'first_name': 'Robert',
#      'last_name': 'Gaal',
#      'permalink': 'robert-gaal'}},
#    {'is_past': False,
#     'title': 'Co-founder',
#     'person': {'first_name': 'Wouter',
#      'last_name': 'Broekhof',
#      'permalink': 'wouter-broekhof'}},
#    {'is_past': False,
#     'title': 'Shareholder/Advisor',
#     'person': {'first_name': 'Boris',
#      'last_name': 'Veldhuijzen van Zanten',
#      'permalink': 'boris-veldhuijzen-van-zanten'}},
#    {'is_past': False,
#     'title': 'Lead Developer',
#     'person': {'first_name': 'Menno',
#      'last_name': 'Van der Sman',
#      'permalink': 'menno-van-der-sman'}},
#    {'is_past': True,
#     'title': 'Developer',
#     'person': {'first_name': 'Mark',
#      'last_name': 'Mulder',
#      'permalink': 'mark-mulder'}}],
#   'competitions': [{'competitor': {'name': 'RescueTime',
#      'permalink': 'rescuetime'}},
#    {'competitor': {'name': 'Chomp', 'permalink': 'chomp'}},
#    {'competitor': {'name': 'blippr', 'permalink': 'blippr'}},
#    {'competitor': {'name': 'Suzerein Solutions',
#      'permalink': 'suzerein-solutions'}}],
#   'providerships': [{'title': 'Marketing and PR',
#     'is_past': True,
#     'provider': {'name': 'Mercury Global Partners',
#      'permalink': 'mercury-global-partners'}}],
#   'total_money_raised': '$1M',
#   'funding_rounds': [{'id': 100,
#     'round_code': 'a',
#     'source_url': 'http://www.techcrunch.com/2008/06/02/wakoopa-secures-1-million-for-app-monitoring-social-network/',
#     'source_description': 'Wakoopa Secures $1 Million for App-Monitoring Social Network',
#     'raised_amount': 1000000,
#     'raised_currency_code': 'USD',
#     'funded_year': 2008,
#     'funded_month': 6,
#     'funded_day': 2,
#     'investments': [{'company': None,
#       'financial_org': {'name': 'Big Bang Ventures',
#        'permalink': 'big-bang-ventures'},
#       'person': None},
#      {'company': None,
#       'financial_org': {'name': 'HENQ Invest', 'permalink': 'henq-invest'},
#       'person': None},
#      {'company': None,
#       'financial_org': {'name': 'DCIF', 'permalink': 'dcif'},
#       'person': None},
#      {'company': {'name': 'The Next Web', 'permalink': 'the-next-web'},
#       'financial_org': None,
#       'person': None}]}],
#   'investments': [],
#   'acquisition': None,
#   'acquisitions': [],
#   'offices': [{'description': 'Arts & Crafts',
#     'address1': 'Damrak 70, 254',
#     'address2': '',
#     'zip_code': '1012LM',
#     'city': 'Amsterdam',
#     'state_code': None,
#     'country_code': 'NLD',
#     'latitude': 52.3745228,
#     'longitude': 4.8948623}],
#   'milestones': [],
#   'ipo': None,
#   'video_embeds': [],
#   'screenshots': [],
#   'external_links': [],
#   'partners': [],
#   'location': [{'type': 'Point', 'coordinates': [4.8948623, 52.3745228]}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297e58'),
#   'name': 'eBuddy',
#   'permalink': 'ebuddy',
#   'crunchbase_url': 'http://www.crunchbase.com/company/ebuddy',
#   'homepage_url': 'http://www.ebuddy.com',
#   'blog_url': 'http://blog.ebuddy.com/',
#   'blog_feed_url': 'http://blog.ebuddy.com/index.php/feed/',
#   'twitter_username': 'ebuddy',
#   'category_code': 'messaging',
#   'number_of_employees': 90,
#   'founded_year': 2003,
#   'founded_month': 9,
#   'founded_day': 1,
#   'deadpooled_year': None,
#   'deadpooled_month': None,
#   'deadpooled_day': None,
#   'deadpooled_url': None,
#   'tag_list': 'ebuddy, crunchbase, techcrunch, im, mobile-im, mim, web-based-messenger, www-msn-com-br, aol, open-aim-2-0, windows-live-messenger, yahoo-messenger, myspace-im, googletalk, xms, mobile-messaging',
#   'alias_list': '',
#   'email_address': 'feedback@ebuddy.com',
#   'phone_number': '+31 20 514 1420',
#   'description': 'Web and mobile messaging',
#   'created_at': 'Wed Jul 25 11:48:02 UTC 2007',
#   'updated_at': 'Tue Oct 01 12:55:24 UTC 2013',
#   'overview': '<p>eBuddy created the world’s first, independent, web browser-based instant messaging service as e-Messenger in 2003. The company was rebranded in 2006 from e-Messenger to eBuddy. eBuddy currently offers two products: eBuddy Chat and XMS.</p>\n\n<p>eBuddy Chat enables millions of monthly global users with Facebook Chat, MSN, Google Talk, Yahoo Messenger, ICQ and AOL accounts to chat free of charge in one aggregated interface. eBuddy Chat is currently available on the Web and offers free mobile solutions for iOS, Android, J2ME and mobile Web-enabled devices.</p>\n\n<p>XMS is a free, real-time messaging app for smartphones. Launched in March 2011, XMS offers unlimited smartphone messaging through one’s Internet connection. XMS is currently available for iOS, Android, BlackBerry, Nokia and Windows Phone 7 devices.</p>\n\n<p>eBuddy processes over 17 billion messages per month and enables more than 30 million unique monthly users to exchange messages through its services.</p>\n\n<p>eBuddy is a privately-held company backed by Prime Technology Ventures and Lowland Capital Partners. eBuddy is headquartered in Amsterdam and has local offices in San Francisco and Singapore.</p>',
#   'image': {'available_sizes': [[[150, 35],
#      'assets/images/resized/0000/3781/3781v41-max-150x150.png'],
#     [[250, 59], 'assets/images/resized/0000/3781/3781v41-max-250x250.png'],
#     [[251, 60], 'assets/images/resized/0000/3781/3781v41-max-450x450.png']],
#    'attribution': None},
#   'products': [],
#   'relationships': [{'is_past': False,
#     'title': 'COO, Co-founder',
#     'person': {'first_name': 'Onno',
#      'last_name': 'Bakker',
#      'permalink': 'onno-bakker'}},
#    {'is_past': False,
#     'title': 'Co-founder',
#     'person': {'first_name': 'Paulo',
#      'last_name': 'Taylor',
#      'permalink': 'paulo-taylor'}},
#    {'is_past': False,
#     'title': 'COO',
#     'person': {'first_name': 'Sytse',
#      'last_name': 'Zuidema',
#      'permalink': 'sytse-zuidema'}},
#    {'is_past': False,
#     'title': 'CEO, Co-founder',
#     'person': {'first_name': 'Jan-Joost',
#      'last_name': 'Rueb',
#      'permalink': 'jan-joost-rueb'}},
#    {'is_past': False,
#     'title': 'Strategic Partnership Director',
#     'person': {'first_name': 'Jonie',
#      'last_name': 'Oostveen',
#      'permalink': 'jonie-oostveen'}},
#    {'is_past': False,
#     'title': 'Investor',
#     'person': {'first_name': 'Alex',
#      'last_name': 'Mashinsky',
#      'permalink': 'alex-mashinsky'}},
#    {'is_past': True,
#     'title': 'Chief Commercial Officer (CCO)',
#     'person': {'first_name': 'Rogier',
#      'last_name': 'van den Heuvel',
#      'permalink': 'rogier-van-den-heuvel'}},
#    {'is_past': True,
#     'title': 'CFO',
#     'person': {'first_name': 'Wijnand',
#      'last_name': 'van de Calseijde',
#      'permalink': 'wijnand-van-de-calseijde'}},
#    {'is_past': True,
#     'title': 'VP Products and Marketing',
#     'person': {'first_name': 'Martijn',
#      'last_name': 'Jansen',
#      'permalink': 'martijn-jansen'}},
#    {'is_past': True,
#     'title': 'VP Products & Marketing',
#     'person': {'first_name': 'Jan-Joost',
#      'last_name': 'Kraal',
#      'permalink': 'jan-joost-kraal'}},
#    {'is_past': True,
#     'title': 'Sales and Channel Development',
#     'person': {'first_name': 'Marc',
#      'last_name': 'Duijndam',
#      'permalink': 'marc-duijndam'}},
#    {'is_past': True,
#     'title': 'Director Mobile',
#     'person': {'first_name': 'Jan-Joost',
#      'last_name': 'Kraal',
#      'permalink': 'jan-joost-kraal'}},
#    {'is_past': True,
#     'title': 'Board of Director',
#     'person': {'first_name': 'Sake',
#      'last_name': 'Bosch',
#      'permalink': 'sake-bosch'}},
#    {'is_past': True,
#     'title': '',
#     'person': {'first_name': 'Ruben',
#      'last_name': 'Heerdink',
#      'permalink': 'ruben-heerdink'}},
#    {'is_past': True,
#     'title': 'Advisor',
#     'person': {'first_name': 'Alex',
#      'last_name': 'Mashinsky',
#      'permalink': 'alex-mashinsky'}}],
#   'competitions': [{'competitor': {'name': 'KoolIM', 'permalink': 'koolim'}},
#    {'competitor': {'name': 'Heysan', 'permalink': 'heysan'}},
#    {'competitor': {'name': 'EQO', 'permalink': 'eqo'}},
#    {'competitor': {'name': 'WhatsApp', 'permalink': 'whatsapp'}},
#    {'competitor': {'name': 'Viber', 'permalink': 'viber'}},
#    {'competitor': {'name': 'KakaoTalk', 'permalink': 'kakaotalk'}},
#    {'competitor': {'name': 'Wechat', 'permalink': 'wechat-2'}}],
#   'providerships': [{'title': 'Marketing and PR',
#     'is_past': True,
#     'provider': {'name': 'Mercury Global Partners',
#      'permalink': 'mercury-global-partners'}}],
#   'total_money_raised': '€11.5M',
#   'funding_rounds': [{'id': 239,
#     'round_code': 'a',
#     'source_url': 'http://www.ebuddy.com/press/eBuddy_Lowland_Capital.pdf',
#     'source_description': 'EBUDDY Secures 5 Million Euro In Series A Funding',
#     'raised_amount': 5000000,
#     'raised_currency_code': 'EUR',
#     'funded_year': 2006,
#     'funded_month': 10,
#     'funded_day': 26,
#     'investments': [{'company': None,
#       'financial_org': {'name': 'Lowland Capital Partners',
#        'permalink': 'lowland-capital-partners'},
#       'person': None}]},
#    {'id': 1863,
#     'round_code': 'b',
#     'source_url': 'http://www.ebuddy.com/press/eBuddy_PTV_Press_Release_05Feb2008.pdf',
#     'source_description': 'eBuddy secures â‚¬6.5 million Series B funding',
#     'raised_amount': 6500000,
#     'raised_currency_code': 'EUR',
#     'funded_year': 2008,
#     'funded_month': 2,
#     'funded_day': 5,
#     'investments': [{'company': None,
#       'financial_org': {'name': 'Prime Ventures',
#        'permalink': 'prime-technology-ventures'},
#       'person': None}]}],
#   'investments': [],
#   'acquisition': None,
#   'acquisitions': [],
#   'offices': [{'description': 'Global Headquarters',
#     'address1': 'Keizersgracht 585',
#     'address2': '',
#     'zip_code': '1017 DR',
#     'city': 'Amsterdam',
#     'state_code': None,
#     'country_code': 'NLD',
#     'latitude': 52.3640933,
#     'longitude': 4.8919457},
#    {'description': 'US Headquarters',
#     'address1': '555 Post St.',
#     'address2': '',
#     'zip_code': '94102',
#     'city': 'San Francisco',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.787683,
#     'longitude': -122.410943},
#    {'description': 'Singapore office',
#     'address1': '',
#     'address2': '',
#     'zip_code': '',
#     'city': 'Singapore',
#     'state_code': None,
#     'country_code': 'SGP',
#     'latitude': 51.500152,
#     'longitude': -0.126236}],
#   'milestones': [{'id': 324,
#     'description': 'eBuddy Processing 1 billion Messages per Month for 2M Unique Mobile Users',
#     'stoned_year': 2008,
#     'stoned_month': 4,
#     'stoned_day': 30,
#     'source_url': 'http://news.yahoo.com/s/prweb/20080725/bs_prweb/prweb1141594_1',
#     'source_text': ' eBuddy, the world\'s leading independent provider of web and mobile messaging (IM), announced today that it has surpassed 5M downloads of its mobile IM client in its first year. The company is now processing over 1 billion messages per month on its mobile platform and counts more than 2 million unique monthly mobile users. eBuddy also announced updated releases and redesiged user interfaces for both of their popular mobile IM clients.\r\nADVERTISEMENT\r\n\r\nSan Francisco, CA (PRWEB) July 25, 2008 -- eBuddy, the world\'s leading independent provider of web and mobile instant messaging (IM), announced today that it has experienced explosive mobile IM growth, surpassing 5 million downloads of its mobile IM client since its launch in June 2007.\r\n\r\nJan-Joost Rueb, eBuddy CEO and founder commented, "We are now processing over 1 billion messages per month on our mobile platform for more than 2 million unique monthly users. The fast pace at which our application is being picked up shows how much people want a high quality, easy-to-use, intuitive IM application like eBuddy."\r\n\r\neBuddy also announced updated releases for both of its mobile clients, the popular J2ME client and the mobile Internet browser version, Lite Messenger. The latest J2ME release features a redesigned and improved user interface and the addition of the eBuddy ID (which already exists on eBuddy\'s web browser version) and allows the user to create a single, unique ID which can then be used to log-in and access all of their IM accounts simultaneously. The latest Lite Messenger release includes new features, extra networks and specific design functionality for iPhone, including the new 3G version released worldwide on July 11.\r\n\r\nResearch analysts at Informa estimate the global market for mobile IM will become an $11 billion (â‚¬7.4bn) industry by 2011. eBuddy\'s VP of Mobile, Jan-Joost Kraal adds, "eBuddy has become one of the most downloaded mobile applications worldwide within a year due to rapid adoption, ramped up channel distribution and the help of partners like GetJar. Mobile Internet usage on a global scale is only going to increase, and with a single user average of 30 log-ins per month, eBuddy is an excellent reason for customers to buy a flat-fee data bundle from their mobile carrier."\r\n\r\nAbout eBuddy\r\neBuddy created the world\'s first, independent, web browser-based instant messaging service in 2003. Its patent-pending technology enables 16M+ monthly global visitors with AIM, GoogleTalk, MSN, MySpace and Yahoo! IM accounts to chat free of charge in one, aggregated interface without having to download or install any application on their computer. Supporting 550+ different mobile devices, eBuddy\'s mobile IM solution - m.ebuddy.com -- offers both a J2ME and browser-based IM service and allows 2M+ unique monthly user\'s access on their mobile phone, independent of carrier or device via WAP or mobile Internet browser. eBuddy is a privately held, Amsterdam-based company with additional offices in London and San Francisco, and is backed by Prime Technology Ventures and Lowland Capital Partners. ',
#     'source_description': 'Hungry mobile IM users consume 5M downloads in first year eBuddy processing 1 billion messages per month for 2M unique mobile users',
#     'stoneable_type': 'Company',
#     'stoned_value': None,
#     'stoned_value_type': None,
#     'stoned_acquirer': None,
#     'stoneable': {'name': 'eBuddy', 'permalink': 'ebuddy'}},
#    {'id': 17617,
#     'description': 'Mobile Messaging Platform eBuddy Raising Money At $100 Million Valuation',
#     'stoned_year': 2011,
#     'stoned_month': 8,
#     'stoned_day': 30,
#     'source_url': 'http://www.businessinsider.com/ebuddy-2011-8',
#     'source_text': '',
#     'source_description': 'Mobile Messaging Platform eBuddy Raising Money At $100 Million Valuation',
#     'stoneable_type': 'Company',
#     'stoned_value': None,
#     'stoned_value_type': None,
#     'stoned_acquirer': None,
#     'stoneable': {'name': 'eBuddy', 'permalink': 'ebuddy'}},
#    {'id': 40174,
#     'description': 'Japanese gaming company GREE acquired a minority stake in eBuddy',
#     'stoned_year': 2012,
#     'stoned_month': None,
#     'stoned_day': None,
#     'source_url': 'http://techcrunch.com/2012/10/15/ebuddy-gree-stake-sale/',
#     'source_text': None,
#     'source_description': 'TechCrunch',
#     'stoneable_type': 'Company',
#     'stoned_value': None,
#     'stoned_value_type': None,
#     'stoned_acquirer': None,
#     'stoneable': {'name': 'eBuddy', 'permalink': 'ebuddy'}},
#    {'id': 40299,
#     'description': 'eBuddy receives Mashable award for the Best Mobile App.',
#     'stoned_year': 2009,
#     'stoned_month': None,
#     'stoned_day': None,
#     'source_url': 'http://mashable.com/2009/12/16/open-web-awards-2009-50-winners/',
#     'source_text': None,
#     'source_description': 'Mashable',
#     'stoneable_type': 'Company',
#     'stoned_value': None,
#     'stoned_value_type': None,
#     'stoned_acquirer': None,
#     'stoneable': {'name': 'eBuddy', 'permalink': 'ebuddy'}},
#    {'id': 40300,
#     'description': 'eBuddy receives Mashable award for the Best Mobile User Experience.',
#     'stoned_year': 2010,
#     'stoned_month': None,
#     'stoned_day': None,
#     'source_url': 'http://mashable.com/2011/01/06/mashable-awards-2010-announcing-the-winners/',
#     'source_text': None,
#     'source_description': 'Mashable',
#     'stoneable_type': 'Company',
#     'stoned_value': None,
#     'stoned_value_type': None,
#     'stoned_acquirer': None,
#     'stoneable': {'name': 'eBuddy', 'permalink': 'ebuddy'}},
#    {'id': 40301,
#     'description': 'eBuddy receives Crunchies award for the Best International Startup.',
#     'stoned_year': 2008,
#     'stoned_month': None,
#     'stoned_day': None,
#     'source_url': 'http://crunchies2008.techcrunch.com/',
#     'source_text': None,
#     'source_description': 'TechCrunch',
#     'stoneable_type': 'Company',
#     'stoned_value': None,
#     'stoned_value_type': None,
#     'stoned_acquirer': None,
#     'stoneable': {'name': 'eBuddy', 'permalink': 'ebuddy'}},
#    {'id': 40302,
#     'description': 'eBuddy launched XMS.',
#     'stoned_year': 2011,
#     'stoned_month': 3,
#     'stoned_day': 17,
#     'source_url': 'http://techcrunch.com/2011/03/17/sms-on-steroids-ebuddy-debuts-realtime-cross-platform-messaging-app/',
#     'source_text': None,
#     'source_description': 'TechCrunch',
#     'stoneable_type': 'Company',
#     'stoned_value': None,
#     'stoned_value_type': None,
#     'stoned_acquirer': None,
#     'stoneable': {'name': 'eBuddy', 'permalink': 'ebuddy'}},
#    {'id': 40303,
#     'description': 'eBuddy achieved over 100 million downloads.',
#     'stoned_year': 2010,
#     'stoned_month': 9,
#     'stoned_day': 30,
#     'source_url': 'http://techcrunch.com/2010/09/30/ebuddys-mobile-applications-downloaded-more-than-100-million-times/',
#     'source_text': None,
#     'source_description': 'TechCrunch',
#     'stoneable_type': 'Company',
#     'stoned_value': None,
#     'stoned_value_type': None,
#     'stoned_acquirer': None,
#     'stoneable': {'name': 'eBuddy', 'permalink': 'ebuddy'}},
#    {'id': 40304,
#     'description': 'eBuddy exceeded 250 million user accounts.',
#     'stoned_year': 2011,
#     'stoned_month': 9,
#     'stoned_day': 21,
#     'source_url': 'http://techcrunch.com/2011/09/21/ebuddy-blows-through-250-million-user-accounts-android-up-300/',
#     'source_text': None,
#     'source_description': 'TechCrunch',
#     'stoneable_type': 'Company',
#     'stoned_value': None,
#     'stoned_value_type': None,
#     'stoned_acquirer': None,
#     'stoneable': {'name': 'eBuddy', 'permalink': 'ebuddy'}}],
#   'ipo': None,
#   'video_embeds': [],
#   'screenshots': [{'available_sizes': [[[150, 55],
#       'assets/images/resized/0033/4855/334855v2-max-150x150.jpg'],
#      [[250, 92], 'assets/images/resized/0033/4855/334855v2-max-250x250.jpg'],
#      [[450, 166], 'assets/images/resized/0033/4855/334855v2-max-450x450.jpg']],
#     'attribution': None},
#    {'available_sizes': [[[150, 79],
#       'assets/images/resized/0033/4865/334865v2-max-150x150.png'],
#      [[250, 132], 'assets/images/resized/0033/4865/334865v2-max-250x250.png'],
#      [[450, 238], 'assets/images/resized/0033/4865/334865v2-max-450x450.png']],
#     'attribution': None}],
#   'external_links': [{'external_url': 'http://www.ebuddy.com/2008/08/23/ebuddy-taps-former-google-executive-marc-duijndam/',
#     'title': 'eBuddy Taps Former Google Executive, Marc Duijndam'}],
#   'partners': [],
#   'location': [{'type': 'Point', 'coordinates': [4.8919457, 52.3640933]},
#    {'type': 'Point', 'coordinates': [-122.410943, 37.787683]},
#    {'type': 'Point', 'coordinates': [-0.126236, 51.500152]}]},
#  {'_id': ObjectId('52cdef7c4bab8bd6752980e4'),
#   'name': 'GeoSentric',
#   'permalink': 'geosentric',
#   'crunchbase_url': 'http://www.crunchbase.com/company/geosentric',
#   'homepage_url': 'http://www.geosentric.com',
#   'blog_url': '',
#   'blog_feed_url': '',
#   'twitter_username': '',
#   'category_code': 'mobile',
#   'number_of_employees': None,
#   'founded_year': 2007,
#   'founded_month': 6,
#   'founded_day': 1,
#   'deadpooled_year': None,
#   'deadpooled_month': None,
#   'deadpooled_day': None,
#   'deadpooled_url': None,
#   'tag_list': '',
#   'alias_list': None,
#   'email_address': 'communications!@gypsii.com',
#   'phone_number': '+14019215184',
#   'description': 'Social Network and LBS product developer',
#   'created_at': 'Wed Nov 14 18:50:00 UTC 2007',
#   'updated_at': 'Thu Dec 27 20:43:44 UTC 2012',
#   'overview': '<p>GeoSentric&#8217;s GyPSii is the market-leading mobile digital lifestyle application and geo-mobility social networking platform: connecting people, places and communities across networks and devices, with patented technologies for the transfer and publishing of location based information between mobile devices. </p>\n\n<p>Based in Salo, Finland and Amsterdam, The Netherlands, GeoSentric operates offices in North America, Europe and Asia Pacific. GeoSentric is listed on the Nordic Exchange (NASDAQ OMX: GEO1V)). </p>',
#   'image': {'available_sizes': [[[150, 48],
#      'assets/images/resized/0002/0654/20654v1-max-150x150.png'],
#     [[250, 80], 'assets/images/resized/0002/0654/20654v1-max-250x250.png'],
#     [[250, 80], 'assets/images/resized/0002/0654/20654v1-max-450x450.png']],
#    'attribution': None},
#   'products': [{'name': 'GyPSii', 'permalink': 'gypsii'}],
#   'relationships': [{'is_past': False,
#     'title': 'GM, SVP',
#     'person': {'first_name': 'Mike',
#      'last_name': 'Po',
#      'permalink': 'mike-po'}},
#    {'is_past': True,
#     'title': 'Co-Founder (GyPSii)',
#     'person': {'first_name': 'Sam',
#      'last_name': 'Critchley',
#      'permalink': 'sam-critchley'}},
#    {'is_past': True,
#     'title': 'Executive Chairman',
#     'person': {'first_name': 'Dan',
#      'last_name': 'Harple',
#      'permalink': 'dan-harple'}},
#    {'is_past': True,
#     'title': 'CFO',
#     'person': {'first_name': 'Robin',
#      'last_name': 'Halliday',
#      'permalink': 'robin-halliday'}}],
#   'competitions': [],
#   'providerships': [],
#   'total_money_raised': '$24.1M',
#   'funding_rounds': [{'id': 981,
#     'round_code': 'a',
#     'source_url': 'http://www.fiercewireless.com/press-releases/geosentric-secures-additional-13-million-financing-new-and-existing-investors',
#     'source_description': '',
#     'raised_amount': 13100000,
#     'raised_currency_code': 'USD',
#     'funded_year': 2007,
#     'funded_month': 9,
#     'funded_day': 1,
#     'investments': [{'company': None,
#       'financial_org': {'name': 'Horizon Group', 'permalink': 'horizon-group'},
#       'person': None},
#      {'company': None,
#       'financial_org': {'name': 'Schroders',
#        'permalink': 'schroders-private-bank'},
#       'person': None}]},
#    {'id': 13025,
#     'round_code': 'b',
#     'source_url': 'http://paidcontent.org/article/419-gypsii-raises-another-11-million-for-mobile-location-sharing/',
#     'source_description': 'GyPSii Raises Another $11 Million For Mobile Location Sharing ',
#     'raised_amount': 11000000,
#     'raised_currency_code': 'USD',
#     'funded_year': 2010,
#     'funded_month': 3,
#     'funded_day': 15,
#     'investments': [{'company': None,
#       'financial_org': {'name': 'Schroders',
#        'permalink': 'schroders-private-bank'},
#       'person': None}]}],
#   'investments': [],
#   'acquisition': None,
#   'acquisitions': [],
#   'offices': [{'description': 'Amsterdam',
#     'address1': 'Keizersgracht 212',
#     'address2': '',
#     'zip_code': '1016 DX',
#     'city': 'Amsterdam',
#     'state_code': None,
#     'country_code': 'NLD',
#     'latitude': 37.09024,
#     'longitude': -95.712891}],
#   'milestones': [],
#   'ipo': {'valuation_amount': None,
#    'valuation_currency_code': 'USD',
#    'pub_year': None,
#    'pub_month': None,
#    'pub_day': None,
#    'stock_symbol': 'NASDAQ OMX:GEO1V'},
#   'video_embeds': [],
#   'screenshots': [],
#   'external_links': [],
#   'partners': [],
#   'location': [{'type': 'Point', 'coordinates': [-95.712891, 37.09024]}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675298205'),
#   'name': 'livecastr',
#   'permalink': 'livecastr',
#   'crunchbase_url': 'http://www.crunchbase.com/company/livecastr',
#   'homepage_url': 'http://livecastr.com',
#   'blog_url': 'http://livecastr.com/davos08.html',
#   'blog_feed_url': None,
#   'twitter_username': None,
#   'category_code': 'games_video',
#   'number_of_employees': None,
#   'founded_year': None,
#   'founded_month': None,
#   'founded_day': None,
#   'deadpooled_year': None,
#   'deadpooled_month': None,
#   'deadpooled_day': None,
#   'deadpooled_url': None,
#   'tag_list': 'livestreaming, videocalling, cellphones, videopublishing',
#   'alias_list': None,
#   'email_address': 'ralph@livecastr.com',
#   'phone_number': '+31 20 368 0645',
#   'description': None,
#   'created_at': 'Fri Jan 25 12:11:22 UTC 2008',
#   'updated_at': 'Thu Dec 01 07:36:46 UTC 2011',
#   'overview': '<p>A service developed by IceMobile, livecastr allows users to broadcast live video from their phones either via a software download to their phone, or if supported by the handset, making a video call to livecastr, who then archives the video.  The service competes with other live-streaming-via-phone offerings from <a href="http://www.crunchbase.com/company/mogulus" title="Mogulus">Mogulus</a>, <a href="http://www.crunchbase.com/company/qik" title="Qik">Qik</a>, <a href="http://www.crunchbase.com/company/flixwagon" title="FlixWagon">FlixWagon</a> and <a href="http://www.crunchbase.com/company/Bambuser" title="Bambuser">Bambuser</a>.</p>',
#   'image': {'available_sizes': [[[148, 50],
#      'assets/images/resized/0000/3298/3298v1-max-150x150.png'],
#     [[148, 50], 'assets/images/resized/0000/3298/3298v1-max-250x250.png'],
#     [[148, 50], 'assets/images/resized/0000/3298/3298v1-max-450x450.png']],
#    'attribution': None},
#   'products': [{'name': 'livecastr', 'permalink': 'livecastr'}],
#   'relationships': [{'is_past': None,
#     'title': 'Founder',
#     'person': {'first_name': 'Ralph',
#      'last_name': 'Cohen',
#      'permalink': 'ralph-cohen'}}],
#   'competitions': [{'competitor': {'name': 'Livestream',
#      'permalink': 'livestream'}},
#    {'competitor': {'name': 'Bambuser', 'permalink': 'bambuser'}}],
#   'providerships': [],
#   'total_money_raised': '$0',
#   'funding_rounds': [],
#   'investments': [],
#   'acquisition': None,
#   'acquisitions': [],
#   'offices': [{'description': None,
#     'address1': None,
#     'address2': None,
#     'zip_code': None,
#     'city': 'Amsterdam',
#     'state_code': None,
#     'country_code': 'NLD',
#     'latitude': 52.373812,
#     'longitude': 4.890951}],
#   'milestones': [],
#   'ipo': None,
#   'video_embeds': [],
#   'screenshots': [],
#   'external_links': [],
#   'partners': []},
#  {'_id': ObjectId('52cdef7c4bab8bd675298247'),
#   'name': 'MovingLabs',
#   'permalink': 'movinglabs',
#   'crunchbase_url': 'http://www.crunchbase.com/company/movinglabs',
#   'homepage_url': 'http://www.movinglabs.com',
#   'blog_url': 'http://www.movinglabs.com/index.php/EN/Weblog',
#   'blog_feed_url': 'http://www.movinglabs.com/index.php/EN/Weblog/RSS',
#   'twitter_username': 'movinglabs',
#   'category_code': 'web',
#   'number_of_employees': None,
#   'founded_year': None,
#   'founded_month': None,
#   'founded_day': None,
#   'deadpooled_year': None,
#   'deadpooled_month': None,
#   'deadpooled_day': None,
#   'deadpooled_url': None,
#   'tag_list': None,
#   'alias_list': None,
#   'email_address': 'info@movinglabs.com',
#   'phone_number': '',
#   'description': None,
#   'created_at': 'Mon Feb 11 22:27:53 UTC 2008',
#   'updated_at': 'Thu Sep 22 16:42:48 UTC 2011',
#   'overview': '<p>MovingLabs hosts a slew of web apps.  Products range from a Photo site to an online database platform.</p>',
#   'image': {'available_sizes': [[[150, 45],
#      'assets/images/resized/0001/1496/11496v1-max-150x150.jpg'],
#     [[212, 64], 'assets/images/resized/0001/1496/11496v1-max-250x250.jpg'],
#     [[212, 64], 'assets/images/resized/0001/1496/11496v1-max-450x450.jpg']],
#    'attribution': None},
#   'products': [{'name': 'PicturePush', 'permalink': 'picturepush'},
#    {'name': 'FlexLists', 'permalink': 'flexlists'},
#    {'name': 'XinuReturns', 'permalink': 'xinureturns'},
#    {'name': 'VoteLists', 'permalink': 'votelists'},
#    {'name': 'BloxDB', 'permalink': 'bloxdb'},
#    {'name': 'TeamSpinner', 'permalink': 'teamspinner'},
#    {'name': 'Observu', 'permalink': 'observu'}],
#   'relationships': [{'is_past': None,
#     'title': '',
#     'person': {'first_name': 'Tycho',
#      'last_name': 'Luyben',
#      'permalink': 'tycho-luyben'}},
#    {'is_past': None,
#     'title': '',
#     'person': {'first_name': 'Michiel',
#      'last_name': 'van Vlaardingen',
#      'permalink': 'michiel-van-vlaardingen'}}],
#   'competitions': [{'competitor': {'name': 'Dabble DB',
#      'permalink': 'dabbledb'}},
#    {'competitor': {'name': 'Zoho', 'permalink': 'zoho'}},
#    {'competitor': {'name': 'Flickr', 'permalink': 'flickr'}}],
#   'providerships': [],
#   'total_money_raised': '$0',
#   'funding_rounds': [],
#   'investments': [],
#   'acquisition': None,
#   'acquisitions': [],
#   'offices': [{'description': None,
#     'address1': '',
#     'address2': '',
#     'zip_code': '',
#     'city': 'Amsterdam',
#     'state_code': None,
#     'country_code': 'NLD',
#     'latitude': 52.373812,
#     'longitude': 4.890951}],
#   'milestones': [],
#   'ipo': None,
#   'video_embeds': [],
#   'screenshots': [],
#   'external_links': [],
#   'partners': []},
#  {'_id': ObjectId('52cdef7c4bab8bd6752982c8'),
#   'name': 'RankOne Media Group',
#   'permalink': 'rankone-media-group',
#   'crunchbase_url': 'http://www.crunchbase.com/company/rankone-media-group',
#   'homepage_url': 'http://www.rankone.nl',
#   'blog_url': 'http://www.rankone.nl/nl/blog/',
#   'blog_feed_url': 'http://www.rankone.nl/blog/?feed=rss2',
#   'twitter_username': None,
#   'category_code': 'web',
#   'number_of_employees': 10,
#   'founded_year': 2002,
#   'founded_month': 1,
#   'founded_day': 1,
#   'deadpooled_year': None,
#   'deadpooled_month': None,
#   'deadpooled_day': None,
#   'deadpooled_url': None,
#   'tag_list': None,
#   'alias_list': None,
#   'email_address': 'info@rankone.nl',
#   'phone_number': '0031204279597',
#   'description': None,
#   'created_at': 'Wed Feb 13 18:02:08 UTC 2008',
#   'updated_at': 'Wed Oct 28 20:44:39 UTC 2009',
#   'overview': '<p>RankOne Media builds online community technology.  </p>',
#   'image': {'available_sizes': [[[150, 64],
#      'assets/images/resized/0001/2031/12031v1-max-150x150.png'],
#     [[192, 83], 'assets/images/resized/0001/2031/12031v1-max-250x250.png'],
#     [[192, 83], 'assets/images/resized/0001/2031/12031v1-max-450x450.png']],
#    'attribution': None},
#   'products': [{'name': 'cdfreaks.com', 'permalink': 'cdfreaks-com'}],
#   'relationships': [{'is_past': False,
#     'title': 'CEO and Founder',
#     'person': {'first_name': 'R.J.',
#      'last_name': 'van Lieshout',
#      'permalink': 'r-j-van-lieshout'}},
#    {'is_past': True,
#     'title': 'Managing Director',
#     'person': {'first_name': 'J.W.',
#      'last_name': 'Aldershoff',
#      'permalink': 'j-w-aldershoff'}}],
#   'competitions': [],
#   'providerships': [],
#   'total_money_raised': '$0',
#   'funding_rounds': [],
#   'investments': [],
#   'acquisition': None,
#   'acquisitions': [],
#   'offices': [{'description': None,
#     'address1': 'Herengracht 498',
#     'address2': '',
#     'zip_code': '1017CB',
#     'city': 'Amsterdam',
#     'state_code': None,
#     'country_code': 'NLD',
#     'latitude': 52.365001,
#     'longitude': 4.892903}],
#   'milestones': [],
#   'ipo': None,
#   'video_embeds': [],
#   'screenshots': [],
#   'external_links': [{'external_url': 'http://www.cdfreaks.com',
#     'title': 'CD Freaks.com'}],
#   'partners': []},
#  {'_id': ObjectId('52cdef7c4bab8bd6752983b3'),
#   'name': 'Mobypicture',
#   'permalink': 'mobypicture',
#   'crunchbase_url': 'http://www.crunchbase.com/company/mobypicture',
#   'homepage_url': 'http://www.mobypicture.com',
#   'blog_url': 'http://mathys.vanabbe.com/',
#   'blog_feed_url': 'http://mathys.vanabbe.com/?feed=rss2',
#   'twitter_username': 'mobypicture',
#   'category_code': 'mobile',
#   'number_of_employees': 5,
#   'founded_year': None,
#   'founded_month': None,
#   'founded_day': None,
#   'deadpooled_year': None,
#   'deadpooled_month': None,
#   'deadpooled_day': None,
#   'deadpooled_url': None,
#   'tag_list': '',
#   'alias_list': '',
#   'email_address': '',
#   'phone_number': '',
#   'description': 'Photo/Video Sharing Service',
#   'created_at': 'Sun Feb 24 07:52:31 UTC 2008',
#   'updated_at': 'Wed Jun 19 14:16:40 UTC 2013',
#   'overview': '<p>Share your adventures instantly with your friends.  Mobypicture enables users to share photos, video, text and audio directly to their friends on their favorite social sites like Flickr, Facebook, YouTube, Wordpress, Twitter and many more. Mobypicture supports groups, geolocation and a lot of extra features.</p>',
#   'image': {'available_sizes': [[[150, 51],
#      'assets/images/resized/0003/8224/38224v5-max-150x150.png'],
#     [[250, 85], 'assets/images/resized/0003/8224/38224v5-max-250x250.png'],
#     [[450, 153], 'assets/images/resized/0003/8224/38224v5-max-450x450.png']],
#    'attribution': None},
#   'products': [],
#   'relationships': [{'is_past': False,
#     'title': 'Founder and managing partner',
#     'person': {'first_name': 'Mathys',
#      'last_name': 'van Abbe',
#      'permalink': 'mathys-van-abbe'}},
#    {'is_past': True,
#     'title': 'CTO',
#     'person': {'first_name': 'Timan',
#      'last_name': 'Rebel',
#      'permalink': 'timan-rebel'}}],
#   'competitions': [{'competitor': {'name': 'Tiny Pictures',
#      'permalink': 'tiny-pictures'}},
#    {'competitor': {'name': 'Pixelpipe', 'permalink': 'pixelpipe'}},
#    {'competitor': {'name': 'Shozu', 'permalink': 'shozu'}},
#    {'competitor': {'name': 'Twitpic', 'permalink': 'twitpic'}},
#    {'competitor': {'name': 'yfrog', 'permalink': 'yfrog'}}],
#   'providerships': [],
#   'total_money_raised': '$0',
#   'funding_rounds': [],
#   'investments': [],
#   'acquisition': None,
#   'acquisitions': [],
#   'offices': [{'description': 'Mobyboat HQ',
#     'address1': 'Amstel 51h',
#     'address2': '',
#     'zip_code': '1018EJ',
#     'city': 'Amsterdam',
#     'state_code': None,
#     'country_code': 'NLD',
#     'latitude': 52.3650312,
#     'longitude': 4.9024295}],
#   'milestones': [{'id': 14745,
#     'description': 'Hired Glenn Wolters as an intern iOS developer',
#     'stoned_year': 2011,
#     'stoned_month': 2,
#     'stoned_day': 1,
#     'source_url': '',
#     'source_text': None,
#     'source_description': '',
#     'stoneable_type': 'Company',
#     'stoned_value': None,
#     'stoned_value_type': None,
#     'stoned_acquirer': None,
#     'stoneable': {'name': 'Mobypicture', 'permalink': 'mobypicture'}}],
#   'ipo': None,
#   'video_embeds': [],
#   'screenshots': [{'available_sizes': [[[150, 95],
#       'assets/images/resized/0003/8225/38225v1-max-150x150.png'],
#      [[250, 159], 'assets/images/resized/0003/8225/38225v1-max-250x250.png'],
#      [[450, 287], 'assets/images/resized/0003/8225/38225v1-max-450x450.png']],
#     'attribution': None},
#    {'available_sizes': [[[150, 93],
#       'assets/images/resized/0012/4313/124313v2-max-150x150.png'],
#      [[250, 156], 'assets/images/resized/0012/4313/124313v2-max-250x250.png'],
#      [[450, 281], 'assets/images/resized/0012/4313/124313v2-max-450x450.png']],
#     'attribution': None}],
#   'external_links': [],
#   'partners': []},
#  {'_id': ObjectId('52cdef7c4bab8bd675298770'),
#   'name': 'MADS',
#   'permalink': 'mads',
#   'crunchbase_url': 'http://www.crunchbase.com/company/mads',
#   'homepage_url': 'http://www.mads.com',
#   'blog_url': '',
#   'blog_feed_url': '',
#   'twitter_username': '',
#   'category_code': 'advertising',
#   'number_of_employees': 20,
#   'founded_year': 2006,
#   'founded_month': 2,
#   'founded_day': 1,
#   'deadpooled_year': None,
#   'deadpooled_month': None,
#   'deadpooled_day': None,
#   'deadpooled_url': None,
#   'tag_list': 'mobile, advertising, profiling, location-based, desktop, smartphone, tablet, iptv, targeting, behavioural, re-targeting, rtb, mediation, multi-channel',
#   'alias_list': None,
#   'email_address': 'ashu.mathura@mads.com',
#   'phone_number': '+31 20 894 33 33',
#   'description': 'Inside Mobile Marketing',
#   'created_at': 'Tue Apr 08 20:20:58 UTC 2008',
#   'updated_at': 'Wed Sep 04 15:03:08 UTC 2013',
#   'overview': '<p>MADS | Inside Mobile Marketing</p>\n\n<p>MADS powers the full mobile advertising value chain, and enables operators, publishers and advertisers to deliver highly targeted and personalized campaigns to mobile consumers. MADS delivers a full suite of products including: MADS ONE for Operators, to create, manage and monetize mobile inventory; MADS ONE for Agencies, to plan, book and optimize campaigns; and MADS ONE for Advertisers, to track real-time campaign performance analytics and reports.</p>\n\n<p>MADS unlocks powerful advertising opportunities for brands and creates new revenue streams for operators and publishers across all mobile channels including: Mobile Internet, SMS Push/Insert, MMS Push/Insert, Mobile Video, Mobile Games and Applications, Idle Screen and Ring Back Tones. MADS empowers advertisers to deploy dynamic, interactive, highly personalized mobile ads to consumers with the same confidence and control as online ads.</p>\n\n<p>MADS is currently processing more than 2 billion ad requests per month World-wide, and is the mobile advertising platform of choice for more than 150 operators and publishers across 31 countries. MADS was founded in 2006 and is a privately-held company based in Amsterdam.</p>',
#   'image': {'available_sizes': [[[150, 50],
#      'assets/images/resized/0001/7019/17019v5-max-150x150.png'],
#     [[250, 83], 'assets/images/resized/0001/7019/17019v5-max-250x250.png'],
#     [[437, 146], 'assets/images/resized/0001/7019/17019v5-max-450x450.png']],
#    'attribution': None},
#   'products': [{'name': 'MADS ONE', 'permalink': 'mads-for-operators'}],
#   'relationships': [{'is_past': False,
#     'title': 'Co-founder & CTO',
#     'person': {'first_name': 'Dennis',
#      'last_name': 'Geerdink',
#      'permalink': 'dennis-geerdink'}},
#    {'is_past': False,
#     'title': 'Founder & CEO',
#     'person': {'first_name': 'Ashu',
#      'last_name': 'Mathura',
#      'permalink': 'ashu-mathura'}},
#    {'is_past': False,
#     'title': 'COO',
#     'person': {'first_name': 'Pieter',
#      'last_name': 'Smits',
#      'permalink': 'pieter-smits'}},
#    {'is_past': False,
#     'title': 'Director of Sales & CCO',
#     'person': {'first_name': 'Jasper',
#      'last_name': 'de Vreugt',
#      'permalink': 'jasper-de-vreugt'}},
#    {'is_past': False,
#     'title': 'CTO & Solutions Architect',
#     'person': {'first_name': 'Melvin',
#      'last_name': 'Rook',
#      'permalink': 'melvin-rook'}}],
#   'competitions': [{'competitor': {'name': 'Velti', 'permalink': 'velti'}},
#    {'competitor': {'name': 'Mocean Mobile', 'permalink': 'mocean-mobile'}},
#    {'competitor': {'name': 'Smart AdServer', 'permalink': 'smart-adserver'}},
#    {'competitor': {'name': 'DoubleClick', 'permalink': 'doubleclick'}},
#    {'competitor': {'name': 'ADTECH Systems', 'permalink': 'adtech-systems'}},
#    {'competitor': {'name': 'OpenX', 'permalink': 'openx'}}],
#   'providerships': [{'title': 'Marketing and PR',
#     'is_past': True,
#     'provider': {'name': 'Mercury Global Partners',
#      'permalink': 'mercury-global-partners'}}],
#   'total_money_raised': '€1.75M',
#   'funding_rounds': [{'id': 2622,
#     'round_code': 'seed',
#     'source_url': '',
#     'source_description': '',
#     'raised_amount': 250000,
#     'raised_currency_code': 'EUR',
#     'funded_year': 2006,
#     'funded_month': 4,
#     'funded_day': 1,
#     'investments': [{'company': None,
#       'financial_org': None,
#       'person': {'first_name': 'Ashu',
#        'last_name': 'Mathura',
#        'permalink': 'ashu-mathura'}}]},
#    {'id': 2674,
#     'round_code': 'a',
#     'source_url': '',
#     'source_description': '',
#     'raised_amount': 500000,
#     'raised_currency_code': 'EUR',
#     'funded_year': 2007,
#     'funded_month': 1,
#     'funded_day': 6,
#     'investments': [{'company': None,
#       'financial_org': {'name': 'HENQ Invest', 'permalink': 'henq-invest'},
#       'person': None}]},
#    {'id': 26344,
#     'round_code': 'b',
#     'source_url': 'http://eu.techcrunch.com/2011/11/04/mobile-ad-serving-startup-mads-raises-e1-million-series-b/',
#     'source_description': 'Mobile ad serving startup MADS raises â‚¬1 million Series B',
#     'raised_amount': 1000000,
#     'raised_currency_code': 'EUR',
#     'funded_year': 2011,
#     'funded_month': 11,
#     'funded_day': 4,
#     'investments': [{'company': None,
#       'financial_org': {'name': 'OTM Investments',
#        'permalink': 'otm-investments'},
#       'person': None}]}],
#   'investments': [],
#   'acquisition': None,
#   'acquisitions': [],
#   'offices': [{'description': 'World Headquarters',
#     'address1': 'Keizersgracht 635',
#     'address2': '',
#     'zip_code': '1017 DS',
#     'city': 'Amsterdam',
#     'state_code': None,
#     'country_code': 'NLD',
#     'latitude': 52.3637746,
#     'longitude': 4.8946071}],
#   'milestones': [],
#   'ipo': None,
#   'video_embeds': [],
#   'screenshots': [],
#   'external_links': [{'external_url': 'http://startuptunes.com/2011/11/20/mads-raises-e1m-1-4m-in-series-b-funding/',
#     'title': ''}],
#   'partners': [],
#   'location': [{'type': 'Point', 'coordinates': [4.8946071, 52.3637746]}]},
#  {'_id': ObjectId('52cdef7c4bab8bd6752987a6'),
#   'name': 'YouTellMe',
#   'permalink': 'youtellme',
#   'crunchbase_url': 'http://www.crunchbase.com/company/youtellme',
#   'homepage_url': 'http://www.youtellme.com',
#   'blog_url': 'http://www.youtellme.com/blog',
#   'blog_feed_url': 'http://www.youtellme.com/blog/feed/',
#   'twitter_username': None,
#   'category_code': 'ecommerce',
#   'number_of_employees': 7,
#   'founded_year': 2007,
#   'founded_month': 3,
#   'founded_day': 9,
#   'deadpooled_year': None,
#   'deadpooled_month': None,
#   'deadpooled_day': None,
#   'deadpooled_url': None,
#   'tag_list': 'social-shopping, start-up, buying-guide, consumer-support, decisions-support, product-comparison, pricecomparison',
#   'alias_list': None,
#   'email_address': 'info@youtellme.com',
#   'phone_number': '',
#   'description': None,
#   'created_at': 'Thu Apr 10 09:38:07 UTC 2008',
#   'updated_at': 'Thu Dec 01 07:41:44 UTC 2011',
#   'overview': '<p>YouTellMe is a social shopping website in Europe that focuses on product comparison.  International launch is scheduled for 2009. </p>\n\n<p>YouTellMe is founded by Joost Nauta &amp; Thijs Goos.  The company is located in Amsterdam, the Netherlands.</p>',
#   'image': {'available_sizes': [[[150, 48],
#      'assets/images/resized/0001/7105/17105v1-max-150x150.png'],
#     [[172, 56], 'assets/images/resized/0001/7105/17105v1-max-250x250.png'],
#     [[172, 56], 'assets/images/resized/0001/7105/17105v1-max-450x450.png']],
#    'attribution': None},
#   'products': [{'name': 'YouTellMe.com', 'permalink': 'youtellme-com'}],
#   'relationships': [{'is_past': False,
#     'title': 'CXO',
#     'person': {'first_name': 'Thijs',
#      'last_name': 'Goos',
#      'permalink': 'thijs-goos'}},
#    {'is_past': False,
#     'title': 'Board Member',
#     'person': {'first_name': 'Federico',
#      'last_name': 'Grosso',
#      'permalink': 'federico-grosso'}},
#    {'is_past': True,
#     'title': 'CEO',
#     'person': {'first_name': 'Joost',
#      'last_name': 'Nauta',
#      'permalink': 'joost-nauta'}},
#    {'is_past': True,
#     'title': 'CTO',
#     'person': {'first_name': 'Rick',
#      'last_name': 'van Hattem',
#      'permalink': 'rick-van-hattem'}},
#    {'is_past': True,
#     'title': 'Senior Engineer',
#     'person': {'first_name': 'Thierry',
#      'last_name': 'Schellenbach',
#      'permalink': 'thierry-schellenbach'}}],
#   'competitions': [],
#   'providerships': [],
#   'total_money_raised': '$0',
#   'funding_rounds': [],
#   'investments': [],
#   'acquisition': None,
#   'acquisitions': [],
#   'offices': [{'description': 'YouTellMe Headquarters',
#     'address1': 'Keizersgracht 182',
#     'address2': '',
#     'zip_code': '1016 DW',
#     'city': 'Amsterdam',
#     'state_code': None,
#     'country_code': 'NLD',
#     'latitude': 52.3751058,
#     'longitude': 4.8853887}],
#   'milestones': [],
#   'ipo': None,
#   'video_embeds': [],
#   'screenshots': [],
#   'external_links': [],
#   'partners': []},
#  {'_id': ObjectId('52cdef7c4bab8bd67529884a'),
#   'name': 'Mirror42',
#   'permalink': 'mirror42',
#   'crunchbase_url': 'http://www.crunchbase.com/company/mirror42',
#   'homepage_url': 'http://www.mirror42.com',
#   'blog_url': 'http://mirror42.com/blog',
#   'blog_feed_url': 'feed://kpilibrary.com/experts/recent.rss',
#   'twitter_username': 'mirror42',
#   'category_code': 'software',
#   'number_of_employees': 15,
#   'founded_year': 2004,
#   'founded_month': 4,
#   'founded_day': 10,
#   'deadpooled_year': None,
#   'deadpooled_month': None,
#   'deadpooled_day': None,
#   'deadpooled_url': None,
#   'tag_list': 'kpi, performance-management, saas, bi, business-intelligence, dashboards, benchmarking, community',
#   'alias_list': None,
#   'email_address': 'info@mirror42.com',
#   'phone_number': '+31 (0)20 531 56 20',
#   'description': 'SaaS Performance Management',
#   'created_at': 'Wed Apr 16 12:27:12 UTC 2008',
#   'updated_at': 'Fri Jun 01 13:18:40 UTC 2012',
#   'overview': '<p>Mirror42 enables businesses to implement performance management. At Mirror42 we believe that every company, big or small, should be able to measure themselves without having heavy investments in Enterprise Business Intelligence and without ending up in spreadsheet management. Performance management is about communicating and sharing information. The Internet and Software as a Service provide new opportunities for performance management professionals.</p>',
#   'image': {'available_sizes': [[[140, 60],
#      'assets/images/resized/0001/7381/17381v1-max-150x150.png'],
#     [[140, 60], 'assets/images/resized/0001/7381/17381v1-max-250x250.png'],
#     [[140, 60], 'assets/images/resized/0001/7381/17381v1-max-450x450.png']],
#    'attribution': None},
#   'products': [{'name': 'KPI Library', 'permalink': 'kpi-library'},
#    {'name': 'KPI Dashboard', 'permalink': 'kpi-dashboard'},
#    {'name': 'KPI Benchmark', 'permalink': 'kpi-benchmark'},
#    {'name': 'KPI Project', 'permalink': 'kpi-project'}],
#   'relationships': [{'is_past': False,
#     'title': 'CEO',
#     'person': {'first_name': 'Karel',
#      'last_name': 'van der Poel',
#      'permalink': 'karel-van-der-poel'}},
#    {'is_past': False,
#     'title': 'CTO',
#     'person': {'first_name': 'Laurens',
#      'last_name': 'Pit',
#      'permalink': 'laurens-pit'}},
#    {'is_past': False,
#     'title': 'VP Products',
#     'person': {'first_name': 'Erik',
#      'last_name': 'Hoffmann',
#      'permalink': 'erik-hoffmann'}},
#    {'is_past': False,
#     'title': 'SVP Business Development',
#     'person': {'first_name': 'Arjen',
#      'last_name': 'Pront',
#      'permalink': 'arjen-pront'}},
#    {'is_past': True,
#     'title': 'CEO',
#     'person': {'first_name': 'Marcel',
#      'last_name': 'E. Smit',
#      'permalink': 'marcel-e-smit'}},
#    {'is_past': True,
#     'title': 'CFO',
#     'person': {'first_name': 'Arjan',
#      'last_name': 'Berkenbosch',
#      'permalink': 'arjan-berkenbosch'}},
#    {'is_past': True,
#     'title': 'Worldwide VP Sales',
#     'person': {'first_name': 'Marc',
#      'last_name': 'Mulder',
# ...
#   'blog_feed_url': '',
#   'twitter_username': 'Layar',
#   'category_code': 'mobile',
#   'number_of_employees': 32,
#   'founded_year': 2009,
#   'founded_month': 8,
#   'founded_day': None,
#   'deadpooled_year': None,
#   'deadpooled_month': None,
#   'deadpooled_day': None,
#   'deadpooled_url': None,
#   'tag_list': 'browser, mobile-browser, augmented-reality-browser, camera-browser',
#   'alias_list': '',
#   'email_address': 'info@layar.com',
#   'phone_number': '',
#   'description': 'Augmented Reality',
#   'created_at': 'Sun Jun 21 10:59:44 UTC 2009',
#   'updated_at': 'Mon Aug 26 12:38:28 UTC 2013',
#   'overview': '<p>Layar B.V. designs and develops mobile phone application. It offers Layar, a mobile augmented browser that provides information on top of the camera display view in various categories, including eating and drinking, entertainment and leisure, games, government, health care, local search and directory services, real estate, retail, schools and universities, social networks and communities, tourism, transportation, and weather. </p>\n\n<p>The company was founded in 2009 and is headquartered in Amsterdam, the Netherlands.</p>',
#   'image': {'available_sizes': [[[150, 75],
#      'assets/images/resized/0004/9966/49966v13-max-150x150.png'],
#     [[250, 125], 'assets/images/resized/0004/9966/49966v13-max-250x250.png'],
#     [[450, 225], 'assets/images/resized/0004/9966/49966v13-max-450x450.png']],
#    'attribution': None},
#   'products': [],
#   'relationships': [{'is_past': False,
#     'title': 'Founder',
#     'person': {'first_name': 'Claire',
#      'last_name': 'Boonstra',
#      'permalink': 'claire-boonstra'}},
#    {'is_past': False,
#     'title': 'Founder',
#     'person': {'first_name': 'Raimo',
#      'last_name': 'Van Der Klein',
#      'permalink': 'raimo-van-der-klein'}},
#    {'is_past': False,
#     'title': 'CEO',
#     'person': {'first_name': 'Quintin',
#      'last_name': 'Schevernels',
#      'permalink': 'quintin-schevernels'}},
#    {'is_past': False,
#     'title': 'Founder',
#     'person': {'first_name': 'Maarten',
#      'last_name': 'Lens-Fitzgerald',
#      'permalink': 'maarten-lens-fitzgerald'}},
#    {'is_past': True,
#     'title': 'Worldwide Head of Customer Development',
#     'person': {'first_name': 'Matt',
#      'last_name': 'Miesnieks',
#      'permalink': 'matt-miesnieks'}}],
#   'competitions': [],
#   'providerships': [{'title': 'Europe & US',
#     'is_past': True,
#     'provider': {'name': 'Ballou PR', 'permalink': 'ballou-pr'}}],
#   'total_money_raised': '$13.4M',
#   'funding_rounds': [{'id': 9299,
#     'round_code': 'a',
#     'source_url': 'http://techcrunch.com/2010/02/15/layar-scores-3-4m-in-funding-global-distribution-agreement/',
#     'source_description': 'Layar Scores $3.4M In Funding, Global Distribution Agreement',
#     'raised_amount': 3400000,
#     'raised_currency_code': 'USD',
#     'funded_year': 2010,
#     'funded_month': 2,
#     'funded_day': 15,
#     'investments': [{'company': None,
#       'financial_org': {'name': 'Sunstone Capital',
#        'permalink': 'sunstone-capital'},
#       'person': None},
#      {'company': None,
#       'financial_org': {'name': 'Prime Ventures',
#        'permalink': 'prime-technology-ventures'},
#       'person': None}]},
#    {'id': 20098,
#     'round_code': 'b',
#     'source_url': 'http://www.finsmes.com/2010/11/layar-closes-10m-series-b-funding-round.html',
#     'source_description': 'Layar Closes â‚¬10M Series B Funding Round',
#     'raised_amount': 10000000,
#     'raised_currency_code': 'EUR',
#     'funded_year': 2010,
#     'funded_month': 11,
#     'funded_day': 20,
#     'investments': [{'company': None,
#       'financial_org': {'name': 'Intel Capital', 'permalink': 'intel-capital'},
#       'person': None}]}],
#   'investments': [],
#   'acquisition': None,
#   'acquisitions': [],
#   'offices': [{'description': 'HQ',
#     'address1': 'Vijzelstraat 20',
#     'address2': '',
#     'zip_code': '1017HK',
#     'city': 'Amsterdam',
#     'state_code': None,
#     'country_code': 'NLD',
#     'latitude': 52.3657578,
#     'longitude': 4.8928722}],
#   'milestones': [],
#   'ipo': None,
#   'video_embeds': [{'embed_code': '<iframe width="430" height="270" src="//www.youtube.com/embed/OQUcX1QyH6k?list=UU6wgCjjHckp6In6-vHF_xQQ" frameborder="0" allowfullscreen></iframe>',
#     'description': '<p>Discover interactive print with the Layar App!</p>'}],
#   'screenshots': [{'available_sizes': [[[150, 113],
#       'assets/images/resized/0031/3965/313965v4-max-150x150.png'],
#      [[250, 189], 'assets/images/resized/0031/3965/313965v4-max-250x250.png'],
#      [[450, 341], 'assets/images/resized/0031/3965/313965v4-max-450x450.png']],
#     'attribution': None},
#    {'available_sizes': [[[150, 86],
#       'assets/images/resized/0031/3966/313966v2-max-150x150.png'],
#      [[250, 144], 'assets/images/resized/0031/3966/313966v2-max-250x250.png'],
#      [[450, 259], 'assets/images/resized/0031/3966/313966v2-max-450x450.png']],
#     'attribution': None}],
#   'external_links': [{'external_url': 'http://www.facebook.com/augmented.reality.layar',
#     'title': 'Facebook Page'},
#    {'external_url': 'https://twitter.com/Layar', 'title': 'Twitter'},
#    {'external_url': 'http://www.linkedin.com/company/layar',
#     'title': 'LinkedIn'},
#    {'external_url': 'http://pinterest.com/LayarAR', 'title': 'Pinterest'}],
#   'partners': [],
#   'location': [{'type': 'Point', 'coordinates': [4.8928722, 52.3657578]}]},
#  {'_id': ObjectId('52cdef7f4bab8bd67529c1aa'),
#   'name': 'Lipperhey',
#   'permalink': 'lipperhey',
#   'crunchbase_url': 'http://www.crunchbase.com/company/lipperhey',
#   'homepage_url': 'http://www.lipperhey.com',
#   'blog_url': '',
#   'blog_feed_url': '',
#   'twitter_username': 'lipperheytweets',
#   'category_code': 'software',
#   'number_of_employees': 6,
#   'founded_year': 2009,
#   'founded_month': 4,
#   'founded_day': 8,
#   'deadpooled_year': None,
#   'deadpooled_month': None,
#   'deadpooled_day': None,
#   'deadpooled_url': None,
#   'tag_list': 'seo, searchabillity, online, service, soho',
#   'alias_list': None,
#   'email_address': 'info@lipperhey.com',
#   'phone_number': '',
#   'description': 'online seo service',
#   'created_at': 'Tue Jun 23 23:18:07 UTC 2009',
#   'updated_at': 'Sun Aug 28 02:18:31 UTC 2011',
#   'overview': '<p>Lipperhey is an objective online service that analyzes the quality, searchability and popularity of Web sites.  The service is based on privately developed software that assesses Web sites according to the SEO principles developed by the leading search engines.  The service helps Web site owners understand how to better optimize their Web sites to attract more customers and increase sales.  Lipperhey is based in Amsterdam and can be found at www.lipperhey.com</p>',
#   'image': {'available_sizes': [[[150, 39],
#      'assets/images/resized/0005/0413/50413v2-max-150x150.jpg'],
#     [[250, 65], 'assets/images/resized/0005/0413/50413v2-max-250x250.jpg'],
#     [[450, 117], 'assets/images/resized/0005/0413/50413v2-max-450x450.jpg']],
#    'attribution': None},
#   'products': [{'name': 'SEO analysis', 'permalink': 'seo-analysis'}],
#   'relationships': [{'is_past': False,
#     'title': 'Co-Founder',
#     'person': {'first_name': 'Gijs',
#      'last_name': 'Barends',
#      'permalink': 'gijs-barends'}},
#    {'is_past': False,
#     'title': 'Co-Founder',
#     'person': {'first_name': 'Marc',
#      'last_name': 'NoÃ«t',
#      'permalink': 'marc-not'}},
#    {'is_past': False,
#     'title': 'Co-Founder',
#     'person': {'first_name': 'Henk',
#      'last_name': 'Molenaar',
#      'permalink': 'henk-molenaar'}},
#    {'is_past': False,
#     'title': 'Co-Founder',
#     'person': {'first_name': 'Christian',
#      'last_name': 'Branbergen',
#      'permalink': 'christian-branbergen'}}],
#   'competitions': [{'competitor': {'name': 'HubSpot', 'permalink': 'hubspot'}},
#    {'competitor': {'name': 'UpCity', 'permalink': 'diyseo'}},
#    {'competitor': {'name': 'Analytics SEO', 'permalink': 'analytics-seo'}}],
#   'providerships': [{'title': 'PR',
#     'is_past': False,
#     'provider': {'name': 'SHIFT Communications',
#      'permalink': 'shift-communications'}}],
#   'total_money_raised': '€200k',
#   'funding_rounds': [{'id': 6874,
#     'round_code': 'seed',
#     'source_url': '',
#     'source_description': '',
#     'raised_amount': 200000,
#     'raised_currency_code': 'EUR',
#     'funded_year': 2010,
#     'funded_month': 1,
#     'funded_day': 1,
#     'investments': []}],
#   'investments': [],
#   'acquisition': None,
#   'acquisitions': [],
#   'offices': [{'description': 'Amsterdam Office',
#     'address1': 'Timorplein 42',
#     'address2': '',
#     'zip_code': '1094CC',
#     'city': 'Amsterdam',
#     'state_code': None,
#     'country_code': 'NLD',
#     'latitude': 52.3655578,
#     'longitude': 4.9345824}],
#   'milestones': [],
#   'ipo': None,
#   'video_embeds': [],
#   'screenshots': [],
#   'external_links': [{'external_url': 'http://www.searchcowboys.com',
#     'title': 'Online SEO-check: '}],
#   'partners': [],
#   'location': [{'type': 'Point', 'coordinates': [4.9345824, 52.3655578]}]},
#  {'_id': ObjectId('52cdef7f4bab8bd67529c22d'),
#   'name': 'Elsevier',
#   'permalink': 'elsevier',
#   'crunchbase_url': 'http://www.crunchbase.com/company/elsevier',
#   'homepage_url': 'http://www.elsevier.com',
#   'blog_url': '',
#   'blog_feed_url': '',
#   'twitter_username': 'ElsevierConnec',
#   'category_code': 'web',
#   'number_of_employees': None,
#   'founded_year': 1880,
#   'founded_month': None,
#   'founded_day': None,
#   'deadpooled_year': None,
#   'deadpooled_month': None,
#   'deadpooled_day': None,
#   'deadpooled_url': None,
#   'tag_list': '',
#   'alias_list': '',
#   'email_address': '',
#   'phone_number': '',
#   'description': 'Medical and Science Documents',
#   'created_at': 'Thu Jun 25 21:47:30 UTC 2009',
#   'updated_at': 'Tue Oct 15 21:43:07 UTC 2013',
#   'overview': '<p>Elsevier is a world-leading publisher of scientific, technical and medical information products and services. Working in partnership with the global science and health communities, Elsevier&#8217;s 7,000 employees in over 70 offices worldwide publish more than 2,000 journals and 1,900 new books per year, in addition to offering a suite of innovative electronic products, such as ScienceDirect, MD Consult, Scopus, bibliographic databases, and online reference works.</p>\n\n<p>Elsevier is a global business headquartered in Amsterdam, The Netherlands and has offices worldwide. Elsevier is part of External link  Reed Elsevier Group plc, a world-leading publisher and information provider. Operating in the science and medical, legal, education and business-to-business sectors, Reed Elsevier provides high-quality and flexible information solutions to users, with increasing emphasis on the Internet as a means of delivery. Reed Elsevier&#8217;s ticker symbols are REN (Euronext Amsterdam), REL (London Stock Exchange), RUK and ENL (New York Stock Exchange).</p>',
#   'image': {'available_sizes': [[[150, 33],
#      'assets/images/resized/0005/0737/50737v1-max-150x150.png'],
#     [[175, 39], 'assets/images/resized/0005/0737/50737v1-max-250x250.png'],
#     [[175, 39], 'assets/images/resized/0005/0737/50737v1-max-450x450.png']],
#    'attribution': None},
#   'products': [],
#   'relationships': [{'is_past': False,
#     'title': 'Chief Information Officer and Head of Global Electronic Product Development',
#     'person': {'first_name': 'Bill',
#      'last_name': 'Godfrey',
#      'permalink': 'bill-godfrey-2'}},
#    {'is_past': False,
#     'title': 'Chief Executive Officer',
#     'person': {'first_name': 'Ron',
#      'last_name': 'Mobed',
#      'permalink': 'ron-mobed'}},
#    {'is_past': False,
#     'title': 'Senior Vice President, Global Communications',
#     'person': {'first_name': 'David',
#      'last_name': 'Ruth',
#      'permalink': 'david-ruth'}},
#    {'is_past': False,
#     'title': 'Executive Vice President, Operations',
#     'person': {'first_name': 'Adriaan',
#      'last_name': 'Roosen',
#      'permalink': 'adriaan-roosen'}},
#    {'is_past': False,
#     'title': "Co - Editor, Cecil's Textbook of Medicine",
#     'person': {'first_name': 'Dennis',
#      'last_name': 'Ausiello',
#      'permalink': 'dennis-a-ausiello'}},
#    {'is_past': False,
#     'title': 'Senior Vice President and  General Counsel',
#     'person': {'first_name': 'Mark',
#      'last_name': 'Seeley',
#      'permalink': 'mark-seeley'}},
#    {'is_past': False,
#     'title': 'Chief Financial Officer',
#     'person': {'first_name': 'David',
#      'last_name': 'Lomas',
#      'permalink': 'david-lomas'}},
#    {'is_past': False,
#     'title': 'Director of Strategy',
#     'person': {'first_name': 'Eser',
#      'last_name': 'Keskiner',
#      'permalink': 'eser-keskiner'}},
#    {'is_past': True,
#     'title': 'CEO',
#     'person': {'first_name': 'Erik',
#      'last_name': 'Engstrom',
#      'permalink': 'erik-engstrom'}},
#    {'is_past': True,
#     'title': 'Author: Understanding Your Users',
#     'person': {'first_name': 'Catherine',
#      'last_name': 'Courage',
#      'permalink': 'catherine-courage'}},
#    {'is_past': True,
#     'title': 'QA / Intranet Design',
#     'person': {'first_name': 'Dan',
#      'last_name': 'Chilton',
#      'permalink': 'dan-chilton'}}],
#   'competitions': [],
#   'providerships': [],
#   'total_money_raised': '$0',
#   'funding_rounds': [],
#   'investments': [],
#   'acquisition': None,
#   'acquisitions': [{'price_amount': None,
#     'price_currency_code': 'USD',
#     'term_code': None,
#     'source_url': 'http://www.elsevier.com/wps/find/authored_newsitem.cws_home/companynews05_01179',
#     'source_description': 'Elsevier Acquires Professional Development Software, Inc., Provider of "Software for Nurses" Online Learning Education',
#     'acquired_year': 2009,
#     'acquired_month': 4,
#     'acquired_day': 7,
#     'company': {'name': 'Professional Development Software',
#      'permalink': 'professional-development-software'}},
#    {'price_amount': None,
#     'price_currency_code': 'USD',
#     'term_code': None,
#     'source_url': 'http://techcrunch.com/2010/06/10/elsevier-acquires-semantic-technology-software-company-collexis/',
#     'source_description': 'Elsevier Acquires Semantic Technology Software Company Collexis',
#     'acquired_year': 2010,
#     'acquired_month': 6,
#     'acquired_day': 10,
#     'company': {'name': 'Collexis', 'permalink': 'collexis'}},
#    {'price_amount': None,
#     'price_currency_code': 'USD',
#     'term_code': None,
#     'source_url': 'http://www.prnewswire.com/news-releases/elsevier-acquires-fisterracom-an-e-clinical-reference-solution-for-spanish-primary-care-professionals-121489704.html',
#     'source_description': 'Elsevier Acquires Fisterra.Com, an E-Clinical Reference Solution for Spanish Primary Care Professionals',
#     'acquired_year': 2011,
#     'acquired_month': 5,
#     'acquired_day': 9,
#     'company': {'name': 'Fisterra.com', 'permalink': 'fisterra-com'}},
#    {'price_amount': None,
#     'price_currency_code': 'USD',
#     'term_code': None,
#     'source_url': 'http://www.elsevier.com/about/press-releases/corporate/elsevier-acquires-knovel,-provider-of-web-based-productivity-application-for-the-engineering-community',
#     'source_description': 'Elsevier Acquires Knovel, Provider of Web-based Productivity Application for the Engineering Community',
#     'acquired_year': 2013,
#     'acquired_month': 1,
#     'acquired_day': 7,
#     'company': {'name': 'Knovel', 'permalink': 'knovel'}},
#    {'price_amount': None,
#     'price_currency_code': 'USD',
#     'term_code': None,
#     'source_url': 'http://techcrunch.com/2013/04/08/confirmed-elsevier-has-bought-mendeley-for-69m-100m-to-expand-open-social-education-data-efforts/',
#     'source_description': 'Elsevier Has Bought Mendeley For $69M-$100M To Expand Its Open, Social Education Data Efforts',
#     'acquired_year': 2013,
#     'acquired_month': 4,
#     'acquired_day': 8,
#     'company': {'name': 'Mendeley', 'permalink': 'mendeley'}}],
#   'offices': [{'description': '',
#     'address1': '',
#     'address2': '',
#     'zip_code': '',
#     'city': 'Amsterdam',
#     'state_code': None,
#     'country_code': 'NLD',
#     'latitude': 52.3738007,
#     'longitude': 4.8909347}],
#   'milestones': [],
#   'ipo': None,
#   'video_embeds': [],
#   'screenshots': [],
#   'external_links': [],
#   'partners': []}]

# %%
def getLocation(companies):
    location =[]
    for i in range(len(companies['offices'])):
        longitude = companies['offices'][i]['longitude']
        latitude = companies['offices'][i]['latitude']
        loc = {
            'type':'Point',
            'coordinates':[longitude, latitude]
        }
        location.append(loc)
    return location

# %%
for cp in comp:
    value = {"$set": {'location':getLocation(cp)}}
    coll.update_one(cp, value)

# %%
comp[0]['location'][0]
# Out:
# {'type': 'Point', 'coordinates': [4.8948623, 52.3745228]}
