# %%
import requests
import json
import sys
import os
from dotenv import load_dotenv
load_dotenv()
import pandas as pd

# %%
def requestyelp(business):
    yelp_api_key = os.getenv("YELP_API_KEY")
    if not yelp_api_key:
        raise ValueError("No key provided")
    else:
        print("The key provided is: ", yelp_api_key[0:5])

    url='https://api.yelp.com/v3/businesses/search'
    headers = {'Authorization': 'Bearer %s' % yelp_api_key}

    info = []
    for offset in range(0, 1000, 50):
        params = {'limit': 50,'term':business,'location':'new york','offset': offset, 'radius':5000}
        req=requests.get(url, params=params, headers=headers)

        if req.status_code == 200:
                info += req.json()['businesses']
        elif req.status_code == 400:
                print('400 Bad Request')
                break
                      
    print('The status code is {}'.format(req.status_code))
    
    return info

# %%
#json.loads(req.text)

starbucks = requestyelp("starbucks")
starbucks[0]
# Out:
# The key provided is:  zPUE-
# The status code is 200
# {'id': 'xAvwjM0F5LN9g3yFsk9e0w',
#  'alias': 'starbucks-brooklyn-78',
#  'name': 'Starbucks',
#  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/aTZv043RR8uGZX8U2k6rpg/o.jpg',
#  'is_closed': False,
#  'url': 'https://www.yelp.com/biz/starbucks-brooklyn-78?adjust_creative=Pv4KgwVPErnaJnrLXRjn5g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Pv4KgwVPErnaJnrLXRjn5g',
#  'review_count': 9,
#  'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#  'rating': 4.0,
#  'coordinates': {'latitude': 40.702818, 'longitude': -73.993666},
#  'transactions': [],
#  'price': '$$',
#  'location': {'address1': '11 Old Fulton St.',
#   'address2': '',
#   'address3': None,
#   'city': 'Brooklyn',
#   'zip_code': '11201',
#   'country': 'US',
#   'state': 'NY',
#   'display_address': ['11 Old Fulton St.', 'Brooklyn, NY 11201']},
#  'phone': '+19176857717',
#  'display_phone': '(917) 685-7717',
#  'distance': 296.84014710793184}

# %%
print(len(starbucks))
# Out:
# 1000

# %%
def tabla(company):
    info = []
    for i in company:
        venues={ 
            'name': i['name'],
            'categories': i['alias'],
            'city': i['location']['city'],
            'geolocation': {'type': 'Point', 'coordinates':[i['coordinates']['longitude'],i['coordinates']['latitude']]}                    }
        info.append(venues)
    company_info = pd.DataFrame(info)
    return company_info

# %%
starbucks_df = tabla(starbucks)
starbucks_df.head(50)
# Out:
#                  name                    categories      city  \
# 0           Starbucks         starbucks-brooklyn-78  Brooklyn
# 1           Starbucks         starbucks-brooklyn-21  Brooklyn
# 2           Starbucks        starbucks-new-york-524  New York
# 3           Starbucks        starbucks-new-york-217  New York
# 4           Starbucks        starbucks-new-york-567  New York
# 5           Starbucks        starbucks-new-york-290  New York
# 6           Starbucks        starbucks-new-york-381  New York
# 7           Starbucks         starbucks-brooklyn-17  Brooklyn
# 8           Starbucks        starbucks-new-york-346  New York
# 9           Starbucks        starbucks-new-york-506  New York
# 10          Starbucks        starbucks-new-york-395  New York
# 11          Starbucks        starbucks-new-york-214  New York
# 12          Starbucks        starbucks-new-york-404  New York
# 13          Starbucks        starbucks-new-york-477  New York
# 14          Starbucks        starbucks-new-york-229  New York
# 15          Starbucks        starbucks-new-york-264  New York
# 16          Starbucks          starbucks-brooklyn-6  Brooklyn
# 17          Starbucks        starbucks-new-york-436  New York
# 18          Starbucks        starbucks-new-york-143  New York
# 19          Starbucks        starbucks-new-york-131  New York
# 20          Starbucks        starbucks-new-york-295  New York
# 21          Starbucks         starbucks-brooklyn-14  Brooklyn
# 22          Starbucks        starbucks-new-york-345  New York
# 23          Starbucks        starbucks-new-york-278  New York
# 24          Starbucks         starbucks-brooklyn-40  Brooklyn
# 25          Starbucks        starbucks-new-york-434  New York
# 26          Starbucks        starbucks-new-york-128  New York
# 27          Starbucks        starbucks-new-york-574  New York
# 28          Starbucks        starbucks-new-york-511  New York
# 29          Starbucks        starbucks-new-york-560  New York
# 30          Starbucks         starbucks-brooklyn-32  Brooklyn
# 31          Starbucks        starbucks-new-york-189  New York
# 32          Starbucks        starbucks-new-york-428  New York
# 33          Starbucks        starbucks-new-york-575  New York
# 34          Starbucks        starbucks-new-york-215  New York
# 35          Starbucks        starbucks-new-york-537  New York
# 36          Starbucks        starbucks-new-york-380  New York
# 37          Starbucks        starbucks-new-york-111  New York
# 38          Starbucks        starbucks-new-york-510  New York
# 39          Starbucks         starbucks-brooklyn-69  Brooklyn
# 40          Starbucks         starbucks-brooklyn-76  Brooklyn
# 41          Starbucks        starbucks-new-york-294  New York
# 42          Starbucks        starbucks-new-york-387  New York
# 43          Starbucks         starbucks-brooklyn-73  Brooklyn
# 44          Starbucks         starbucks-brooklyn-16  Brooklyn
# 45          Starbucks        starbucks-new-york-417  New York
# 46          Starbucks        starbucks-new-york-553  New York
# 47          Starbucks         starbucks-brooklyn-77  Brooklyn
# 48  Starbucks Reserve  starbucks-reserve-new-york-4  New York
# 49          Starbucks         starbucks-brooklyn-50  Brooklyn
#
#                                           geolocation
# 0   {'type': 'Point', 'coordinates': [-73.993666, ...
# 1   {'type': 'Point', 'coordinates': [-73.99080629...
# 2   {'type': 'Point', 'coordinates': [-74.000916, ...
# 3   {'type': 'Point', 'coordinates': [-74.004971, ...
# 4   {'type': 'Point', 'coordinates': [-74.006685, ...
# 5   {'type': 'Point', 'coordinates': [-74.007159, ...
# 6   {'type': 'Point', 'coordinates': [-74.007387, ...
# 7   {'type': 'Point', 'coordinates': [-73.993978, ...
# 8   {'type': 'Point', 'coordinates': [-74.008696, ...
# 9   {'type': 'Point', 'coordinates': [-74.009001, ...
# 10  {'type': 'Point', 'coordinates': [-74.00673000...
# 11  {'type': 'Point', 'coordinates': [-74.00799, 4...
# 12  {'type': 'Point', 'coordinates': [-74.009313, ...
# 13  {'type': 'Point', 'coordinates': [-74.008533, ...
# 14  {'type': 'Point', 'coordinates': [-74.003125, ...
# 15  {'type': 'Point', 'coordinates': [-74.008202, ...
# 16  {'type': 'Point', 'coordinates': [-73.9867893,...
# 17  {'type': 'Point', 'coordinates': [-74.010976, ...
# 18  {'type': 'Point', 'coordinates': [-74.01133, 4...
# 19  {'type': 'Point', 'coordinates': [-74.005956, ...
# 20  {'type': 'Point', 'coordinates': [-74.011055, ...
# 21  {'type': 'Point', 'coordinates': [-73.991201, ...
# 22  {'type': 'Point', 'coordinates': [-74.010363, ...
# 23  {'type': 'Point', 'coordinates': [-73.999961, ...
# 24  {'type': 'Point', 'coordinates': [-73.982911, ...
# 25  {'type': 'Point', 'coordinates': [-74.012051, ...
# 26  {'type': 'Point', 'coordinates': [-74.009077, ...
# 27  {'type': 'Point', 'coordinates': [-74.011793, ...
# 28  {'type': 'Point', 'coordinates': [-74.01087, 4...
# 29  {'type': 'Point', 'coordinates': [-74.012733, ...
# 30  {'type': 'Point', 'coordinates': [-73.988548, ...
# 31  {'type': 'Point', 'coordinates': [-74.0130866,...
# 32  {'type': 'Point', 'coordinates': [-73.989977, ...
# 33  {'type': 'Point', 'coordinates': [-74.013011, ...
# 34  {'type': 'Point', 'coordinates': [-74.002524, ...
# 35  {'type': 'Point', 'coordinates': [-73.99913, 4...
# 36  {'type': 'Point', 'coordinates': [-74.009003, ...
# 37  {'type': 'Point', 'coordinates': [-74.014093, ...
# 38  {'type': 'Point', 'coordinates': [-74.014155, ...
# 39  {'type': 'Point', 'coordinates': [-73.984355, ...
# 40  {'type': 'Point', 'coordinates': [-73.98632603...
# 41  {'type': 'Point', 'coordinates': [-74.007305, ...
# 42  {'type': 'Point', 'coordinates': [-74.004979, ...
# 43  {'type': 'Point', 'coordinates': [-73.98254, 4...
# 44  {'type': 'Point', 'coordinates': [-73.992748, ...
# 45  {'type': 'Point', 'coordinates': [-74.015373, ...
# 46  {'type': 'Point', 'coordinates': [-73.997942, ...
# 47  {'type': 'Point', 'coordinates': [-73.98563, 4...
# 48  {'type': 'Point', 'coordinates': [-74.015465, ...
# 49  {'type': 'Point', 'coordinates': [-73.980887, ...

# %%
starbucks_df = starbucks_df[['Starbucks' in x for x in starbucks_df['name']]]
starbucks_df
# Out:
#           name              categories       city  \
# 0    Starbucks   starbucks-brooklyn-78   Brooklyn
# 1    Starbucks   starbucks-brooklyn-21   Brooklyn
# 2    Starbucks  starbucks-new-york-524   New York
# 3    Starbucks  starbucks-new-york-217   New York
# 4    Starbucks  starbucks-new-york-567   New York
# ..         ...                     ...        ...
# 254  Starbucks  starbucks-new-york-499   New York
# 255  Starbucks     starbucks-sunnyside  Sunnyside
# 256  Starbucks  starbucks-new-york-480   New York
# 257  Starbucks  starbucks-new-york-351   New York
# 258  Starbucks  starbucks-new-york-354   New York
#
#                                            geolocation
# 0    {'type': 'Point', 'coordinates': [-73.993666, ...
# 1    {'type': 'Point', 'coordinates': [-73.99080629...
# 2    {'type': 'Point', 'coordinates': [-74.000916, ...
# 3    {'type': 'Point', 'coordinates': [-74.004971, ...
# 4    {'type': 'Point', 'coordinates': [-74.006685, ...
# ..                                                 ...
# 254  {'type': 'Point', 'coordinates': [-73.979878, ...
# 255  {'type': 'Point', 'coordinates': [-73.9182384,...
# 256  {'type': 'Point', 'coordinates': [-73.984146, ...
# 257  {'type': 'Point', 'coordinates': [-73.954675, ...
# 258  {'type': 'Point', 'coordinates': [-73.956935, ...
#
# [259 rows x 4 columns]

# %%
starbucks_df.to_json('./starbucks1_api.json', orient='records')

# %%
restaurants = requestyelp("vegan")
restaurants[0]
# Out:
# The key provided is:  zPUE-
# The status code is 200
# {'id': 'XipQLDbyTl5tsLlyzAWzug',
#  'alias': 'jajaja-new-york',
#  'name': 'Jajaja',
#  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/6HT76TsvGr6XtRVzBi4S_g/o.jpg',
#  'is_closed': False,
#  'url': 'https://www.yelp.com/biz/jajaja-new-york?adjust_creative=Pv4KgwVPErnaJnrLXRjn5g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Pv4KgwVPErnaJnrLXRjn5g',
#  'review_count': 852,
#  'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#   {'alias': 'vegan', 'title': 'Vegan'},
#   {'alias': 'bars', 'title': 'Bars'}],
#  'rating': 4.5,
#  'coordinates': {'latitude': 40.7141530317142, 'longitude': -73.9904247969389},
#  'transactions': ['pickup', 'restaurant_reservation', 'delivery'],
#  'price': '$$',
#  'location': {'address1': '162 E Broadway',
#   'address2': '',
#   'address3': None,
#   'city': 'New York',
#   'zip_code': '10002',
#   'country': 'US',
#   'state': 'NY',
#   'display_address': ['162 E Broadway', 'New York, NY 10002']},
#  'phone': '+16468835453',
#  'display_phone': '(646) 883-5453',
#  'distance': 1021.7274074140097}

# %%
restaurant_df = tabla(restaurants)
restaurant_df.head(50)
# Out:
#                                                  name  \
# 0                                              Jajaja
# 1                                      Petisco Vegano
# 2                                          Spicy Moon
# 3                                                XYST
# 4                                              Jajaja
# 5                                            by CHLOE
# 6                                 Urban Vegan Kitchen
# 7                                     Divya's Kitchen
# 8                                             Blossom
# 9                                            Ladybird
# 10                             Happy Zoe Vegan Bakery
# 11                                         Dirt Candy
# 12                                       Greedi Vegan
# 13                                Patty Wagon Express
# 14                                    Rip’s Malt Shop
# 15                                       Le Botaniste
# 16                                       Avant Garden
# 17                                          GLUR Thai
# 18                                         Red Bamboo
# 19                                         Honeybee’s
# 20                                         Vegan Love
# 21                                Franchia Vegan Cafe
# 22                                    Rip's Malt Shop
# 23                            Peacefood Cafe Downtown
# 24                                        Jungle Cafe
# 25                                     Orchard Grocer
# 26  Original Buddha Bodai Kosher Vegetarian Restau...
# 27                                          Bar Verde
# 28                                      Copper Branch
# 29                                        Sacred Chow
# 30                                        Double Zero
# 31                                  Bar Velo Brooklyn
# 32                                                Nix
# 33                                     American Vegan
# 34                                 The Cinnamon Snail
# 35                                       Bali Kitchen
# 36                               Govinda's Vegetarian
# 37                                     Artistic Pizza
# 38                                 Superiority Burger
# 39                                           by CHLOE
# 40                                  Delice & Sarrasin
# 41                                   Marty's V Burger
# 42                                              VSPOT
# 43                                         Noodlelove
# 44                                          V 4 Vegan
# 45                                     Black Flamingo
# 46                                   Vegan Food Court
# 47                                       Ital Kitchen
# 48                                           Riverdel
# 49                                    Yeah Dawg Vegan
#
#                                            categories      city  \
# 0                                     jajaja-new-york  New York
# 1                             petisco-vegano-new-york  New York
# 2                                 spicy-moon-new-york  New York
# 3                                     xyst-new-york-2  New York
# 4                                   jajaja-new-york-4  New York
# 5                                by-chloe-new-york-32  New York
# 6                        urban-vegan-kitchen-new-york  New York
# 7                             divyas-kitchen-new-york  New York
# 8                                  blossom-new-york-3  New York
# 9                                   ladybird-new-york  New York
# 10                    happy-zoe-vegan-bakery-brooklyn  Brooklyn
# 11                              dirt-candy-new-york-2  New York
# 12                            greedi-vegan-brooklyn-7  Brooklyn
# 13                       patty-wagon-express-brooklyn  Brooklyn
# 14                           rip-s-malt-shop-new-york  New York
# 15                            le-botaniste-new-york-4  New York
# 16                              avant-garden-new-york  New York
# 17                                 glur-thai-new-york  New York
# 18                                red-bamboo-new-york  New York
# 19                                honeybee-s-new-york  New York
# 20                              vegan-love-new-york-2  New York
# 21                       franchia-vegan-cafe-new-york  New York
# 22                            rips-malt-shop-brooklyn  Brooklyn
# 23                   peacefood-cafe-downtown-new-york  New York
# 24                             jungle-cafe-brooklyn-2  Brooklyn
# 25                            orchard-grocer-new-york  New York
# 26  original-buddha-bodai-kosher-vegetarian-restau...  New York
# 27                                 bar-verde-new-york  New York
# 28                           copper-branch-new-york-2  New York
# 29                               sacred-chow-new-york  New York
# 30                               double-zero-new-york  New York
# 31                         bar-velo-brooklyn-brooklyn  Brooklyn
# 32                                       nix-new-york  New York
# 33                          american-vegan-brooklyn-2  Brooklyn
# 34                      the-cinnamon-snail-new-york-7  New York
# 35                            bali-kitchen-new-york-2  New York
# 36                       govindas-vegetarian-brooklyn  Brooklyn
# 37                            artistic-pizza-new-york  New York
# 38                        superiority-burger-new-york  New York
# 39                               by-chloe-new-york-31  New York
# 40                       delice-and-sarrasin-new-york  New York
# 41                           martys-v-burger-new-york  New York
# 42                                     vspot-brooklyn  Brooklyn
# 43                              noodlelove-new-york-2  New York
# 44                               v-4-vegan-new-york-5  New York
# 45                            black-flamingo-brooklyn  Brooklyn
# 46                          vegan-food-court-new-york  New York
# 47                            ital-kitchen-brooklyn-2  Brooklyn
# 48                                  riverdel-brooklyn  Brooklyn
# 49                           yeah-dawg-vegan-brooklyn  Brooklyn
#
#                                           geolocation
# 0   {'type': 'Point', 'coordinates': [-73.99042479...
# 1   {'type': 'Point', 'coordinates': [-73.988805, ...
# 2   {'type': 'Point', 'coordinates': [-73.98722, 4...
# 3   {'type': 'Point', 'coordinates': [-73.99444, 4...
# 4   {'type': 'Point', 'coordinates': [-74.00455, 4...
# 5   {'type': 'Point', 'coordinates': [-74.001021, ...
# 6   {'type': 'Point', 'coordinates': [-74.00368, 4...
# 7   {'type': 'Point', 'coordinates': [-73.98849, 4...
# 8   {'type': 'Point', 'coordinates': [-74.002365, ...
# 9   {'type': 'Point', 'coordinates': [-73.98477127...
# 10  {'type': 'Point', 'coordinates': [-73.949646, ...
# 11  {'type': 'Point', 'coordinates': [-73.9907183,...
# 12  {'type': 'Point', 'coordinates': [-73.9523247,...
# 13  {'type': 'Point', 'coordinates': [-73.9693814,...
# 14  {'type': 'Point', 'coordinates': [-74.000412, ...
# 15  {'type': 'Point', 'coordinates': [-74.0002028,...
# 16  {'type': 'Point', 'coordinates': [-73.98402, 4...
# 17  {'type': 'Point', 'coordinates': [-73.99665, 4...
# 18  {'type': 'Point', 'coordinates': [-74.00035464...
# 19  {'type': 'Point', 'coordinates': [-73.98403, 4...
# 20  {'type': 'Point', 'coordinates': [-73.98325360...
# 21  {'type': 'Point', 'coordinates': [-73.98124234...
# 22  {'type': 'Point', 'coordinates': [-73.9719, 40...
# 23  {'type': 'Point', 'coordinates': [-73.99297513...
# 24  {'type': 'Point', 'coordinates': [-73.954885, ...
# 25  {'type': 'Point', 'coordinates': [-73.990187, ...
# 26  {'type': 'Point', 'coordinates': [-73.9989484,...
# 27  {'type': 'Point', 'coordinates': [-73.98973613...
# 28  {'type': 'Point', 'coordinates': [-74.00134, 4...
# 29  {'type': 'Point', 'coordinates': [-73.99944, 4...
# 30  {'type': 'Point', 'coordinates': [-73.9896645,...
# 31  {'type': 'Point', 'coordinates': [-73.954429, ...
# 32  {'type': 'Point', 'coordinates': [-73.99359, 4...
# 33  {'type': 'Point', 'coordinates': [-73.96896, 4...
# 34  {'type': 'Point', 'coordinates': [-73.99196867...
# 35  {'type': 'Point', 'coordinates': [-73.987617, ...
# 36  {'type': 'Point', 'coordinates': [-73.98241, 4...
# 37  {'type': 'Point', 'coordinates': [-74.00044, 4...
# 38  {'type': 'Point', 'coordinates': [-73.98355, 4...
# 39  {'type': 'Point', 'coordinates': [-73.99292, 4...
# 40  {'type': 'Point', 'coordinates': [-74.00065, 4...
# 41  {'type': 'Point', 'coordinates': [-73.98257100...
# 42  {'type': 'Point', 'coordinates': [-73.9795, 40...
# 43  {'type': 'Point', 'coordinates': [-73.9956235,...
# 44  {'type': 'Point', 'coordinates': [-73.98727, 4...
# 45  {'type': 'Point', 'coordinates': [-73.953916, ...
# 46  {'type': 'Point', 'coordinates': [-73.989209, ...
# 47  {'type': 'Point', 'coordinates': [-73.95804, 4...
# 48  {'type': 'Point', 'coordinates': [-73.96307, 4...
# 49  {'type': 'Point', 'coordinates': [-73.94766235...

# %%
restaurant_df = restaurant_df[['New York' in x for x in restaurant_df['city']]]
restaurant_df
# Out:
#                   name                    categories      city  \
# 0               Jajaja               jajaja-new-york  New York
# 1       Petisco Vegano       petisco-vegano-new-york  New York
# 2           Spicy Moon           spicy-moon-new-york  New York
# 3                 XYST               xyst-new-york-2  New York
# 4               Jajaja             jajaja-new-york-4  New York
# ..                 ...                           ...       ...
# 993              Shuka              shuka-new-york-3  New York
# 995         Bareburger         bareburger-new-york-4  New York
# 996    Cheong Fun Cart      cheong-fun-cart-new-york  New York
# 997          Del Posto            del-posto-new-york  New York
# 999  DOMODOMO New York  domodomo-new-york-new-york-2  New York
#
#                                            geolocation
# 0    {'type': 'Point', 'coordinates': [-73.99042479...
# 1    {'type': 'Point', 'coordinates': [-73.988805, ...
# 2    {'type': 'Point', 'coordinates': [-73.98722, 4...
# 3    {'type': 'Point', 'coordinates': [-73.99444, 4...
# 4    {'type': 'Point', 'coordinates': [-74.00455, 4...
# ..                                                 ...
# 993  {'type': 'Point', 'coordinates': [-74.00283, 4...
# 995  {'type': 'Point', 'coordinates': [-73.97814, 4...
# 996  {'type': 'Point', 'coordinates': [-73.99637368...
# 997  {'type': 'Point', 'coordinates': [-74.00753301...
# 999  {'type': 'Point', 'coordinates': [-74.00167, 4...
#
# [619 rows x 4 columns]

# %%
restaurant_df.to_json('./vegan1_api.json', orient='records')
