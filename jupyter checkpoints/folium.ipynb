# %%
from pymongo import MongoClient
import folium
from folium import plugins
import pandas as pd
import json


# %matplotlib inline

# %%
def connectCollection(database, collection):
    client = MongoClient()
    db = client[database]
    coll = db[collection]
    return db, coll

# %%
db, coll = connectCollection('companies','starbucks1')
print(coll.json)

starbucks = list(coll.find({"name":"Starbucks"}))
starbucks

print(len(starbucks))
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'companies'), 'starbucks1.json')
# 254

# %%
db, coll = connectCollection('companies','mycompanies')
print(coll.json)

mycompanies = list(coll.find({"name":{"$exists":True}}))
mycompanies
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'companies'), 'mycompanies.json')
# [{'_id': ObjectId('5dd425544a23bde4b53373b9'),
#   'name': 'Magento',
#   'category_code': 'tech',
#   'founded_year': 2010,
#   'total_money_raised': '$22.5 M',
#   'geolocation': {'type': 'Point', 'coordinates': [-118.243425, 34.052187]}},
#  {'_id': ObjectId('5dd425544a23bde4b53373ba'),
#   'name': 'GENWI',
#   'category_code': 'tech',
#   'founded_year': 2010,
#   'total_money_raised': '$7.1 M',
#   'geolocation': {'type': 'Point', 'coordinates': [-111.9035, 33.8171]}},
#  {'_id': ObjectId('5dd425544a23bde4b53373bb'),
#   'name': 'Pixsta',
#   'category_code': 'tech',
#   'founded_year': 2010,
#   'total_money_raised': '£3 M',
#   'geolocation': {'type': 'Point', 'coordinates': [-0.208979, 51.51819]}},
#  {'_id': ObjectId('5dd425544a23bde4b53373bc'),
#   'name': 'PeekYou',
#   'category_code': 'tech',
#   'founded_year': 2012,
#   'total_money_raised': '$1.83 M',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.985506, 40.757929]}},
#  {'_id': ObjectId('5dd425544a23bde4b53373bd'),
#   'name': 'Fixya',
#   'category_code': 'tech',
#   'founded_year': 2013,
#   'total_money_raised': '$8 M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.323895, 37.566879]}},
#  {'_id': ObjectId('5dd425544a23bde4b53373be'),
#   'name': 'Titan Gaming',
#   'category_code': 'tech',
#   'founded_year': 2010,
#   'total_money_raised': '$1 M',
#   'geolocation': {'type': 'Point', 'coordinates': [-113.515769, 53.544711]}},
#  {'_id': ObjectId('5dd425544a23bde4b53373bf'),
#   'name': 'BrandYourself',
#   'category_code': 'tech',
#   'founded_year': 2009,
#   'total_money_raised': '$1.5 M',
#   'geolocation': {'type': 'Point', 'coordinates': [-71.24762, 42.275263]}},
#  {'_id': ObjectId('5dd425544a23bde4b53373c0'),
#   'name': 'Integrate',
#   'category_code': 'tech',
#   'founded_year': 2010,
#   'total_money_raised': '$34.8 M',
#   'geolocation': {'type': 'Point', 'coordinates': [-74.0353787, 40.7481039]}},
#  {'_id': ObjectId('5dd425544a23bde4b53373c1'),
#   'name': 'Prezi',
#   'category_code': 'tech',
#   'founded_year': 2009,
#   'total_money_raised': '$14.3 M',
#   'geolocation': {'type': 'Point', 'coordinates': [19.059078, 47.490346]}},
#  {'_id': ObjectId('5dd425544a23bde4b53373c2'),
#   'name': 'Burt',
#   'category_code': 'tech',
#   'founded_year': 2009,
#   'total_money_raised': '$3.5 M',
#   'geolocation': {'type': 'Point', 'coordinates': [18.036587, 59.337864]}},
#  {'_id': ObjectId('5dd425544a23bde4b53373c3'),
#   'name': 'Inuvo',
#   'category_code': 'tech',
#   'founded_year': 2009,
#   'total_money_raised': '$4.2 M',
#   'geolocation': {'type': 'Point', 'coordinates': [-82.702449, 27.913011]}},
#  {'_id': ObjectId('5dd425544a23bde4b53373c4'),
#   'name': 'Burt',
#   'category_code': 'tech',
#   'founded_year': 2009,
#   'total_money_raised': '$3.5 M',
#   'geolocation': {'type': 'Point', 'coordinates': [18.036587, 59.337864]}},
#  {'_id': ObjectId('5dd425544a23bde4b53373c5'),
#   'name': 'Integrate',
#   'category_code': 'tech',
#   'founded_year': 2010,
#   'total_money_raised': '$34.8 M',
#   'geolocation': {'type': 'Point', 'coordinates': [-74.0353787, 40.7481039]}},
#  {'_id': ObjectId('5dd425544a23bde4b53373c6'),
#   'name': 'Social Gaming Network',
#   'category_code': 'tech',
#   'founded_year': 2011,
#   'total_money_raised': '$17.1 M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.161523, 37.446823]}},
#  {'_id': ObjectId('5dd425544a23bde4b53373c7'),
#   'name': 'ScaleMP',
#   'category_code': 'tech',
#   'founded_year': 2009,
#   'total_money_raised': '$8 M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.0385792, 37.3229727]}},
#  {'_id': ObjectId('5dd425544a23bde4b53373c8'),
#   'name': 'isocket',
#   'category_code': 'tech',
#   'founded_year': 2009,
#   'total_money_raised': '$10.1 M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.321836, 37.55909]}},
#  {'_id': ObjectId('5dd425544a23bde4b53373c9'),
#   'name': 'Yipit',
#   'category_code': 'tech',
#   'founded_year': 2010,
#   'total_money_raised': '$7.55 M',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.987764, 40.744618]}},
#  {'_id': ObjectId('5dd425544a23bde4b53373ca'),
#   'name': 'Skydeck',
#   'category_code': 'tech',
#   'founded_year': 2012,
#   'total_money_raised': '$4 M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.3254705, 37.5645375]}},
#  {'_id': ObjectId('5dd425544a23bde4b53373cb'),
#   'name': 'VisualOn',
#   'category_code': 'tech',
#   'founded_year': 2011,
#   'total_money_raised': '$3.1 M',
#   'geolocation': {'type': 'Point', 'coordinates': [-121.955879, 37.270518]}},
#  {'_id': ObjectId('5dd425544a23bde4b53373cc'),
#   'name': 'Meez',
#   'category_code': 'tech',
#   'founded_year': 2009,
#   'total_money_raised': '$10.2 M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.397582, 37.785271]}},
#  {'_id': ObjectId('5dd425544a23bde4b53373cd'),
#   'name': 'Heyzap',
#   'category_code': 'tech',
#   'founded_year': 2009,
#   'total_money_raised': '$7.97 M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.4041485, 37.7905538]}},
#  {'_id': ObjectId('5dd425544a23bde4b53373ce'),
#   'name': 'Social Gaming Network',
#   'category_code': 'tech',
#   'founded_year': 2011,
#   'total_money_raised': '$17.1 M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.161523, 37.446823]}},
#  {'_id': ObjectId('5dd425544a23bde4b53373cf'),
#   'name': 'Formspring',
#   'category_code': 'tech',
#   'founded_year': 2009,
#   'total_money_raised': '$14.3 M',
#   'geolocation': {'type': 'Point', 'coordinates': [-86.0547016, 39.9052263]}},
#  {'_id': ObjectId('5dd425544a23bde4b53373d0'),
#   'name': 'RazorGator',
#   'category_code': 'tech',
#   'founded_year': 2011,
#   'total_money_raised': '$58.8 M',
#   'geolocation': {'type': 'Point', 'coordinates': [-118.445243, 34.047312]}},
#  {'_id': ObjectId('5dd425544a23bde4b53373d1'),
#   'name': 'Inuvo',
#   'category_code': 'tech',
#   'founded_year': 2009,
#   'total_money_raised': '$4.2 M',
#   'geolocation': {'type': 'Point', 'coordinates': [-82.702449, 27.913011]}},
#  {'_id': ObjectId('5dd425544a23bde4b53373d2'),
#   'name': 'Tinychat',
#   'category_code': 'tech',
#   'founded_year': 2009,
#   'total_money_raised': '$1.5 M',
#   'geolocation': {'type': 'Point', 'coordinates': [-72.5196907, 42.3756409]}},
#  {'_id': ObjectId('5dd425544a23bde4b53373d3'),
#   'name': 'BASH Gaming',
#   'category_code': 'tech',
#   'founded_year': 2010,
#   'total_money_raised': '$1 M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.0780632, 37.5561712]}},
#  {'_id': ObjectId('5dd425544a23bde4b53373d4'),
#   'name': 'AppNeta',
#   'category_code': 'tech',
#   'founded_year': 2010,
#   'total_money_raised': '$55.8 M',
#   'geolocation': {'type': 'Point', 'coordinates': [-71.24756, 42.318138]}},
#  {'_id': ObjectId('5dd425544a23bde4b53373d5'),
#   'name': 'BASH Gaming',
#   'category_code': 'tech',
#   'founded_year': 2010,
#   'total_money_raised': '$1 M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.0780632, 37.5561712]}},
#  {'_id': ObjectId('5dd425544a23bde4b53373d6'),
#   'name': 'AppZero',
#   'category_code': 'tech',
#   'founded_year': 2009,
#   'total_money_raised': '$15.1 M',
#   'geolocation': {'type': 'Point', 'coordinates': [-71.1469003, 42.6751888]}},
#  {'_id': ObjectId('5dd425544a23bde4b53373d7'),
#   'name': 'MyLikes',
#   'category_code': 'tech',
#   'founded_year': 2010,
#   'total_money_raised': '$6.23 M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.408914, 37.777995]}},
#  {'_id': ObjectId('5dd425544a23bde4b53373d8'),
#   'name': 'Cognitive Match',
#   'category_code': 'tech',
#   'founded_year': 2009,
#   'total_money_raised': '$10.2 M',
#   'geolocation': {'type': 'Point', 'coordinates': [-0.0936688, 51.5119418]}},
#  {'_id': ObjectId('5dd425544a23bde4b53373d9'),
#   'name': 'Cognitive Match',
#   'category_code': 'tech',
#   'founded_year': 2009,
#   'total_money_raised': '$10.2 M',
#   'geolocation': {'type': 'Point', 'coordinates': [-0.0936688, 51.5119418]}},
#  {'_id': ObjectId('5dd425544a23bde4b53373da'),
#   'name': 'Shutl',
#   'category_code': 'tech',
#   'founded_year': 2009,
#   'total_money_raised': '£7.66 M',
#   'geolocation': {'type': 'Point', 'coordinates': [-0.1020265, 51.5196135]}},
#  {'_id': ObjectId('5dd425544a23bde4b53373db'),
#   'name': 'Cognitive Match',
#   'category_code': 'tech',
#   'founded_year': 2009,
#   'total_money_raised': '$10.2 M',
#   'geolocation': {'type': 'Point', 'coordinates': [-0.0936688, 51.5119418]}},
#  {'_id': ObjectId('5dd425544a23bde4b53373dc'),
#   'name': 'Simulmedia',
#   'category_code': 'tech',
#   'founded_year': 2009,
#   'total_money_raised': '$57.3 M',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.994797, 40.727216]}},
#  {'_id': ObjectId('5dd425544a23bde4b53373dd'),
#   'name': 'CoTweet',
#   'category_code': 'tech',
#   'founded_year': 2009,
#   'total_money_raised': '$1.1 M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.3764714, 37.7405936]}},
#  {'_id': ObjectId('5dd425544a23bde4b53373de'),
#   'name': 'Cognitive Match',
#   'category_code': 'tech',
#   'founded_year': 2009,
#   'total_money_raised': '$10.2 M',
#   'geolocation': {'type': 'Point', 'coordinates': [-0.0936688, 51.5119418]}},
#  {'_id': ObjectId('5dd425544a23bde4b53373df'),
#   'name': 'Tongal',
#   'category_code': 'tech',
#   'founded_year': 2009,
#   'total_money_raised': '$16 M',
#   'geolocation': {'type': 'Point', 'coordinates': [-118.489748, 34.007112]}},
#  {'_id': ObjectId('5dd425544a23bde4b53373e0'),
#   'name': 'The Resumator',
#   'category_code': 'tech',
#   'founded_year': 2009,
#   'total_money_raised': '$2.98 M',
#   'geolocation': {'type': 'Point', 'coordinates': [-80.001933, 40.438423]}},
#  {'_id': ObjectId('5dd425544a23bde4b53373e1'),
#   'name': 'Shareaholic',
#   'category_code': 'tech',
#   'founded_year': 2009,
#   'total_money_raised': '$5.46 M',
#   'geolocation': {'type': 'Point', 'coordinates': [-71.1032591, 42.3647559]}},
#  {'_id': ObjectId('5dd425544a23bde4b53373e2'),
#   'name': 'Vaultive',
#   'category_code': 'tech',
#   'founded_year': 2009,
#   'total_money_raised': '$11 M',
#   'geolocation': {'type': 'Point', 'coordinates': [-74.011114, 40.707954]}},
#  {'_id': ObjectId('5dd425544a23bde4b53373e3'),
#   'name': 'Gravity',
#   'category_code': 'tech',
#   'founded_year': 2009,
#   'total_money_raised': '$20.6 M',
#   'geolocation': {'type': 'Point', 'coordinates': [-118.489681, 34.007967]}},
#  {'_id': ObjectId('5dd425544a23bde4b53373e4'),
#   'name': 'Brandsclub',
#   'category_code': 'tech',
#   'founded_year': 2009,
#   'total_money_raised': '$17 M',
#   'geolocation': {'type': 'Point', 'coordinates': [-46.6388182, -23.5489433]}},
#  {'_id': ObjectId('5dd425544a23bde4b53373e5'),
#   'name': 'GameChanger Media',
#   'category_code': 'tech',
#   'founded_year': 2009,
#   'total_money_raised': '$3.64 M',
#   'geolocation': {'type': 'Point', 'coordinates': [-74.0136605, 40.7078343]}},
#  {'_id': ObjectId('5dd425544a23bde4b53373e6'),
#   'name': 'ClickFuel',
#   'category_code': 'tech',
#   'founded_year': 2009,
#   'total_money_raised': '$9 M',
#   'geolocation': {'type': 'Point', 'coordinates': [-71.0680027, 42.3406534]}},
#  {'_id': ObjectId('5dd425544a23bde4b53373e7'),
#   'name': 'Chartbeat',
#   'category_code': 'tech',
#   'founded_year': 2009,
#   'total_money_raised': '$14.5 M',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.990967, 40.73343]}},
#  {'_id': ObjectId('5dd425544a23bde4b53373e8'),
#   'name': 'VistaGen Therapeutics',
#   'category_code': 'tech',
#   'founded_year': 2013,
#   'total_money_raised': '$41.3 M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.3843489, 37.6656476]}},
#  {'_id': ObjectId('5dd425544a23bde4b53373e9'),
#   'name': 'Althea Systems',
#   'category_code': 'tech',
#   'founded_year': 2009,
#   'total_money_raised': '$3 M',
#   'geolocation': {'type': 'Point', 'coordinates': [77.6136847, 12.9349604]}},
#  {'_id': ObjectId('5dd425544a23bde4b53373ea'),
#   'name': 'Solix Biofuels',
#   'category_code': 'tech',
#   'founded_year': 2009,
#   'total_money_raised': '$68.8 M',
#   'geolocation': {'type': 'Point', 'coordinates': [-105.0766501, 40.5932386]}},
#  {'_id': ObjectId('5dd425544a23bde4b53373eb'),
#   'name': 'Clovis Oncology',
#   'category_code': 'tech',
#   'founded_year': 2009,
#   'total_money_raised': '$357 M',
#   'geolocation': {'type': 'Point', 'coordinates': [-105.259041, 40.026]}},
#  {'_id': ObjectId('5dd425544a23bde4b53373ec'),
#   'name': 'Ykone',
#   'category_code': 'tech',
#   'founded_year': 2009,
#   'total_money_raised': '€1.5 M',
#   'geolocation': {'type': 'Point', 'coordinates': [2.3509871, 48.8566667]}},
#  {'_id': ObjectId('5dd425544a23bde4b53373ed'),
#   'name': 'Layar',
#   'category_code': 'tech',
#   'founded_year': 2009,
#   'total_money_raised': '$13.4 M',
#   'geolocation': {'type': 'Point', 'coordinates': [4.8928722, 52.3657578]}},
#  {'_id': ObjectId('5dd425544a23bde4b53373ee'),
#   'name': 'Applied Genetics Technologies Corporation',
#   'category_code': 'tech',
#   'founded_year': 2009,
#   'total_money_raised': '$78.1 M',
#   'geolocation': {'type': 'Point', 'coordinates': [-82.4768036, 29.7847641]}},
#  {'_id': ObjectId('5dd425544a23bde4b53373ef'),
#   'name': 'Z2Live',
#   'category_code': 'tech',
#   'founded_year': 2009,
#   'total_money_raised': '$6.5 M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.3399782, 47.6103008]}},
#  {'_id': ObjectId('5dd425544a23bde4b53373f0'),
#   'name': 'ticketea',
#   'category_code': 'tech',
#   'founded_year': 2010,
#   'total_money_raised': '$5.73 M',
#   'geolocation': {'type': 'Point', 'coordinates': [-3.7061764, 40.4455155]}},
#  {'_id': ObjectId('5dd425544a23bde4b53373f1'),
#   'name': 'Teambox',
#   'category_code': 'tech',
#   'founded_year': 2009,
#   'total_money_raised': '$6.75 M',
#   'geolocation': {'type': 'Point', 'coordinates': [2.1920231, 41.4063346]}},
#  {'_id': ObjectId('5dd425544a23bde4b53373f2'),
#   'name': 'Delphi',
#   'category_code': 'tech',
#   'founded_year': 2009,
#   'total_money_raised': '$8 M',
#   'geolocation': {'type': 'Point', 'coordinates': [-83.16134, 42.603532]}},
#  {'_id': ObjectId('5dd425544a23bde4b53373f3'),
#   'name': 'Tiny Speck',
#   'category_code': 'tech',
#   'founded_year': 2009,
#   'total_money_raised': '$17.2 M',
#   'geolocation': {'type': 'Point', 'coordinates': [-123.109217, 49.2824551]}},
#  {'_id': ObjectId('5dd425544a23bde4b53373f4'),
#   'name': 'Getyoo',
#   'category_code': 'tech',
#   'founded_year': 2009,
#   'total_money_raised': '€1.13 M',
#   'geolocation': {'type': 'Point', 'coordinates': [4.3464721, 50.83997]}},
#  {'_id': ObjectId('5dd425544a23bde4b53373f5'),
#   'name': 'ChallengePost',
#   'category_code': 'tech',
#   'founded_year': 2009,
#   'total_money_raised': '$4.6 M',
#   'geolocation': {'type': 'Point', 'coordinates': [-74.00717, 40.7408042]}}]

# %%
db, coll = connectCollection('companies', 'vegan1')

vegan = list(coll.find({"name": {"$exists": True}}))
vegan
# Out:
# [{'_id': ObjectId('5dd7bf25aac549526eb77df8'),
#   'name': "Divya's Kitchen",
#   'categories': 'divyas-kitchen-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.98849, 40.72378]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77df9'),
#   'name': 'Blossom',
#   'categories': 'blossom-new-york-3',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-74.002365, 40.745513]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77dfa'),
#   'name': 'Ladybird',
#   'categories': 'ladybird-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point',
#    'coordinates': [-73.9847712789, 40.7267693111]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77dfb'),
#   'name': 'XYST',
#   'categories': 'xyst-new-york-2',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.99444, 40.73874]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77dfc'),
#   'name': 'Dirt Candy',
#   'categories': 'dirt-candy-new-york-2',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.9907183, 40.7179075]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77dfd'),
#   'name': 'Le Botaniste',
#   'categories': 'le-botaniste-new-york-4',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-74.0002028, 40.7204278]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77dfe'),
#   'name': 'Rip’s Malt Shop',
#   'categories': 'rip-s-malt-shop-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-74.000412, 40.735666]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77dff'),
#   'name': 'Avant Garden',
#   'categories': 'avant-garden-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.98402, 40.7261499]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e00'),
#   'name': 'GLUR Thai',
#   'categories': 'glur-thai-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.99665, 40.74121]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e01'),
#   'name': 'Red Bamboo',
#   'categories': 'red-bamboo-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point',
#    'coordinates': [-74.0003546456, 40.7313183708]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e02'),
#   'name': 'Honeybee’s',
#   'categories': 'honeybee-s-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.98403, 40.72563]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e03'),
#   'name': 'Petisco Vegano',
#   'categories': 'petisco-vegano-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.988805, 40.713928]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e04'),
#   'name': 'Peacefood Cafe Downtown',
#   'categories': 'peacefood-cafe-downtown-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point',
#    'coordinates': [-73.9929751334, 40.7332670925]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e05'),
#   'name': 'Spicy Moon',
#   'categories': 'spicy-moon-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.98722, 40.72674]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e06'),
#   'name': 'Orchard Grocer',
#   'categories': 'orchard-grocer-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.990187, 40.717744]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e07'),
#   'name': 'Original Buddha Bodai Kosher Vegetarian Restaurant',
#   'categories': 'original-buddha-bodai-kosher-vegetarian-restaurant-new-york-3',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.9989484, 40.7138543]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e08'),
#   'name': 'Franchia Vegan Cafe',
#   'categories': 'franchia-vegan-cafe-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point',
#    'coordinates': [-73.9812423409, 40.7474712051]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e09'),
#   'name': 'Bar Verde',
#   'categories': 'bar-verde-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point',
#    'coordinates': [-73.9897361398, 40.7260849061]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e0a'),
#   'name': 'Copper Branch',
#   'categories': 'copper-branch-new-york-2',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-74.00134, 40.72935]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e0b'),
#   'name': 'Sacred Chow',
#   'categories': 'sacred-chow-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.99944, 40.72959]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e0c'),
#   'name': 'Jajaja',
#   'categories': 'jajaja-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point',
#    'coordinates': [-73.9904247969, 40.7141530317]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e0d'),
#   'name': 'Jajaja',
#   'categories': 'jajaja-new-york-4',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-74.00455, 40.72979]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e0e'),
#   'name': 'Urban Vegan Kitchen',
#   'categories': 'urban-vegan-kitchen-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-74.00368, 40.7302]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e0f'),
#   'name': 'Vegan Love',
#   'categories': 'vegan-love-new-york-2',
#   'city': 'New York',
#   'geolocation': {'type': 'Point',
#    'coordinates': [-73.9832536018, 40.7285173652]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e10'),
#   'name': 'Double Zero',
#   'categories': 'double-zero-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.9896645, 40.7261288]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e11'),
#   'name': 'Nix',
#   'categories': 'nix-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.99359, 40.73323]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e12'),
#   'name': 'The Cinnamon Snail',
#   'categories': 'the-cinnamon-snail-new-york-7',
#   'city': 'New York',
#   'geolocation': {'type': 'Point',
#    'coordinates': [-73.9919686739, 40.750320537]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e13'),
#   'name': 'Bali Kitchen',
#   'categories': 'bali-kitchen-new-york-2',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.987617, 40.725371]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e14'),
#   'name': 'Artistic Pizza',
#   'categories': 'artistic-pizza-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-74.00044, 40.73069]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e15'),
#   'name': 'Superiority Burger',
#   'categories': 'superiority-burger-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.98355, 40.72739]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e16'),
#   'name': 'by CHLOE',
#   'categories': 'by-chloe-new-york-31',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.99292, 40.74197]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e17'),
#   'name': 'Delice & Sarrasin',
#   'categories': 'delice-and-sarrasin-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-74.00065, 40.73377]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e18'),
#   'name': 'by CHLOE',
#   'categories': 'by-chloe-new-york-32',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-74.001021, 40.729219]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e19'),
#   'name': "Marty's V Burger",
#   'categories': 'martys-v-burger-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point',
#    'coordinates': [-73.9825710043, 40.7418634775]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e1a'),
#   'name': 'The Cinnamon Snail',
#   'categories': 'the-cinnamon-snail-new-york-2',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.992215, 40.75007]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e1b'),
#   'name': 'A.T.M. Vegan Deli',
#   'categories': 'a-t-m-vegan-deli-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.95825, 40.7217]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e1c'),
#   'name': 'Cocoron',
#   'categories': 'cocoron-new-york-3',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.99305, 40.72031]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e1d'),
#   'name': 'Plant Food + Wine',
#   'categories': 'plant-food-wine-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.989751, 40.7261989]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e1e'),
#   'name': 'ABCV',
#   'categories': 'abcv-new-york-2',
#   'city': 'New York',
#   'geolocation': {'type': 'Point',
#    'coordinates': [-73.98887401, 40.7379039813]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e1f'),
#   'name': 'Kajitsu',
#   'categories': 'kajitsu-new-york-3',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.9777215, 40.7498614]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e20'),
#   'name': 'May Kaidee East Broadway',
#   'categories': 'may-kaidee-east-broadway-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point',
#    'coordinates': [-73.9874649793, 40.7140637]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e21'),
#   'name': 'Terri',
#   'categories': 'terri-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.9923, 40.74252]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e22'),
#   'name': 'Beyond Sushi',
#   'categories': 'beyond-sushi-new-york-9',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-74.00766, 40.706433]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e23'),
#   'name': 'Areppas Soho',
#   'categories': 'areppas-soho-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.99713, 40.72185]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e24'),
#   'name': 'Dun-Well Doughnuts',
#   'categories': 'dun-well-doughnuts-new-york-3',
#   'city': 'New York',
#   'geolocation': {'type': 'Point',
#    'coordinates': [-73.9846205124, 40.7271946946]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e25'),
#   'name': 'Bodhi Kosher Vegetarian Restaurant',
#   'categories': 'bodhi-kosher-vegetarian-restaurant-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.99931, 40.71641]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e26'),
#   'name': 'by CHLOE',
#   'categories': 'by-chloe-new-york-30',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-74.00418, 40.70657]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e27'),
#   'name': 'Quantum Leap',
#   'categories': 'quantum-leap-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.99874, 40.72916]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e28'),
#   'name': 'Confectionery',
#   'categories': 'confectionery-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.98305, 40.72732]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e29'),
#   'name': 'Hangawi',
#   'categories': 'hangawi-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.984662, 40.746737]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e2a'),
#   'name': 'VLife',
#   'categories': 'vlife-new-york-2',
#   'city': 'New York',
#   'geolocation': {'type': 'Point',
#    'coordinates': [-73.9929176564, 40.7481116799]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e2b'),
#   'name': 'Body & Soul Bakeshop',
#   'categories': 'body-and-soul-bakeshop-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.99099, 40.73644]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e2c'),
#   'name': 'westbourne',
#   'categories': 'westbourne-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-74.00193, 40.72687]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e2d'),
#   'name': 'Noodlelove',
#   'categories': 'noodlelove-new-york-2',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.9956235, 40.7209]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e2e'),
#   'name': 'Jisu Vegetarian',
#   'categories': 'jisu-vegetarian-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.995209, 40.716084]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e2f'),
#   'name': 'V 4 Vegan',
#   'categories': 'v-4-vegan-new-york-5',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.98727, 40.72881]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e30'),
#   'name': 'Mother of Pearl',
#   'categories': 'mother-of-pearl-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.98412, 40.72566]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e31'),
#   'name': 'Vegan Food Court',
#   'categories': 'vegan-food-court-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.989209, 40.729113]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e32'),
#   'name': 'Beyond Sushi',
#   'categories': 'beyond-sushi-new-york-7',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.98588, 40.7329]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e33'),
#   'name': 'by CHLOE',
#   'categories': 'by-chloe-new-york-29',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.99711, 40.72273]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e34'),
#   'name': 'Jell & Chill',
#   'categories': 'jell-and-chill-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point',
#    'coordinates': [-73.9846681058, 40.726435034]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e35'),
#   'name': 'Spring Cafe',
#   'categories': 'spring-cafe-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-74.00021, 40.71792]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e36'),
#   'name': 'Goemon',
#   'categories': 'goemon-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.99509, 40.72083]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e37'),
#   'name': 'Mulberry & Vine',
#   'categories': 'mulberry-and-vine-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-74.0101342, 40.7150751]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e38'),
#   'name': 'Beyond Sushi',
#   'categories': 'beyond-sushi-new-york-10',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.99629, 40.72216]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e39'),
#   'name': 'The Little Beet',
#   'categories': 'the-little-beet-new-york-6',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.9887, 40.74393]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e3a'),
#   'name': 'Go Zen',
#   'categories': 'go-zen-new-york-3',
#   'city': 'New York',
#   'geolocation': {'type': 'Point',
#    'coordinates': [-74.0005102638, 40.7313398845]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e3b'),
#   'name': 'Riverdel',
#   'categories': 'riverdel-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.988119, 40.718296]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e3c'),
#   'name': 'Farmacy Kitchen',
#   'categories': 'farmacy-kitchen-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point',
#    'coordinates': [-73.9972921315, 40.7221148939]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e3d'),
#   'name': 'Atlas Cafe & Bakery',
#   'categories': 'atlas-cafe-and-bakery-new-york-2',
#   'city': 'New York',
#   'geolocation': {'type': 'Point',
#    'coordinates': [-73.9894421246, 40.7265019578]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e3e'),
#   'name': 'Taim West Village',
#   'categories': 'taim-west-village-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point',
#    'coordinates': [-74.0019588366, 40.7360023763]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e3f'),
#   'name': 'Nish Nush',
#   'categories': 'nish-nush-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-74.007695, 40.715688]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e40'),
#   'name': 'Souen',
#   'categories': 'souen-new-york-2',
#   'city': 'New York',
#   'geolocation': {'type': 'Point',
#    'coordinates': [-73.9873733521, 40.7266693115]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e41'),
#   'name': 'Ramen Ishida',
#   'categories': 'ramen-ishida-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.98834, 40.71959]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e42'),
#   'name': 'Bombay Sandwich Co.',
#   'categories': 'bombay-sandwich-co-new-york-40',
#   'city': 'New York',
#   'geolocation': {'type': 'Point',
#    'coordinates': [-73.9903596202, 40.7450715522]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e43'),
#   'name': 'Hotel Tortuga',
#   'categories': 'hotel-tortuga-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.98545, 40.73239]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e44'),
#   'name': "The Butcher's Daughter",
#   'categories': 'the-butchers-daughter-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point',
#    'coordinates': [-73.9948451276, 40.7207068627]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e45'),
#   'name': 'Nefista Vegan Kofteh',
#   'categories': 'nefista-vegan-kofteh-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-74.000735, 40.729414]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e46'),
#   'name': 'BoCaphe',
#   'categories': 'bocaphê-new-york-3',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.997557, 40.722046]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e47'),
#   'name': 'Rawsome Treats',
#   'categories': 'rawsome-treats-new-york-12',
#   'city': 'New York',
#   'geolocation': {'type': 'Point',
#    'coordinates': [-73.9886739485, 40.7208686955]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e48'),
#   'name': "Erin McKenna's Bakery",
#   'categories': 'erin-mckennas-bakery-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.989604, 40.718132]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e49'),
#   'name': 'Zizi',
#   'categories': 'zizi-new-york-3',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-74.00002, 40.74293]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e4a'),
#   'name': 'Bareburger',
#   'categories': 'bareburger-new-york-30',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.999819, 40.742943]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e4b'),
#   'name': 'Village Natural',
#   'categories': 'village-natural-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-74.000244, 40.735622]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e4c'),
#   'name': 'Areppas',
#   'categories': 'areppas-new-york-3',
#   'city': 'New York',
#   'geolocation': {'type': 'Point',
#    'coordinates': [-73.9971453122, 40.7218576658]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e4d'),
#   'name': 'Vegetarian Dim Sum House',
#   'categories': 'vegetarian-dim-sum-house-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.998161, 40.715023]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e4e'),
#   'name': 'Jivamuktea Café',
#   'categories': 'jivamuktea-café-new-york-2',
#   'city': 'New York',
#   'geolocation': {'type': 'Point',
#    'coordinates': [-73.9910125948, 40.7343094009]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e4f'),
#   'name': 'Nish Nush',
#   'categories': 'nish-nush-new-york-5',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-74.007949, 40.709472]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e50'),
#   'name': 'Green Symphony',
#   'categories': 'green-symphony-new-york-2',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.9968139, 40.738083]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e51'),
#   'name': 'Cafe Bari',
#   'categories': 'cafe-bari-new-york-3',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-74.00173, 40.71909]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e52'),
#   'name': 'Skinny Buddha Organic Kitchen',
#   'categories': 'skinny-buddha-organic-kitchen-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.98991, 40.72379]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e53'),
#   'name': 'The Organic Grill',
#   'categories': 'the-organic-grill-new-york-130',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.98578, 40.72737]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e54'),
#   'name': 'Mille Nonne',
#   'categories': 'mille-nonne-new-york-2',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.9882738, 40.7180351]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e55'),
#   'name': 'Beyond Sushi',
#   'categories': 'beyond-sushi-new-york-8',
#   'city': 'New York',
#   'geolocation': {'type': 'Point',
#    'coordinates': [-74.0066324868, 40.7424675259]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e56'),
#   'name': "LuAnne's Wild Ginger All-Asian Vegan",
#   'categories': 'luannes-wild-ginger-all-asian-vegan-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.9964956, 40.7204631]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e57'),
#   'name': "Jack's Stir Brew Coffee",
#   'categories': 'jacks-stir-brew-coffee-new-york-2',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-74.002356, 40.707633]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e58'),
#   'name': 'Caravan of Dreams',
#   'categories': 'caravan-of-dreams-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point',
#    'coordinates': [-73.9856490472, 40.7261704451]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e59'),
#   'name': 'Cocoron:  Gluten-Free noodle Pop up',
#   'categories': 'cocoron-gluten-free-noodle-pop-up-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.99086, 40.71909]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e5a'),
#   'name': 'Malibu Farm',
#   'categories': 'malibu-farm-new-york-2',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-74.001749, 40.705925]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e5b'),
#   'name': 'Zyara NY',
#   'categories': 'zyara-ny-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.98507, 40.71964]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e5c'),
#   'name': 'Sunshine - Hummus',
#   'categories': 'sunshine-hummus-new-york-2',
#   'city': 'New York',
#   'geolocation': {'type': 'Point',
#    'coordinates': [-73.9934370902, 40.731080654]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e5d'),
#   'name': 'Baodega',
#   'categories': 'baodega-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.99178, 40.74014]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e5e'),
#   'name': 'Golden Diner',
#   'categories': 'golden-diner-new-york-2',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.994, 40.71244]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e5f'),
#   'name': 'Citizens of Bleecker',
#   'categories': 'citizens-of-bleecker-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.999672, 40.728603]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e60'),
#   'name': 'Mulberry & Vine',
#   'categories': 'mulberry-and-vine-new-york-2',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.99035, 40.74527]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e61'),
#   'name': 'Gohan-ya',
#   'categories': 'gohan-ya-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point',
#    'coordinates': [-73.9917685837, 40.7150115073]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e62'),
#   'name': 'Magic Mix Juicery',
#   'categories': 'magic-mix-juicery-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-74.006735, 40.70961]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e63'),
#   'name': 'Night Music',
#   'categories': 'night-music-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.98454, 40.72658]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e64'),
#   'name': 'Zooba',
#   'categories': 'zooba-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point',
#    'coordinates': [-73.9973096922, 40.7212932028]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e65'),
#   'name': 'Holy Cow',
#   'categories': 'holy-cow-new-york-4',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.98792, 40.74588]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e66'),
#   'name': 'NAYA',
#   'categories': 'naya-new-york-20',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-74.0114968, 40.7023139]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e67'),
#   'name': 'Square Pizza',
#   'categories': 'square-pizza-new-york-2',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.98468, 40.72008]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e68'),
#   'name': 'Hole in the Wall',
#   'categories': 'hole-in-the-wall-new-york-2',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-74.00563, 40.70837]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e69'),
#   'name': "Ribalta Mo'",
#   'categories': 'ribalta-mo-new-york-2',
#   'city': 'New York',
#   'geolocation': {'type': 'Point',
#    'coordinates': [-73.9918599852, 40.7503255563]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e6a'),
#   'name': 'Ananda',
#   'categories': 'ananda-new-york-4',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.999147, 40.728724]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e6b'),
#   'name': 'M Noodle Shop',
#   'categories': 'm-noodle-shop-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.988659, 40.720348]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e6c'),
#   'name': 'Mint Kitchen',
#   'categories': 'mint-kitchen-new-york-5',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.99301, 40.73345]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e6d'),
#   'name': 'Little Beet Table',
#   'categories': 'little-beet-table-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.98545, 40.74116]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e6e'),
#   'name': 'Vish Hummus & Happiness',
#   'categories': 'vish-hummus-and-happiness-new-york-3',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.96197, 40.71684]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e6f'),
#   'name': 'Three Times',
#   'categories': 'three-times-new-york-2',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.99104, 40.73285]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e70'),
#   'name': 'NY Dosas',
#   'categories': 'ny-dosas-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point',
#    'coordinates': [-73.9986377977, 40.730838608]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e71'),
#   'name': 'YunShang Rice Noodle House',
#   'categories': 'yunshang-rice-noodle-house-new-york-4',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.99765, 40.71525]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e72'),
#   'name': 'Lifethyme',
#   'categories': 'lifethyme-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.99906, 40.73378]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e73'),
#   'name': 'OM Juice Bar',
#   'categories': 'om-juice-bar-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.98621, 40.74355]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e74'),
#   'name': 'Ahimsa Garden',
#   'categories': 'ahimsa-garden-new-york-4',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.98319, 40.72849]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e75'),
#   'name': 'Sunflower Cafe',
#   'categories': 'sunflower-cafe-new-york-5',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.98219, 40.7399]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e76'),
#   'name': 'TONCHIN NEW YORK',
#   'categories': 'tonchin-new-york-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.9844951, 40.7502727]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e77'),
#   'name': 'Green Gorilla Kitchen',
#   'categories': 'green-gorilla-kitchen-new-york-2',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.9912, 40.73587]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e78'),
#   'name': 'Sabai Thai Restaurant',
#   'categories': 'sabai-thai-restaurant-new-york-3',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.98365, 40.74422]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e79'),
#   'name': 'Dill & Parsley',
#   'categories': 'dill-and-parsley-new-york-8',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-74.006831, 40.706162]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e7a'),
#   'name': 'POST',
#   'categories': 'post-new-york-2',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.98302, 40.72298]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e7b'),
#   'name': 'Lekka Burger',
#   'categories': 'lekka-burger-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-74.0105318, 40.715151]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e7c'),
#   'name': 'Flowers Cafe',
#   'categories': 'flowers-cafe-new-york-3',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.989697, 40.716256]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e7d'),
#   'name': "The Butcher's Daughter",
#   'categories': 'the-butchers-daughter-new-york-2',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-74.00606, 40.73639]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e7e'),
#   'name': 'Chama Mama',
#   'categories': 'chama-mama-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.99892, 40.7384]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e7f'),
#   'name': 'The Wild Son',
#   'categories': 'the-wild-son-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-74.00836, 40.74073]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e80'),
#   'name': 'Bive',
#   'categories': 'bive-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.99018, 40.71844]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e81'),
#   'name': 'Awash Ethiopian Restaurant',
#   'categories': 'awash-ethiopian-restaurant-new-york-3',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.98682, 40.72658]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e82'),
#   'name': 'Spring Natural',
#   'categories': 'spring-natural-new-york-2',
#   'city': 'New York',
#   'geolocation': {'type': 'Point',
#    'coordinates': [-73.9969895035, 40.7212623954]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e83'),
#   'name': 'Westville West',
#   'categories': 'westville-west-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-74.0041863, 40.7340046]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e84'),
#   'name': 'CHALAIT',
#   'categories': 'chalait-new-york-9',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-74.00788, 40.7287]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e85'),
#   'name': 'Smør',
#   'categories': 'smør-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.98153, 40.72927]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e86'),
#   'name': "Yonah Schimmel's Knish Bakery",
#   'categories': 'yonah-schimmels-knish-bakery-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.99015, 40.7231]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e87'),
#   'name': 'King David Tacos',
#   'categories': 'king-david-tacos-new-york-2',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-74.01043, 40.703458]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e88'),
#   'name': 'Dig Inn',
#   'categories': 'dig-inn-new-york-12',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-74.011963, 40.7042826]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e89'),
#   'name': 'May-Wah Vegetarian Market',
#   'categories': 'may-wah-vegetarian-market-new-york-2',
#   'city': 'New York',
#   'geolocation': {'type': 'Point',
#    'coordinates': [-73.9990171031, 40.718663748]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e8a'),
#   'name': 'The Little Beet',
#   'categories': 'the-little-beet-new-york-5',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.9921676, 40.7499719]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e8b'),
#   'name': 'Westville - Wall St',
#   'categories': 'westville-wall-st-new-york-5',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-74.00652, 40.70478]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e8c'),
#   'name': 'Good Thanks NYC',
#   'categories': 'good-thanks-nyc-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.98952, 40.71972]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e8d'),
#   'name': 'Two Hands',
#   'categories': 'two-hands-new-york-4',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-74.00547, 40.71782]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e8e'),
#   'name': 'LoveMama',
#   'categories': 'lovemama-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.9860613, 40.7303859]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e8f'),
#   'name': 'The MasalaWala',
#   'categories': 'the-masalawala-new-york-2',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.98666, 40.72191]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e90'),
#   'name': 'Cocoron',
#   'categories': 'cocoron-new-york-2',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.9953191, 40.7207236]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e91'),
#   'name': 'Alimama',
#   'categories': 'alimama-new-york-3',
#   'city': 'New York',
#   'geolocation': {'type': 'Point',
#    'coordinates': [-73.9992850858, 40.7158626896]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e92'),
#   'name': 'Hey Chong Qing Noodle',
#   'categories': 'hey-chong-qing-noodle-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.9817453223, 40.74045]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e93'),
#   'name': "Eva's Kitchen",
#   'categories': 'evas-kitchen-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.997152, 40.732822]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e94'),
#   'name': 'Black Cat LES',
#   'categories': 'black-cat-les-new-york-2',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.984509, 40.719129]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e95'),
#   'name': 'Seed + Mill',
#   'categories': 'seed-mill-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-74.0056454, 40.7420723]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e96'),
#   'name': 'Springbone Kitchen',
#   'categories': 'springbone-kitchen-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.99932, 40.72986]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e97'),
#   'name': 'El Vez Burrito Bar',
#   'categories': 'el-vez-burrito-bar-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point',
#    'coordinates': [-74.015635, 40.7147356377]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e98'),
#   'name': 'Maestro Pasta',
#   'categories': 'maestro-pasta-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-74.007891, 40.709329]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e99'),
#   'name': 'The Dumpling Shop',
#   'categories': 'the-dumpling-shop-new-york-2',
#   'city': 'New York',
#   'geolocation': {'type': 'Point',
#    'coordinates': [-73.9877445929, 40.728198064]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e9a'),
#   'name': 'Three Jewels Cafe',
#   'categories': 'three-jewels-cafe-new-york-2',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.99119, 40.72624]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e9b'),
#   'name': 'Sweets by CHLOE',
#   'categories': 'sweets-by-chloe-new-york-8',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-74.00098, 40.729191]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e9c'),
#   'name': 'Tonii’s Fresh Rice Noodle',
#   'categories': 'tonii-s-fresh-rice-noodle-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.99899, 40.71572]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e9d'),
#   'name': 'Tofu Tofu',
#   'categories': 'tofu-tofu-new-york-5',
#   'city': 'New York',
#   'geolocation': {'type': 'Point',
#    'coordinates': [-73.9954301342, 40.7176299521]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e9e'),
#   'name': 'Osteria 57',
#   'categories': 'osteria-57-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.99786, 40.73467]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77e9f'),
#   'name': 'Market Crates',
#   'categories': 'market-crates-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.986576, 40.748279]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77ea0'),
#   'name': 'Sakib',
#   'categories': 'sakib-new-york-2',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.962702, 40.712023]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77ea1'),
#   'name': 'Very Fresh Noodles',
#   'categories': 'very-fresh-noodles-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-74.00625, 40.7423387008]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77ea2'),
#   'name': 'Taboonette',
#   'categories': 'taboonette-new-york-2',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-74.00487, 40.72945]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77ea3'),
#   'name': 'Fish Cheeks',
#   'categories': 'fish-cheeks-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.9927, 40.7258]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77ea4'),
#   'name': 'sweetgreen',
#   'categories': 'sweetgreen-new-york-4',
#   'city': 'New York',
#   'geolocation': {'type': 'Point',
#    'coordinates': [-73.9972511652, 40.7210635428]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77ea5'),
#   'name': 'Berber Street Food',
#   'categories': 'berber-street-food-new-york-2',
#   'city': 'New York',
#   'geolocation': {'type': 'Point',
#    'coordinates': [-74.0033399463, 40.7302376195]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77ea6'),
#   'name': 'Society Cafe',
#   'categories': 'society-cafe-new-york-2',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.9965962, 40.7362063]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77ea7'),
#   'name': 'Heavenly Market And Cafe',
#   'categories': 'heavenly-market-and-cafe-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.994, 40.73116]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77ea8'),
#   'name': 'Dr Smood Soho',
#   'categories': 'dr-smood-soho-new-york-2',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-74.0014, 40.72282]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77ea9'),
#   'name': 'Itaewon',
#   'categories': 'itaewon-new-york-2',
#   'city': 'New York',
#   'geolocation': {'type': 'Point',
#    'coordinates': [-73.9867554409, 40.7475125112]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77eaa'),
#   'name': 'Two Boots Pizza - West Village',
#   'categories': 'two-boots-pizza-west-village-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.998279, 40.740009]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77eab'),
#   'name': 'Melt Shop',
#   'categories': 'melt-shop-new-york-7',
#   'city': 'New York',
#   'geolocation': {'type': 'Point',
#    'coordinates': [-74.0065573417, 40.7097319538]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77eac'),
#   'name': 'Bamboo Bites',
#   'categories': 'bamboo-bites-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.9895, 40.71835]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77ead'),
#   'name': 'Arepa Factory',
#   'categories': 'arepa-factory-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.98268, 40.72748]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77eae'),
#   'name': 'Thai Direct Bowls',
#   'categories': 'thai-direct-bowls-new-york-4',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.98311, 40.72688]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77eaf'),
#   'name': 'Banter',
#   'categories': 'banter-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-74.0010999, 40.72787]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77eb0'),
#   'name': 'indi thai',
#   'categories': 'indi-thai-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.99035, 40.71983]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77eb1'),
#   'name': 'Cathédrale Restaurant',
#   'categories': 'cathédrale-restaurant-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.98951, 40.7316]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77eb2'),
#   'name': 'Zest Ramen',
#   'categories': 'zest-ramen-new-york-8',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.99186, 40.71816]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77eb3'),
#   'name': 'Areppas',
#   'categories': 'areppas-new-york-2',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.985479, 40.740077]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77eb4'),
#   'name': 'nonono',
#   'categories': 'nonono-new-york-6',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.98499, 40.74545]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77eb5'),
#   'name': 'Kaffe 1668',
#   'categories': 'kaffe-1668-new-york-3',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-74.00968, 40.72092]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77eb6'),
#   'name': 'Fong On',
#   'categories': 'fong-on-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.9937, 40.71417]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77eb7'),
#   'name': "Pinky's Space",
#   'categories': 'pinkys-space-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.98879, 40.72355]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77eb8'),
#   'name': 'BCD Tofu House',
#   'categories': 'bcd-tofu-house-new-york-3',
#   'city': 'New York',
#   'geolocation': {'type': 'Point',
#    'coordinates': [-73.9862447208, 40.7475036314]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77eb9'),
#   'name': 'Blackbarn Cafe | Bar',
#   'categories': 'blackbarn-cafe-bar-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-74.0064163, 40.7428934]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77eba'),
#   'name': 'The Bean',
#   'categories': 'the-bean-new-york-3',
#   'city': 'New York',
#   'geolocation': {'type': 'Point',
#    'coordinates': [-73.9896519939, 40.7257617915]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77ebb'),
#   'name': 'Cafe Himalaya',
#   'categories': 'cafe-himalaya-new-york-2',
#   'city': 'New York',
#   'geolocation': {'type': 'Point',
#    'coordinates': [-73.9879441221, 40.7232289034]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77ebc'),
#   'name': 'Ginger and Lemongrass',
#   'categories': 'ginger-and-lemongrass-new-york-2',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.98567, 40.71912]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77ebd'),
#   'name': 'Gotan - Tribeca',
#   'categories': 'gotan-tribeca-new-york-2',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-74.006607, 40.719255]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77ebe'),
#   'name': 'Brooklyn Bagel & Coffee Company',
#   'categories': 'brooklyn-bagel-and-coffee-company-new-york-8',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.9932199, 40.73104]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77ebf'),
#   'name': 'Tatsu Ramen',
#   'categories': 'tatsu-ramen-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.98446, 40.72908]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77ec0'),
#   'name': 'Three Times',
#   'categories': 'three-times-new-york-3',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.985209, 40.718271]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77ec1'),
#   'name': "Jack's Wife Freda",
#   'categories': 'jacks-wife-freda-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.99756, 40.72213]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77ec2'),
#   'name': 'Local 92',
#   'categories': 'local-92-new-york-32',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.9885354, 40.726957]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77ec3'),
#   'name': 'Pinks Cantina',
#   'categories': 'pinks-cantina-new-york-4',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.99189, 40.72229]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77ec4'),
#   'name': 'GrandLo Cafe',
#   'categories': 'grandlo-cafe-new-york-3',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.9854576, 40.7168074]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77ec5'),
#   'name': 'Cinnamon Garden',
#   'categories': 'cinnamon-garden-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.9872199, 40.72674]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77ec6'),
#   'name': 'Downtown Bakery Cocina Mexicana',
#   'categories': 'downtown-bakery-cocina-mexicana-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.98711, 40.72543]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77ec7'),
#   'name': 'Cafe Greenpoint',
#   'categories': 'cafe-greenpoint-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.950889, 40.724431]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77ec8'),
#   'name': 'Bonsai Kakigōri',
#   'categories': 'bonsai-kakigōri-new-york-3',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.987934, 40.721372]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77ec9'),
#   'name': 'Cafe 11',
#   'categories': 'cafe-11-new-york-4',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-74.0140703, 40.7052529]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77eca'),
#   'name': 'Michaeli Bakery',
#   'categories': 'michaeli-bakery-new-york-2',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.992054, 40.714349]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77ecb'),
#   'name': "Proto's Pizza",
#   'categories': 'protos-pizza-new-york-9',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.989746, 40.725353]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77ecc'),
#   'name': 'Nami Nori',
#   'categories': 'nami-nori-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-74.003212, 40.730284]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77ecd'),
#   'name': 'NaNa Thai Street',
#   'categories': 'nana-thai-street-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.98854, 40.73954]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77ece'),
#   'name': "Tribeca's Kitchen",
#   'categories': 'tribecas-kitchen-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point',
#    'coordinates': [-74.0072225928, 40.7162705536]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77ecf'),
#   'name': 'Junzi Kitchen',
#   'categories': 'junzi-kitchen-new-york-13',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-74.004978, 40.726138]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77ed0'),
#   'name': 'mochii',
#   'categories': 'mochii-new-york-3',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.98447, 40.72634]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77ed1'),
#   'name': 'Charley St',
#   'categories': 'charley-st-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.99548, 40.72093]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77ed2'),
#   'name': "John's of 12th Street",
#   'categories': 'johns-of-12th-street-new-york-2',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.985502, 40.730685]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb77ed3'),
#   'name': 'Frangos Peri Peri',
# ...
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-74.00972, 40.71432]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb7801a'),
#   'name': "Rizzo's Fine Pizza",
#   'categories': 'rizzos-fine-pizza-new-york-4',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.984456, 40.720852]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb7801b'),
#   'name': 'Seabird',
#   'categories': 'seabird-new-york-2',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-74.0008299, 40.73232]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb7801c'),
#   'name': 'Maman Nomad',
#   'categories': 'maman-nomad-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.99023, 40.74325]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb7801d'),
#   'name': 'Mémé Mediterranean',
#   'categories': 'mémé-mediterranean-new-york-4',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-74.00616, 40.736412]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb7801e'),
#   'name': 'MIGHTY Bowl',
#   'categories': 'mighty-bowl-new-york-2',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-74.00049, 40.72986]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb7801f'),
#   'name': 'Thelewala',
#   'categories': 'thelewala-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-74.00068, 40.72963]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb78020'),
#   'name': 'Nur',
#   'categories': 'nur-new-york-2',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.9888, 40.73854]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb78021'),
#   'name': 'SMARTWICH',
#   'categories': 'smartwich-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.989, 40.73026]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb78022'),
#   'name': 'GST Greenwich Sports Tavern Village',
#   'categories': 'gst-greenwich-sports-tavern-village-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-74.0048, 40.72975]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb78023'),
#   'name': 'Benares',
#   'categories': 'benares-new-york-3',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-74.009209, 40.71415]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb78024'),
#   'name': 'Tokuyama Salon Café',
#   'categories': 'tokuyama-salon-café-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.9802, 40.72399]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb78025'),
#   'name': 'Two Boots East Village',
#   'categories': 'two-boots-east-village-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.98489, 40.72369]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb78026'),
#   'name': 'La Contenta',
#   'categories': 'la-contenta-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.98691, 40.71873]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb78027'),
#   'name': 'Cafe Mogador',
#   'categories': 'cafe-mogador-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point',
#    'coordinates': [-73.9845085144, 40.7272587674]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb78028'),
#   'name': 'Forkright',
#   'categories': 'forkright-new-york-2',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.99379, 40.74634]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb78029'),
#   'name': 'Pommes Frites',
#   'categories': 'pommes-frites-new-york-2',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-74.000152, 40.730022]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb7802a'),
#   'name': 'Niche',
#   'categories': 'niche-new-york-3',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.98518, 40.71786]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb7802b'),
#   'name': 'Mezetto',
#   'categories': 'mezetto-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point',
#    'coordinates': [-73.9889362577, 40.7228863781]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb7802c'),
#   'name': 'Los Tacos No.1',
#   'categories': 'los-tacos-no-1-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-74.0060838, 40.7425547]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb7802d'),
#   'name': "Benny's Burritos",
#   'categories': 'bennys-burritos-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point',
#    'coordinates': [-74.0021237785, 40.7380740387]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb7802e'),
#   'name': 'Som Bo',
#   'categories': 'som-bo-new-york-2',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-74.00136, 40.74192]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb7802f'),
#   'name': 'Natural Frontier Market',
#   'categories': 'natural-frontier-market-new-york-3',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.98218, 40.7396]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb78030'),
#   'name': 'Short Stories',
#   'categories': 'short-stories-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.99144, 40.72671]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb78031'),
#   'name': 'Dos Toros',
#   'categories': 'dos-toros-new-york-23',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-74.01333, 40.70253]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb78032'),
#   'name': 'Westville Bakery',
#   'categories': 'westville-bakery-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.98336, 40.72766]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb78033'),
#   'name': 'Omai',
#   'categories': 'omai-new-york-2',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-74.002563, 40.744289]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb78034'),
#   'name': 'BÀO Tea House',
#   'categories': 'bào-tea-house-new-york-2',
#   'city': 'New York',
#   'geolocation': {'type': 'Point',
#    'coordinates': [-74.0004889567, 40.7312487927]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb78035'),
#   'name': 'Essex Taqueria',
#   'categories': 'essex-taqueria-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.9877989, 40.7197418]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb78036'),
#   'name': 'Juicology Kitchen',
#   'categories': 'juicology-kitchen-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.990384, 40.747727]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb78037'),
#   'name': 'Xe May Sandwich Shop',
#   'categories': 'xe-may-sandwich-shop-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.98493, 40.7272]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb78038'),
#   'name': 'Bessou',
#   'categories': 'bessou-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.992675, 40.725502]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb78039'),
#   'name': 'Van Leeuwen Ice Cream',
#   'categories': 'van-leeuwen-ice-cream-new-york-9',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.996098, 40.721971]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb7803a'),
#   'name': 'Chikarashi',
#   'categories': 'chikarashi-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.99948, 40.71787]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb7803b'),
#   'name': 'Friend of A Farmer',
#   'categories': 'friend-of-a-farmer-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.98677, 40.73695]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb7803c'),
#   'name': 'The Paris Cafe',
#   'categories': 'the-paris-cafe-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-74.00159, 40.70732]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb7803d'),
#   'name': 'Ofrenda',
#   'categories': 'ofrenda-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-74.00242, 40.73391]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb7803e'),
#   'name': 'ilili Box',
#   'categories': 'ilili-box-new-york-5',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-74.00102, 40.71897]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb7803f'),
#   'name': 'Narcissa',
#   'categories': 'narcissa-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point',
#    'coordinates': [-73.9909284947, 40.7279081085]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb78040'),
#   'name': 'Sagaponack Bar & Grill',
#   'categories': 'sagaponack-bar-and-grill-new-york-2',
#   'city': 'New York',
#   'geolocation': {'type': 'Point',
#    'coordinates': [-73.9907836914, 40.7409324646]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb78041'),
#   'name': 'Middle Eats',
#   'categories': 'middle-eats-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.9953, 40.74412]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb78042'),
#   'name': 'The Maze',
#   'categories': 'the-maze-new-york-3',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.9872499, 40.747846]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb78043'),
#   'name': 'The Longshoreman',
#   'categories': 'the-longshoreman-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-74.0027, 40.68472]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb78044'),
#   'name': 'Hao Noodle Chelsea',
#   'categories': 'hao-noodle-chelsea-new-york-7',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-74.00436, 40.7406999]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb78045'),
#   'name': 'Afandi Grill',
#   'categories': 'afandi-grill-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.98493, 40.72842]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb78046'),
#   'name': 'M&J Asian Cuisine',
#   'categories': 'm-and-j-asian-cuisine-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point',
#    'coordinates': [-73.9780369922, 40.7292851718]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb78047'),
#   'name': 'Galata Mediterranean Cuisine',
#   'categories': 'galata-mediterranean-cuisine-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.97753, 40.74531]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb78048'),
#   'name': 'Aurora Soho',
#   'categories': 'aurora-soho-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-74.003199, 40.723543]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb78049'),
#   'name': 'Tu Do Restaurant',
#   'categories': 'tu-do-restaurant-new-york-3',
#   'city': 'New York',
#   'geolocation': {'type': 'Point',
#    'coordinates': [-73.9953305926, 40.7178239198]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb7804a'),
#   'name': 'Umami Burger - Brookfield Place',
#   'categories': 'umami-burger-brookfield-place-new-york-2',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-74.015913, 40.713225]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb7804b'),
#   'name': 'Pho Vietnam',
#   'categories': 'pho-vietnam-new-york-2',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.9944029, 40.717587]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb7804c'),
#   'name': "Molly's Cupcakes",
#   'categories': 'mollys-cupcakes-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-74.00248, 40.73014]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb7804d'),
#   'name': 'sweetgreen',
#   'categories': 'sweetgreen-new-york-13',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-74.008382, 40.705586]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb7804e'),
#   'name': 'Thunder Bun',
#   'categories': 'thunder-bun-new-york-3',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-74.0114968, 40.7023139]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb7804f'),
#   'name': 'Wayla',
#   'categories': 'wayla-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.99275, 40.71828]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb78050'),
#   'name': "Vegan O'Brien Baking Company",
#   'categories': 'vegan-o-brien-baking-company-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-74.00714, 40.71455]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb78051'),
#   'name': 'China Blue',
#   'categories': 'china-blue-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-74.009958, 40.724038]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb78052'),
#   'name': 'Meryienda',
#   'categories': 'meryienda-new-york-2',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-74.0094471, 40.7464969]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb78053'),
#   'name': "Becky's Bites",
#   'categories': 'beckys-bites-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.98423, 40.72624]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb78054'),
#   'name': 'Juice Press',
#   'categories': 'juice-press-new-york-70',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-74.00981, 40.71412]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb78055'),
#   'name': 'Dante',
#   'categories': 'dante-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-74.00165, 40.72879]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb78056'),
#   'name': 'Matchaful',
#   'categories': 'matchaful-new-york-5',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-74.00398, 40.72109]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb78057'),
#   'name': 'Lucid Café',
#   'categories': 'lucid-café-new-york-4',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.97785, 40.74874]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb78058'),
#   'name': 'Hummus Kitchen',
#   'categories': 'hummus-kitchen-new-york-5',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.97983, 40.74367]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb78059'),
#   'name': 'marcellino tratoria & pizzeria',
#   'categories': 'marcellino-tratoria-and-pizzeria-new-york-2',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.99666, 40.72066]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb7805a'),
#   'name': 'The Hummus & Pita',
#   'categories': 'the-hummus-and-pita-new-york-8',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-74.00671, 40.71474]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb7805b'),
#   'name': 'Tings Jamaican Jerk Chicken',
#   'categories': 'tings-jamaican-jerk-chicken-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-74.0061307, 40.7422926]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb7805c'),
#   'name': 'Juice Generation',
#   'categories': 'juice-generation-new-york-9',
#   'city': 'New York',
#   'geolocation': {'type': 'Point',
#    'coordinates': [-73.9969973947, 40.7241123623]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb7805d'),
#   'name': 'Bareburger',
#   'categories': 'bareburger-new-york-4',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.97814, 40.74616]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb7805e'),
#   'name': 'Miznon',
#   'categories': 'miznon-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-74.006206, 40.742575]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb7805f'),
#   'name': 'Shuka',
#   'categories': 'shuka-new-york-3',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-74.00283, 40.72707]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb78060'),
#   'name': 'Cheong Fun Cart',
#   'categories': 'cheong-fun-cart-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point',
#    'coordinates': [-73.9963736857, 40.7176279773]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb78061'),
#   'name': 'Del Posto',
#   'categories': 'del-posto-new-york',
#   'city': 'New York',
#   'geolocation': {'type': 'Point',
#    'coordinates': [-74.0075330133, 40.7434155953]}},
#  {'_id': ObjectId('5dd7bf25aac549526eb78062'),
#   'name': 'DOMODOMO New York',
#   'categories': 'domodomo-new-york-new-york-2',
#   'city': 'New York',
#   'geolocation': {'type': 'Point', 'coordinates': [-74.00167, 40.72803]}}]

# %%
db, coll = connectCollection('companies', 'oldcompanies')

oldcompanies = list(coll.find({"name": {"$exists":True}}))
oldcompanies
# Out:
# [{'_id': ObjectId('5dd5b0ccafee9fc7eb027230'),
#   'name': 'Gizmoz',
#   'category_code': 'web',
#   'founded_year': 2003,
#   'total_money_raised': '$18.1M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.169472, 37.48413]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb027231'),
#   'name': 'Plaxo',
#   'category_code': 'web',
#   'founded_year': 2002,
#   'total_money_raised': '$28.3M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.055197, 37.387845]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb027232'),
#   'name': 'StumbleUpon',
#   'category_code': 'web',
#   'founded_year': 2002,
#   'total_money_raised': '$18.5M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.419204, 37.775196]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb027233'),
#   'name': 'Twitter',
#   'category_code': 'social',
#   'founded_year': 2006,
#   'total_money_raised': '$1.16B',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.4169244, 37.7768052]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb027234'),
#   'name': 'Joost',
#   'category_code': 'games_video',
#   'founded_year': 2006,
#   'total_money_raised': '$45M',
#   'geolocation': {'type': 'Point', 'coordinates': [-74.0094471, 40.7464969]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb027235'),
#   'name': 'Technorati',
#   'category_code': 'advertising',
#   'founded_year': 2002,
#   'total_money_raised': '$32.1M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.393041, 37.779558]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb027236'),
#   'name': 'Powerset',
#   'category_code': 'search',
#   'founded_year': 2006,
#   'total_money_raised': '$22.5M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.395289, 37.778613]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb027237'),
#   'name': 'Facebook',
#   'category_code': 'social',
#   'founded_year': 2004,
#   'total_money_raised': '$2.43B',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.151801, 37.41605]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb027238'),
#   'name': 'Facebook',
#   'category_code': 'social',
#   'founded_year': 2004,
#   'total_money_raised': '$2.43B',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.151801, 37.41605]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb027239'),
#   'name': 'Facebook',
#   'category_code': 'social',
#   'founded_year': 2004,
#   'total_money_raised': '$2.43B',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.151801, 37.41605]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb02723a'),
#   'name': 'Mahalo',
#   'category_code': 'web',
#   'founded_year': 2007,
#   'total_money_raised': '$21M',
#   'geolocation': {'type': 'Point', 'coordinates': [-118.487267, 34.017606]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb02723b'),
#   'name': 'AddThis',
#   'category_code': 'advertising',
#   'founded_year': 2004,
#   'total_money_raised': '$73M',
#   'geolocation': {'type': 'Point', 'coordinates': [-77.245195, 38.926172]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb02723c'),
#   'name': 'Geni',
#   'category_code': 'web',
#   'founded_year': 2006,
#   'total_money_raised': '$16.5M',
#   'geolocation': {'type': 'Point', 'coordinates': [-118.393064, 34.090368]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb02723d'),
#   'name': 'Kyte',
#   'category_code': 'games_video',
#   'founded_year': 2006,
#   'total_money_raised': '$23.4M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.409173, 37.788482]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb02723e'),
#   'name': 'Slacker',
#   'category_code': 'music',
#   'founded_year': 2006,
#   'total_money_raised': '$73.1M',
#   'geolocation': {'type': 'Point', 'coordinates': [-117.081406, 33.022176]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb02723f'),
#   'name': 'Veoh',
#   'category_code': 'games_video',
#   'founded_year': 2004,
#   'total_money_raised': '$69.8M',
#   'geolocation': {'type': 'Point', 'coordinates': [-117.20834, 32.902266]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb027240'),
#   'name': 'eBay',
#   'category_code': 'web',
#   'founded_year': 1995,
#   'total_money_raised': '$6.7M',
#   'geolocation': {'type': 'Point', 'coordinates': [-121.930035, 37.295005]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb027241'),
#   'name': 'AddThis',
#   'category_code': 'advertising',
#   'founded_year': 2004,
#   'total_money_raised': '$73M',
#   'geolocation': {'type': 'Point', 'coordinates': [-77.245195, 38.926172]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb027242'),
#   'name': 'OpenX',
#   'category_code': 'advertising',
#   'founded_year': 2008,
#   'total_money_raised': '$75.5M',
#   'geolocation': {'type': 'Point', 'coordinates': [-118.1327468, 34.1494713]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb027243'),
#   'name': 'Jingle Networks',
#   'category_code': 'mobile',
#   'founded_year': 2005,
#   'total_money_raised': '$88.7M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.173887, 37.480999]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb027244'),
#   'name': 'Scribd',
#   'category_code': 'news',
#   'founded_year': 2007,
#   'total_money_raised': '$25.8M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.404052, 37.789634]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb027245'),
#   'name': 'Digg',
#   'category_code': 'news',
#   'founded_year': 2004,
#   'total_money_raised': '$45M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.394523, 37.764726]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb027246'),
#   'name': 'AddThis',
#   'category_code': 'advertising',
#   'founded_year': 2004,
#   'total_money_raised': '$73M',
#   'geolocation': {'type': 'Point', 'coordinates': [-77.245195, 38.926172]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb027247'),
#   'name': 'AddThis',
#   'category_code': 'advertising',
#   'founded_year': 2004,
#   'total_money_raised': '$73M',
#   'geolocation': {'type': 'Point', 'coordinates': [-77.245195, 38.926172]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb027248'),
#   'name': 'MeetMoi',
#   'category_code': 'social',
#   'founded_year': 2007,
#   'total_money_raised': '$5.58M',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.985506, 40.757929]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb027249'),
#   'name': 'Meetup',
#   'category_code': 'web',
#   'founded_year': 2002,
#   'total_money_raised': '$18.3M',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.995722, 40.72604]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb02724a'),
#   'name': 'Prosper',
#   'category_code': 'finance',
#   'founded_year': 2006,
#   'total_money_raised': '$120M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.402524, 37.78976]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb02724b'),
#   'name': 'Jajah',
#   'category_code': 'mobile',
#   'founded_year': 2005,
#   'total_money_raised': '$33M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.0899512, 37.4233896]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb02724c'),
#   'name': 'blogTV',
#   'category_code': 'games_video',
#   'founded_year': 2006,
#   'total_money_raised': '$3M',
#   'geolocation': {'type': 'Point', 'coordinates': [34.851612, 31.046051]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb02724d'),
#   'name': 'LifeLock',
#   'category_code': 'security',
#   'founded_year': 2005,
#   'total_money_raised': '$178M',
#   'geolocation': {'type': 'Point', 'coordinates': [-111.938739, 33.429859]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb02724e'),
#   'name': 'YouTube',
#   'category_code': 'games_video',
#   'founded_year': 2005,
#   'total_money_raised': '$11.5M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.426804, 37.627971]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb02724f'),
#   'name': 'AdaptiveBlue',
#   'category_code': 'games_video',
#   'founded_year': 2007,
#   'total_money_raised': '$24M',
#   'geolocation': {'type': 'Point', 'coordinates': [-74.3372, 40.801358]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb027250'),
#   'name': 'Skype',
#   'category_code': 'software',
#   'founded_year': 2003,
#   'total_money_raised': '$76.8M',
#   'geolocation': {'type': 'Point', 'coordinates': [-0.131916, 51.518132]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb027251'),
#   'name': 'Pando Networks',
#   'category_code': 'games_video',
#   'founded_year': 2004,
#   'total_money_raised': '$11M',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.99873, 40.722655]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb027252'),
#   'name': 'Livestream',
#   'category_code': 'games_video',
#   'founded_year': 2007,
#   'total_money_raised': '$14.7M',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.995625, 40.726155]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb027253'),
#   'name': 'Spock',
#   'category_code': 'search',
#   'founded_year': 2006,
#   'total_money_raised': '$7M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.217964, 37.488336]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb027254'),
#   'name': 'Wize',
#   'category_code': 'ecommerce',
#   'founded_year': 2006,
#   'total_money_raised': '$4.99M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.302262, 37.559287]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb027255'),
#   'name': 'CastTV',
#   'category_code': 'games_video',
#   'founded_year': 2006,
#   'total_money_raised': '$3.1M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.393913, 37.780716]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb027256'),
#   'name': 'CriticalMetrics',
#   'category_code': 'web',
#   'founded_year': 2007,
#   'total_money_raised': '$100k',
#   'geolocation': {'type': 'Point', 'coordinates': [-119.306607, 37.269175]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb027257'),
#   'name': 'SodaHead',
#   'category_code': 'web',
#   'founded_year': 2007,
#   'total_money_raised': '$12.7M',
#   'geolocation': {'type': 'Point', 'coordinates': [-119.306607, 37.269175]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb027258'),
#   'name': 'GrandCentral',
#   'category_code': 'mobile',
#   'founded_year': 2006,
#   'total_money_raised': '$4M',
#   'geolocation': {'type': 'Point', 'coordinates': [-121.932202, 37.465645]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb027259'),
#   'name': 'Revision3',
#   'category_code': 'games_video',
#   'founded_year': 2005,
#   'total_money_raised': '$9M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.388243, 37.757758]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb02725a'),
#   'name': 'iSkoot',
#   'category_code': 'mobile',
#   'founded_year': 2005,
#   'total_money_raised': '$32.2M',
#   'geolocation': {'type': 'Point', 'coordinates': [-71.118487, 42.375392]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb02725b'),
#   'name': 'iSkoot',
#   'category_code': 'mobile',
#   'founded_year': 2005,
#   'total_money_raised': '$32.2M',
#   'geolocation': {'type': 'Point', 'coordinates': [-71.118487, 42.375392]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb02725c'),
#   'name': 'Wakoopa',
#   'category_code': 'web',
#   'founded_year': 2007,
#   'total_money_raised': '$1M',
#   'geolocation': {'type': 'Point', 'coordinates': [4.8948623, 52.3745228]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb02725d'),
#   'name': 'Funny Or Die',
#   'category_code': 'games_video',
#   'founded_year': 2007,
#   'total_money_raised': '$18M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.137444, 37.421621]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb02725e'),
#   'name': 'Mashery',
#   'category_code': 'enterprise',
#   'founded_year': 2006,
#   'total_money_raised': '$34.7M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.4038047, 37.7870842]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb02725f'),
#   'name': 'MeeVee',
#   'category_code': 'games_video',
#   'founded_year': 2000,
#   'total_money_raised': '$25M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.341715, 37.590339]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb027260'),
#   'name': 'Topix',
#   'category_code': 'web',
#   'founded_year': 2002,
#   'total_money_raised': '$15M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.151198, 37.44296]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb027261'),
#   'name': 'Yapta',
#   'category_code': 'travel',
#   'founded_year': 2007,
#   'total_money_raised': '$24.3M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.334264, 47.599925]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb027262'),
#   'name': 'Ustream',
#   'category_code': 'games_video',
#   'founded_year': 2007,
#   'total_money_raised': '$60.1M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.07948, 37.392936]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb027263'),
#   'name': 'Jobster',
#   'category_code': 'search',
#   'founded_year': 2004,
#   'total_money_raised': '$52.5M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.357242, 47.617682]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb027264'),
#   'name': 'SideStep',
#   'category_code': 'web',
#   'founded_year': 1999,
#   'total_money_raised': '$32M',
#   'geolocation': {'type': 'Point', 'coordinates': [-121.977853, 37.374998]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb027265'),
#   'name': 'KickApps',
#   'category_code': 'enterprise',
#   'founded_year': 2004,
#   'total_money_raised': '$32M',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.9843328, 40.7516611]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb027266'),
#   'name': 'KickApps',
#   'category_code': 'enterprise',
#   'founded_year': 2004,
#   'total_money_raised': '$32M',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.9843328, 40.7516611]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb027267'),
#   'name': 'RockYou',
#   'category_code': 'games_video',
#   'founded_year': 2005,
#   'total_money_raised': '$136M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.206893, 37.484619]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb027268'),
#   'name': 'Pageflakes',
#   'category_code': 'web',
#   'founded_year': 2006,
#   'total_money_raised': '$4.1M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.414689, 37.758113]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb027269'),
#   'name': 'KickApps',
#   'category_code': 'enterprise',
#   'founded_year': 2004,
#   'total_money_raised': '$32M',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.9843328, 40.7516611]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb02726a'),
#   'name': 'Netvibes',
#   'category_code': 'web',
#   'founded_year': 2005,
#   'total_money_raised': '$16M',
#   'geolocation': {'type': 'Point', 'coordinates': [2.34668, 48.870806]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb02726b'),
#   'name': 'Cisco',
#   'category_code': 'network_hosting',
#   'founded_year': 1984,
#   'total_money_raised': '$2.5M',
#   'geolocation': {'type': 'Point', 'coordinates': [-121.95377, 37.408802]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb02726c'),
#   'name': 'Bebo',
#   'category_code': 'web',
#   'founded_year': 2005,
#   'total_money_raised': '$15M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.401116, 37.782103]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb02726d'),
#   'name': 'TVtrip',
#   'category_code': 'web',
#   'founded_year': 2007,
#   'total_money_raised': '$13.8M',
#   'geolocation': {'type': 'Point', 'coordinates': [2.350987, 48.856667]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb02726e'),
#   'name': 'WeFi',
#   'category_code': 'mobile',
#   'founded_year': 2006,
#   'total_money_raised': '$10M',
#   'geolocation': {'type': 'Point', 'coordinates': [-95.712891, 37.09024]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb02726f'),
#   'name': 'FeedBurner',
#   'category_code': 'web',
#   'founded_year': 2004,
#   'total_money_raised': '$8M',
#   'geolocation': {'type': 'Point', 'coordinates': [-87.628912, 41.889474]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb027270'),
#   'name': 'TheFind',
#   'category_code': 'ecommerce',
#   'founded_year': 2006,
#   'total_money_raised': '$26M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.073463, 37.391502]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb027271'),
#   'name': 'Dogster',
#   'category_code': 'web',
#   'founded_year': 2004,
#   'total_money_raised': '$1M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.400909, 37.762681]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb027272'),
#   'name': 'Farecast',
#   'category_code': 'search',
#   'founded_year': 2003,
#   'total_money_raised': '$20.6M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.359397, 47.620982]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb027273'),
#   'name': 'Loomia',
#   'category_code': 'web',
#   'founded_year': 2004,
#   'total_money_raised': '$7.5M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.404869, 37.796396]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb027274'),
#   'name': 'FlickIM',
#   'category_code': 'mobile',
#   'founded_year': 2006,
#   'total_money_raised': '$1.6M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.269259, 37.870744]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb027275'),
#   'name': 'Meebo',
#   'category_code': 'web',
#   'founded_year': 2005,
#   'total_money_raised': '$70M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.079017, 37.393679]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb027276'),
#   'name': 'Yahoo!',
#   'category_code': 'web',
#   'founded_year': 1994,
#   'total_money_raised': '$6.8M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.025485, 37.418531]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb027277'),
#   'name': 'Terabitz',
#   'category_code': 'web',
#   'founded_year': 2006,
#   'total_money_raised': '$10M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.159928, 37.437328]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb027278'),
#   'name': 'iLike',
#   'category_code': 'games_video',
#   'founded_year': 2002,
#   'total_money_raised': '$16.5M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.323408, 47.615313]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb027279'),
#   'name': 'Eventbrite',
#   'category_code': 'web',
#   'founded_year': 2006,
#   'total_money_raised': '$140M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.39071, 37.779507]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb02727a'),
#   'name': 'Box',
#   'category_code': 'network_hosting',
#   'founded_year': 2005,
#   'total_money_raised': '$409M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.143701, 37.425801]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb02727b'),
#   'name': 'Conduit',
#   'category_code': 'advertising',
#   'founded_year': 2005,
#   'total_money_raised': '$110M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.325248, 37.561877]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb02727c'),
#   'name': 'Kaboodle',
#   'category_code': 'ecommerce',
#   'founded_year': 2005,
#   'total_money_raised': '$5M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.036301, 37.382162]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb02727d'),
#   'name': 'Carbonite',
#   'category_code': 'network_hosting',
#   'founded_year': 2006,
#   'total_money_raised': '$66M',
#   'geolocation': {'type': 'Point', 'coordinates': [-71.076869, 42.350571]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb02727e'),
#   'name': 'Wink',
#   'category_code': 'search',
#   'founded_year': 2004,
#   'total_money_raised': '$6.2M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.072981, 37.40047]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb02727f'),
#   'name': 'Zazzle',
#   'category_code': 'ecommerce',
#   'founded_year': 1999,
#   'total_money_raised': '$46M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.2013557, 37.5108541]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb027280'),
#   'name': 'Newsvine',
#   'category_code': 'web',
#   'founded_year': 2005,
#   'total_money_raised': '$1.25M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.358484, 47.618599]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb027281'),
#   'name': 'Yelp',
#   'category_code': 'search',
#   'founded_year': 2004,
#   'total_money_raised': '$90M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.402195, 37.786183]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb027282'),
#   'name': 'KickApps',
#   'category_code': 'enterprise',
#   'founded_year': 2004,
#   'total_money_raised': '$32M',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.9843328, 40.7516611]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb027283'),
#   'name': 'GigaOM',
#   'category_code': 'news',
#   'founded_year': 2006,
#   'total_money_raised': '$14.3M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.419204, 37.775196]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb027284'),
#   'name': 'Zvents',
#   'category_code': 'web',
#   'founded_year': 2005,
#   'total_money_raised': '$31.2M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.301534, 37.553121]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb027285'),
#   'name': 'Eventful',
#   'category_code': 'web',
#   'founded_year': 2004,
#   'total_money_raised': '$19.6M',
#   'geolocation': {'type': 'Point', 'coordinates': [-117.206292, 32.872081]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb027286'),
#   'name': 'Oodle',
#   'category_code': 'social',
#   'founded_year': 2004,
#   'total_money_raised': '$23.1M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.324621, 37.563585]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb027287'),
#   'name': 'Redfin',
#   'category_code': 'real_estate',
#   'founded_year': 2004,
#   'total_money_raised': '$96.8M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.333253, 47.603122]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb027288'),
#   'name': 'Scripps Networks Interactive',
#   'category_code': 'web',
#   'founded_year': 1994,
#   'total_money_raised': '$10M',
#   'geolocation': {'type': 'Point', 'coordinates': [-95.712891, 37.09024]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb027289'),
#   'name': 'ooma',
#   'category_code': 'hardware',
#   'founded_year': 2004,
#   'total_money_raised': '$81.3M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.116026, 37.451958]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb02728a'),
#   'name': 'Flixster',
#   'category_code': 'web',
#   'founded_year': 2006,
#   'total_money_raised': '$7.18M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.406676, 37.766909]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb02728b'),
#   'name': 'Simply Hired',
#   'category_code': 'search',
#   'founded_year': 2004,
#   'total_money_raised': '$22.3M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.0780632, 37.4219165]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb02728c'),
#   'name': 'oDesk',
#   'category_code': 'web',
#   'founded_year': 2005,
#   'total_money_raised': '$44M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.178557, 37.479952]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb02728d'),
#   'name': 'GoingOn',
#   'category_code': 'software',
#   'founded_year': 2008,
#   'total_money_raised': '$8.5M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.392142, 37.782263]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb02728e'),
#   'name': 'Spreadshirt',
#   'category_code': 'advertising',
#   'founded_year': 2002,
#   'total_money_raised': '$12.7M',
#   'geolocation': {'type': 'Point', 'coordinates': [-80.004195, 40.437985]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb02728f'),
#   'name': 'Piczo',
#   'category_code': 'network_hosting',
#   'founded_year': 1990,
#   'total_money_raised': '$11M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.398479, 37.793703]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb027290'),
#   'name': 'IceRocket',
#   'category_code': 'search',
#   'founded_year': 2004,
#   'total_money_raised': '$300k',
#   'geolocation': {'type': 'Point', 'coordinates': [-96.797111, 32.781078]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb027291'),
#   'name': 'Seesmic',
#   'category_code': 'web',
#   'founded_year': 2007,
#   'total_money_raised': '$16M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.419204, 37.775196]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb027292'),
#   'name': 'GigaOM',
#   'category_code': 'news',
#   'founded_year': 2006,
#   'total_money_raised': '$14.3M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.419204, 37.775196]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb027293'),
#   'name': 'LinkedIn',
#   'category_code': 'social',
#   'founded_year': 2003,
#   'total_money_raised': '$200M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.073635, 37.423258]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb027294'),
#   'name': 'spigit',
#   'category_code': 'software',
#   'founded_year': 2006,
#   'total_money_raised': '$55.6M',
#   'geolocation': {'type': 'Point', 'coordinates': [-121.8731805, 37.6637279]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb027295'),
#   'name': 'spigit',
#   'category_code': 'software',
#   'founded_year': 2006,
#   'total_money_raised': '$55.6M',
#   'geolocation': {'type': 'Point', 'coordinates': [-121.8731805, 37.6637279]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb027296'),
#   'name': 'spigit',
#   'category_code': 'software',
#   'founded_year': 2006,
#   'total_money_raised': '$55.6M',
#   'geolocation': {'type': 'Point', 'coordinates': [-121.8731805, 37.6637279]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb027297'),
#   'name': 'ScanScout',
#   'category_code': 'advertising',
#   'founded_year': 2005,
#   'total_money_raised': '$17.5M',
#   'geolocation': {'type': 'Point', 'coordinates': [-71.051931, 42.340889]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb027298'),
#   'name': 'Indeed',
#   'category_code': 'web',
#   'founded_year': 2004,
#   'total_money_raised': '$5M',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.558082, 41.038155]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb027299'),
#   'name': 'Jaxtr',
#   'category_code': 'mobile',
#   'founded_year': 2005,
#   'total_money_raised': '$21.5M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.18676, 37.451026]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb02729a'),
#   'name': 'introNetworks',
#   'category_code': 'web',
#   'founded_year': 2003,
#   'total_money_raised': '$2.7M',
#   'geolocation': {'type': 'Point', 'coordinates': [-119.641821, 34.42071]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb02729b'),
#   'name': 'Tagged',
#   'category_code': 'social',
#   'founded_year': 2004,
#   'total_money_raised': '$28.7M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.4186, 37.7753]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb02729c'),
#   'name': 'ScanScout',
#   'category_code': 'advertising',
#   'founded_year': 2005,
#   'total_money_raised': '$17.5M',
#   'geolocation': {'type': 'Point', 'coordinates': [-71.051931, 42.340889]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb02729d'),
#   'name': 'Respectance',
#   'category_code': 'web',
#   'founded_year': 2006,
#   'total_money_raised': '$1.75M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.321836, 37.55909]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb02729e'),
#   'name': 'Curse',
#   'category_code': 'games_video',
#   'founded_year': 2006,
#   'total_money_raised': '$12M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.399972, 37.787092]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb02729f'),
#   'name': 'Kiptronic',
#   'category_code': 'advertising',
#   'founded_year': 2005,
#   'total_money_raised': '$7.3M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.402349, 37.792394]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0272a0'),
#   'name': 'Google',
#   'category_code': 'search',
#   'founded_year': 1998,
#   'total_money_raised': '$555M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.084143, 37.421972]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0272a1'),
#   'name': 'Google',
#   'category_code': 'search',
#   'founded_year': 1998,
#   'total_money_raised': '$555M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.084143, 37.421972]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0272a2'),
#   'name': 'Google',
#   'category_code': 'search',
#   'founded_year': 1998,
#   'total_money_raised': '$555M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.084143, 37.421972]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0272a3'),
#   'name': 'Google',
#   'category_code': 'search',
#   'founded_year': 1998,
#   'total_money_raised': '$555M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.084143, 37.421972]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0272a4'),
#   'name': 'Google',
#   'category_code': 'search',
#   'founded_year': 1998,
#   'total_money_raised': '$555M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.084143, 37.421972]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0272a5'),
#   'name': 'hi5',
#   'category_code': 'games_video',
#   'founded_year': 2003,
#   'total_money_raised': '$52M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.400558, 37.788668]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0272a6'),
#   'name': 'Socialtext',
#   'category_code': 'enterprise',
#   'founded_year': 2002,
#   'total_money_raised': '$46.8M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.1615, 37.442949]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0272a7'),
#   'name': 'ScanScout',
#   'category_code': 'advertising',
#   'founded_year': 2005,
#   'total_money_raised': '$17.5M',
#   'geolocation': {'type': 'Point', 'coordinates': [-71.051931, 42.340889]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0272a8'),
#   'name': 'Google',
#   'category_code': 'search',
#   'founded_year': 1998,
#   'total_money_raised': '$555M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.084143, 37.421972]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0272a9'),
#   'name': 'Google',
#   'category_code': 'search',
#   'founded_year': 1998,
#   'total_money_raised': '$555M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.084143, 37.421972]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0272aa'),
#   'name': 'Google',
#   'category_code': 'search',
#   'founded_year': 1998,
#   'total_money_raised': '$555M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.084143, 37.421972]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0272ab'),
#   'name': 'Google',
#   'category_code': 'search',
#   'founded_year': 1998,
#   'total_money_raised': '$555M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.084143, 37.421972]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0272ac'),
#   'name': 'Google',
#   'category_code': 'search',
#   'founded_year': 1998,
#   'total_money_raised': '$555M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.084143, 37.421972]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0272ad'),
#   'name': 'Google',
#   'category_code': 'search',
#   'founded_year': 1998,
#   'total_money_raised': '$555M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.084143, 37.421972]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0272ae'),
#   'name': 'Google',
#   'category_code': 'search',
#   'founded_year': 1998,
#   'total_money_raised': '$555M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.084143, 37.421972]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0272af'),
#   'name': 'Google',
#   'category_code': 'search',
#   'founded_year': 1998,
#   'total_money_raised': '$555M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.084143, 37.421972]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0272b0'),
#   'name': 'Google',
#   'category_code': 'search',
#   'founded_year': 1998,
#   'total_money_raised': '$555M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.084143, 37.421972]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0272b1'),
#   'name': 'Google',
#   'category_code': 'search',
#   'founded_year': 1998,
#   'total_money_raised': '$555M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.084143, 37.421972]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0272b2'),
#   'name': 'Google',
#   'category_code': 'search',
#   'founded_year': 1998,
#   'total_money_raised': '$555M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.084143, 37.421972]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0272b3'),
#   'name': 'Google',
#   'category_code': 'search',
#   'founded_year': 1998,
#   'total_money_raised': '$555M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.084143, 37.421972]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0272b4'),
#   'name': 'Google',
#   'category_code': 'search',
#   'founded_year': 1998,
#   'total_money_raised': '$555M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.084143, 37.421972]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0272b5'),
#   'name': 'Google',
#   'category_code': 'search',
#   'founded_year': 1998,
#   'total_money_raised': '$555M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.084143, 37.421972]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0272b6'),
#   'name': 'Bazaarvoice',
#   'category_code': 'software',
#   'founded_year': 2005,
#   'total_money_raised': '$131M',
#   'geolocation': {'type': 'Point', 'coordinates': [-97.717667, 30.407545]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0272b7'),
#   'name': 'Google',
#   'category_code': 'search',
#   'founded_year': 1998,
#   'total_money_raised': '$555M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.084143, 37.421972]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0272b8'),
#   'name': 'Google',
#   'category_code': 'search',
#   'founded_year': 1998,
#   'total_money_raised': '$555M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.084143, 37.421972]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0272b9'),
#   'name': 'Google',
#   'category_code': 'search',
#   'founded_year': 1998,
#   'total_money_raised': '$555M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.084143, 37.421972]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0272ba'),
#   'name': 'Google',
#   'category_code': 'search',
#   'founded_year': 1998,
#   'total_money_raised': '$555M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.084143, 37.421972]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0272bb'),
#   'name': 'Google',
#   'category_code': 'search',
#   'founded_year': 1998,
#   'total_money_raised': '$555M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.084143, 37.421972]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0272bc'),
#   'name': 'Google',
#   'category_code': 'search',
#   'founded_year': 1998,
#   'total_money_raised': '$555M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.084143, 37.421972]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0272bd'),
#   'name': 'Google',
#   'category_code': 'search',
#   'founded_year': 1998,
#   'total_money_raised': '$555M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.084143, 37.421972]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0272be'),
#   'name': 'Google',
#   'category_code': 'search',
#   'founded_year': 1998,
#   'total_money_raised': '$555M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.084143, 37.421972]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0272bf'),
#   'name': 'Google',
#   'category_code': 'search',
#   'founded_year': 1998,
#   'total_money_raised': '$555M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.084143, 37.421972]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0272c0'),
#   'name': 'Google',
#   'category_code': 'search',
#   'founded_year': 1998,
#   'total_money_raised': '$555M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.084143, 37.421972]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0272c1'),
#   'name': 'Google',
#   'category_code': 'search',
#   'founded_year': 1998,
#   'total_money_raised': '$555M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.084143, 37.421972]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0272c2'),
#   'name': 'Google',
#   'category_code': 'search',
#   'founded_year': 1998,
#   'total_money_raised': '$555M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.084143, 37.421972]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0272c3'),
#   'name': 'Google',
#   'category_code': 'search',
#   'founded_year': 1998,
#   'total_money_raised': '$555M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.084143, 37.421972]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0272c4'),
#   'name': 'Google',
#   'category_code': 'search',
#   'founded_year': 1998,
#   'total_money_raised': '$555M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.084143, 37.421972]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0272c5'),
#   'name': 'Google',
#   'category_code': 'search',
#   'founded_year': 1998,
#   'total_money_raised': '$555M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.084143, 37.421972]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0272c6'),
#   'name': 'Google',
#   'category_code': 'search',
#   'founded_year': 1998,
#   'total_money_raised': '$555M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.084143, 37.421972]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0272c7'),
#   'name': 'Google',
#   'category_code': 'search',
#   'founded_year': 1998,
#   'total_money_raised': '$555M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.084143, 37.421972]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0272c8'),
#   'name': 'Google',
#   'category_code': 'search',
#   'founded_year': 1998,
#   'total_money_raised': '$555M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.084143, 37.421972]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0272c9'),
#   'name': 'Google',
#   'category_code': 'search',
#   'founded_year': 1998,
#   'total_money_raised': '$555M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.084143, 37.421972]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0272ca'),
#   'name': 'NetSuite',
#   'category_code': 'enterprise',
#   'founded_year': 1998,
#   'total_money_raised': '$1.5M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.327323, 37.536172]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0272cb'),
#   'name': 'eBuddy',
#   'category_code': 'messaging',
#   'founded_year': 2003,
#   'total_money_raised': '€11.5M',
#   'geolocation': {'type': 'Point', 'coordinates': [4.8919457, 52.3640933]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0272cc'),
#   'name': 'eBuddy',
#   'category_code': 'messaging',
#   'founded_year': 2003,
#   'total_money_raised': '€11.5M',
#   'geolocation': {'type': 'Point', 'coordinates': [4.8919457, 52.3640933]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0272cd'),
#   'name': 'eBuddy',
#   'category_code': 'messaging',
#   'founded_year': 2003,
#   'total_money_raised': '€11.5M',
#   'geolocation': {'type': 'Point', 'coordinates': [4.8919457, 52.3640933]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0272ce'),
#   'name': 'Phonezoo',
#   'category_code': 'web',
#   'founded_year': 2006,
#   'total_money_raised': '$2.06M',
#   'geolocation': {'type': 'Point', 'coordinates': [-121.991471, 37.386376]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0272cf'),
#   'name': 'Google',
#   'category_code': 'search',
#   'founded_year': 1998,
#   'total_money_raised': '$555M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.084143, 37.421972]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0272d0'),
#   'name': 'Grockit',
#   'category_code': 'social',
#   'founded_year': 2006,
#   'total_money_raised': '$44.7M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.419204, 37.775196]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0272d1'),
#   'name': 'NowPublic',
#   'category_code': 'web',
#   'founded_year': 2005,
#   'total_money_raised': '$12M',
#   'geolocation': {'type': 'Point', 'coordinates': [-123.103986, 49.283376]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0272d2'),
#   'name': 'Google',
#   'category_code': 'search',
#   'founded_year': 1998,
#   'total_money_raised': '$555M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.084143, 37.421972]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0272d3'),
#   'name': 'Vuze',
#   'category_code': 'games_video',
#   'founded_year': 2005,
#   'total_money_raised': '$34M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.2262606, 37.4858654]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0272d4'),
#   'name': 'Wishpot',
#   'category_code': 'ecommerce',
#   'founded_year': 2006,
#   'total_money_raised': '$1.3M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.347533, 47.620716]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0272d5'),
#   'name': 'PodTech',
#   'category_code': 'games_video',
#   'founded_year': 2005,
#   'total_money_raised': '$7.5M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.154176, 37.408256]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0272d6'),
#   'name': 'Google',
#   'category_code': 'search',
#   'founded_year': 1998,
#   'total_money_raised': '$555M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.084143, 37.421972]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0272d7'),
#   'name': 'Reddit',
#   'category_code': 'web',
#   'founded_year': 2005,
#   'total_money_raised': '$100k',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.395257, 37.780883]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0272d8'),
#   'name': 'Crackle',
#   'category_code': 'games_video',
#   'founded_year': 2004,
#   'total_money_raised': '$1.75M',
#   'geolocation': {'type': 'Point', 'coordinates': [-118.401579, 34.017506]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0272d9'),
#   'name': 'Lotame',
#   'category_code': 'advertising',
#   'founded_year': 2006,
#   'total_money_raised': '$34M',
#   'geolocation': {'type': 'Point', 'coordinates': [-76.77514, 39.205649]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0272da'),
#   'name': 'Rebtel',
#   'category_code': 'mobile',
#   'founded_year': 2006,
#   'total_money_raised': '$20M',
#   'geolocation': {'type': 'Point', 'coordinates': [18.1582777, 59.3167843]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0272db'),
#   'name': 'BuddyTV',
#   'category_code': 'games_video',
#   'founded_year': 2005,
#   'total_money_raised': '$10.6M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.356756, 47.61968]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0272dc'),
#   'name': 'Lotame',
#   'category_code': 'advertising',
#   'founded_year': 2006,
#   'total_money_raised': '$34M',
#   'geolocation': {'type': 'Point', 'coordinates': [-76.77514, 39.205649]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0272dd'),
#   'name': 'Buxfer',
#   'category_code': 'web',
#   'founded_year': 2007,
#   'total_money_raised': '$315k',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.073003, 37.400465]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0272de'),
#   'name': 'boo-box',
#   'category_code': 'advertising',
#   'founded_year': 2007,
#   'total_money_raised': '$300k',
#   'geolocation': {'type': 'Point', 'coordinates': [-46.679287, -23.558584]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0272df'),
#   'name': 'Retrevo',
#   'category_code': 'web',
#   'founded_year': 2006,
#   'total_money_raised': '$11.9M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.034021, 37.368594]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0272e0'),
#   'name': 'Brightcove',
#   'category_code': 'enterprise',
#   'founded_year': 2004,
#   'total_money_raised': '$103M',
#   'geolocation': {'type': 'Point', 'coordinates': [-71.086596, 42.362993]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0272e1'),
#   'name': 'WallStrip',
#   'category_code': 'games_video',
#   'founded_year': 2006,
#   'total_money_raised': '$600k',
#   'geolocation': {'type': 'Point', 'coordinates': [-95.712891, 37.09024]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0272e2'),
#   'name': 'Nimbuzz',
#   'category_code': 'mobile',
#   'founded_year': 2006,
#   'total_money_raised': '$25M',
#   'geolocation': {'type': 'Point', 'coordinates': [4.5464658, 51.9122575]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0272e3'),
#   'name': 'Hightail',
#   'category_code': 'network_hosting',
#   'founded_year': 2004,
#   'total_money_raised': '$82.7M',
#   'geolocation': {'type': 'Point', 'coordinates': [-121.935688, 37.288974]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0272e4'),
#   'name': 'obopay',
#   'category_code': 'mobile',
#   'founded_year': 2005,
#   'total_money_raised': '$145M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.258037, 37.524729]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0272e5'),
#   'name': 'Rocketboom',
#   'category_code': 'news',
#   'founded_year': 2007,
#   'total_money_raised': '$1.5M',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.97785, 40.797364]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0272e6'),
#   'name': 'Lotame',
#   'category_code': 'advertising',
#   'founded_year': 2006,
#   'total_money_raised': '$34M',
#   'geolocation': {'type': 'Point', 'coordinates': [-76.77514, 39.205649]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0272e7'),
#   'name': 'IntenseDebate',
#   'category_code': 'web',
#   'founded_year': 2006,
#   'total_money_raised': '$515k',
#   'geolocation': {'type': 'Point', 'coordinates': [-105.276843, 40.010492]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0272e8'),
#   'name': 'Snapfish',
#   'category_code': 'network_hosting',
#   'founded_year': 1999,
#   'total_money_raised': '$43.5M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.396689, 37.78554]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0272e9'),
#   'name': 'PayScale',
#   'category_code': 'software',
#   'founded_year': 1999,
#   'total_money_raised': '$31.1M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.3276962, 47.5999337]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0272ea'),
#   'name': 'IMVU',
#   'category_code': 'web',
#   'founded_year': 2004,
#   'total_money_raised': '$29M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.0727749, 37.3927975]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0272eb'),
#   'name': 'PayPal',
#   'category_code': 'finance',
#   'founded_year': 1998,
#   'total_money_raised': '$197M',
#   'geolocation': {'type': 'Point', 'coordinates': [-121.927696, 37.294465]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0272ec'),
#   'name': 'Echo',
#   'category_code': 'enterprise',
#   'founded_year': 2007,
#   'total_money_raised': '$4.8M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.1879633, 38.0729365]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0272ed'),
#   'name': 'Scrybe',
#   'category_code': 'enterprise',
#   'founded_year': 2007,
#   'total_money_raised': '$1.31M',
#   'geolocation': {'type': 'Point', 'coordinates': [-74.761403, 40.270666]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0272ee'),
#   'name': 'madKast',
#   'category_code': 'web',
#   'founded_year': 2007,
#   'total_money_raised': '$315k',
#   'geolocation': {'type': 'Point', 'coordinates': [-105.276843, 40.010492]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0272ef'),
#   'name': 'Metacafe',
#   'category_code': 'games_video',
#   'founded_year': 2003,
#   'total_money_raised': '$50M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.159928, 37.437328]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0272f0'),
#   'name': 'ChaCha',
#   'category_code': 'advertising',
#   'founded_year': 2005,
#   'total_money_raised': '$89M',
#   'geolocation': {'type': 'Point', 'coordinates': [-86.130347, 39.998641]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0272f1'),
#   'name': 'SelectMinds',
#   'category_code': 'network_hosting',
#   'founded_year': 2000,
#   'total_money_raised': '$5.5M',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.990004, 40.740251]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0272f2'),
#   'name': 'Sportingo',
#   'category_code': 'web',
#   'founded_year': 2006,
#   'total_money_raised': '$3.2M',
#   'geolocation': {'type': 'Point', 'coordinates': [-96.76492, 17.08881]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0272f3'),
#   'name': 'Flock',
#   'category_code': 'web',
#   'founded_year': 2005,
#   'total_money_raised': '$28.3M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.228843, 37.491356]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0272f4'),
#   'name': 'AOL',
#   'category_code': 'web',
#   'founded_year': 1985,
#   'total_money_raised': '$1B',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.9919311, 40.7311317]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0272f5'),
#   'name': 'GreatCall',
#   'category_code': 'mobile',
#   'founded_year': 2005,
#   'total_money_raised': '$75.3M',
#   'geolocation': {'type': 'Point', 'coordinates': [-117.265191, 32.964294]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0272f6'),
#   'name': 'Splashup',
#   'category_code': 'web',
#   'founded_year': 2007,
#   'total_money_raised': '$10k',
#   'geolocation': {'type': 'Point', 'coordinates': [-95.712891, 37.09024]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0272f7'),
#   'name': 'Kontera',
#   'category_code': 'advertising',
#   'founded_year': 2003,
#   'total_money_raised': '$36.1M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.411157, 37.767575]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0272f8'),
#   'name': 'Dropbox',
#   'category_code': 'software',
#   'founded_year': 2007,
#   'total_money_raised': '$257M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.4084994, 37.7909427]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0272f9'),
#   'name': 'Curverider',
#   'category_code': 'network_hosting',
#   'founded_year': 2005,
#   'total_money_raised': '£300k',
#   'geolocation': {'type': 'Point', 'coordinates': [-1.197534, 51.785428]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0272fa'),
#   'name': 'Yola',
#   'category_code': 'web',
#   'founded_year': 2007,
#   'total_money_raised': '$25M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.3954751, 37.7911148]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0272fb'),
#   'name': 'TokBox',
#   'category_code': 'messaging',
#   'founded_year': 2007,
#   'total_money_raised': '$26M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.39071, 37.779507]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0272fc'),
#   'name': 'Weebly',
#   'category_code': 'web',
#   'founded_year': 2006,
#   'total_money_raised': '$670k',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.400729, 37.795555]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0272fd'),
#   'name': 'Aniboom',
#   'category_code': 'games_video',
#   'founded_year': 2006,
#   'total_money_raised': '$14.5M',
#   'geolocation': {'type': 'Point', 'coordinates': [34.851612, 31.046051]}},
# ...
#   'category_code': 'network_hosting',
#   'founded_year': 2007,
#   'total_money_raised': '$1M',
#   'geolocation': {'type': 'Point', 'coordinates': [12.461425, 41.823172]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0275d5'),
#   'name': 'Talend',
#   'category_code': 'analytics',
#   'founded_year': 2005,
#   'total_money_raised': '$102M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.111711, 37.371908]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0275d6'),
#   'name': 'OVGuide',
#   'category_code': 'games_video',
#   'founded_year': 2006,
#   'total_money_raised': '$7.98M',
#   'geolocation': {'type': 'Point', 'coordinates': [-118.243425, 34.052187]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0275d7'),
#   'name': 'FuGen Solutions',
#   'category_code': 'web',
#   'founded_year': 2006,
#   'total_money_raised': '$925k',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.012475, 37.384239]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0275d8'),
#   'name': 'SnapLogic',
#   'category_code': 'enterprise',
#   'founded_year': 2006,
#   'total_money_raised': '$34.8M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.302654, 37.558245]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0275d9'),
#   'name': 'Fave Media',
#   'category_code': 'search',
#   'founded_year': 2006,
#   'total_money_raised': '$1.6M',
#   'geolocation': {'type': 'Point', 'coordinates': [-87.640442, 41.924899]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0275da'),
#   'name': 'EatLime',
#   'category_code': 'photo_video',
#   'founded_year': 2007,
#   'total_money_raised': '$3.38M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.4194155, 37.7749295]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0275db'),
#   'name': 'New Relic',
#   'category_code': 'software',
#   'founded_year': 2008,
#   'total_money_raised': '$175M',
#   'geolocation': {'type': 'Point', 'coordinates': [-119.306607, 37.269175]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0275dc'),
#   'name': 'Andera',
#   'category_code': 'finance',
#   'founded_year': 2000,
#   'total_money_raised': '$9.35M',
#   'geolocation': {'type': 'Point', 'coordinates': [-71.4133543, 41.8283364]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0275dd'),
#   'name': 'NewsCred',
#   'category_code': 'advertising',
#   'founded_year': 2008,
#   'total_money_raised': '$21.8M',
#   'geolocation': {'type': 'Point', 'coordinates': [6.124424, 46.223157]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0275de'),
#   'name': 'NewsCred',
#   'category_code': 'advertising',
#   'founded_year': 2008,
#   'total_money_raised': '$21.8M',
#   'geolocation': {'type': 'Point', 'coordinates': [6.124424, 46.223157]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0275df'),
#   'name': 'Boardwalktech',
#   'category_code': 'software',
#   'founded_year': 2004,
#   'total_money_raised': '$500k',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.103076, 37.431941]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0275e0'),
#   'name': 'Authentium',
#   'category_code': 'software',
#   'founded_year': 1999,
#   'total_money_raised': '$21M',
#   'geolocation': {'type': 'Point', 'coordinates': [-80.134733, 26.837923]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0275e1'),
#   'name': 'ExpertFlyer',
#   'category_code': 'search',
#   'founded_year': 2004,
#   'total_money_raised': '$30k',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.042188, 40.773557]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0275e2'),
#   'name': 'ClairMail',
#   'category_code': 'finance',
#   'founded_year': 2004,
#   'total_money_raised': '$34.1M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.513742, 38.057107]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0275e3'),
#   'name': 'BioIQ',
#   'category_code': 'biotech',
#   'founded_year': 2005,
#   'total_money_raised': '$493k',
#   'geolocation': {'type': 'Point', 'coordinates': [-119.704902, 34.424185]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0275e4'),
#   'name': 'Confident Technologies',
#   'category_code': 'enterprise',
#   'founded_year': 1998,
#   'total_money_raised': '$6.29M',
#   'geolocation': {'type': 'Point', 'coordinates': [-95.989442, 36.15057]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0275e5'),
#   'name': 'Appfolio',
#   'category_code': 'real_estate',
#   'founded_year': 2006,
#   'total_money_raised': '$30M',
#   'geolocation': {'type': 'Point', 'coordinates': [-119.863565, 34.433463]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0275e6'),
#   'name': 'CitizenHawk',
#   'category_code': 'advertising',
#   'founded_year': 2006,
#   'total_money_raised': '$3M',
#   'geolocation': {'type': 'Point', 'coordinates': [-117.734795, 33.571604]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0275e7'),
#   'name': 'Nvidia',
#   'category_code': 'hardware',
#   'founded_year': 1993,
#   'total_money_raised': '$25M',
#   'geolocation': {'type': 'Point', 'coordinates': [-121.965381, 37.370026]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0275e8'),
#   'name': 'Nvidia',
#   'category_code': 'hardware',
#   'founded_year': 1993,
#   'total_money_raised': '$25M',
#   'geolocation': {'type': 'Point', 'coordinates': [-121.965381, 37.370026]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0275e9'),
#   'name': 'Nvidia',
#   'category_code': 'hardware',
#   'founded_year': 1993,
#   'total_money_raised': '$25M',
#   'geolocation': {'type': 'Point', 'coordinates': [-121.965381, 37.370026]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0275ea'),
#   'name': 'zweitgeist',
#   'category_code': 'web',
#   'founded_year': 2006,
#   'total_money_raised': '€500k',
#   'geolocation': {'type': 'Point', 'coordinates': [9.926475, 53.563564]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0275eb'),
#   'name': 'sevenload',
#   'category_code': 'games_video',
#   'founded_year': 2006,
#   'total_money_raised': '€25M',
#   'geolocation': {'type': 'Point', 'coordinates': [6.921546, 50.945289]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0275ec'),
#   'name': 'Nvidia',
#   'category_code': 'hardware',
#   'founded_year': 1993,
#   'total_money_raised': '$25M',
#   'geolocation': {'type': 'Point', 'coordinates': [-121.965381, 37.370026]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0275ed'),
#   'name': 'amazingtunes',
#   'category_code': 'games_video',
#   'founded_year': 2006,
#   'total_money_raised': '£1.4M',
#   'geolocation': {'type': 'Point', 'coordinates': [-1.611141, 54.971346]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0275ee'),
#   'name': 'Nvidia',
#   'category_code': 'hardware',
#   'founded_year': 1993,
#   'total_money_raised': '$25M',
#   'geolocation': {'type': 'Point', 'coordinates': [-121.965381, 37.370026]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0275ef'),
#   'name': 'Passenger',
#   'category_code': 'social',
#   'founded_year': 2005,
#   'total_money_raised': '$25.6M',
#   'geolocation': {'type': 'Point', 'coordinates': [-118.308943, 34.029956]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0275f0'),
#   'name': 'Sparkroom',
#   'category_code': 'advertising',
#   'founded_year': 2007,
#   'total_money_raised': '$4M',
#   'geolocation': {'type': 'Point', 'coordinates': [-79.385969, 43.6683]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0275f1'),
#   'name': 'Rapleaf',
#   'category_code': 'messaging',
#   'founded_year': 2006,
#   'total_money_raised': '$16M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.4013875, 37.7867392]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0275f2'),
#   'name': 'rVita',
#   'category_code': 'software',
#   'founded_year': 2007,
#   'total_money_raised': '$1M',
#   'geolocation': {'type': 'Point', 'coordinates': [-121.978821, 37.398476]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0275f3'),
#   'name': 'Tyfone',
#   'category_code': 'mobile',
#   'founded_year': 2004,
#   'total_money_raised': '$5.3M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.674995, 45.5105]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0275f4'),
#   'name': 'SimpleTuition',
#   'category_code': 'finance',
#   'founded_year': 2005,
#   'total_money_raised': '$31M',
#   'geolocation': {'type': 'Point', 'coordinates': [-71.214796, 42.297418]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0275f5'),
#   'name': 'TuneUp',
#   'category_code': 'music',
#   'founded_year': 2007,
#   'total_money_raised': '$15.6M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.4119381, 37.7654195]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0275f6'),
#   'name': 'Infinia',
#   'category_code': 'cleantech',
#   'founded_year': 1985,
#   'total_money_raised': '$152M',
#   'geolocation': {'type': 'Point', 'coordinates': [-119.22322, 46.220919]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0275f7'),
#   'name': 'Efficient Frontier',
#   'category_code': 'advertising',
#   'founded_year': 2002,
#   'total_money_raised': '$6M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.0323525, 37.4049731]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0275f8'),
#   'name': 'MeFeedia',
#   'category_code': 'games_video',
#   'founded_year': 2007,
#   'total_money_raised': '$250k',
#   'geolocation': {'type': 'Point', 'coordinates': [-118.335292, 34.155869]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0275f9'),
#   'name': 'Blackberry',
#   'category_code': 'hardware',
#   'founded_year': 1984,
#   'total_money_raised': '$1B',
#   'geolocation': {'type': 'Point', 'coordinates': [-80.539594, 43.476528]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0275fa'),
#   'name': 'Mozes',
#   'category_code': 'mobile',
#   'founded_year': 2005,
#   'total_money_raised': '$22.3M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.166911, 37.445667]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0275fb'),
#   'name': 'Smarkets',
#   'category_code': 'sports',
#   'founded_year': 2008,
#   'total_money_raised': '$2.71M',
#   'geolocation': {'type': 'Point', 'coordinates': [-0.130772, 51.550757]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0275fc'),
#   'name': 'VirtualLogix',
#   'category_code': 'software',
#   'founded_year': 2002,
#   'total_money_raised': '$29.3M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.015463, 37.409147]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0275fd'),
#   'name': 'Dezide',
#   'category_code': 'software',
#   'founded_year': 2001,
#   'total_money_raised': '$350k',
#   'geolocation': {'type': 'Point', 'coordinates': [9.945944, 57.047302]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0275fe'),
#   'name': 'Futurlink',
#   'category_code': 'mobile',
#   'founded_year': 2003,
#   'total_money_raised': '$7.62M',
#   'geolocation': {'type': 'Point', 'coordinates': [2.189241, 41.396553]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb0275ff'),
#   'name': 'Stitcher',
#   'category_code': 'mobile',
#   'founded_year': 2008,
#   'total_money_raised': '$18.7M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.419204, 37.775196]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb027600'),
#   'name': 'Cognition Technologies',
#   'category_code': 'software',
#   'founded_year': 2003,
#   'total_money_raised': '$2.9M',
#   'geolocation': {'type': 'Point', 'coordinates': [-118.389452, 33.985399]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb027601'),
#   'name': '[x+1]',
#   'category_code': 'enterprise',
#   'founded_year': 1999,
#   'total_money_raised': '$45M',
#   'geolocation': {'type': 'Point', 'coordinates': [-73.982624, 40.7455068]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb027602'),
#   'name': 'IP Commerce',
#   'category_code': 'network_hosting',
#   'founded_year': 2005,
#   'total_money_raised': '$44M',
#   'geolocation': {'type': 'Point', 'coordinates': [-104.99342, 39.74893]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb027603'),
#   'name': 'deviantART',
#   'category_code': 'web',
#   'founded_year': 2000,
#   'total_money_raised': '$13.5M',
#   'geolocation': {'type': 'Point', 'coordinates': [-118.33334, 34.101578]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb027604'),
#   'name': 'TerraPass',
#   'category_code': 'web',
#   'founded_year': 2004,
#   'total_money_raised': '$5.8M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.397847, 37.787445]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb027605'),
#   'name': 'BusinessCard2',
#   'category_code': 'web',
#   'founded_year': 2006,
#   'total_money_raised': '$1.7M',
#   'geolocation': {'type': 'Point', 'coordinates': [-93.250179, 45.004089]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb027606'),
#   'name': 'Raydiance',
#   'category_code': 'manufacturing',
#   'founded_year': 2004,
#   'total_money_raised': '$49.3M',
#   'geolocation': {'type': 'Point', 'coordinates': [-77.083389, 38.96524]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb027607'),
#   'name': 'Sometrics',
#   'category_code': 'games_video',
#   'founded_year': 2007,
#   'total_money_raised': '$5.55M',
#   'geolocation': {'type': 'Point', 'coordinates': [-118.251343, 34.048857]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb027608'),
#   'name': 'SocialVibe',
#   'category_code': 'advertising',
#   'founded_year': 2007,
#   'total_money_raised': '$43.9M',
#   'geolocation': {'type': 'Point', 'coordinates': [-118.3826743, 34.0815238]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb027609'),
#   'name': 'Increo Solutions',
#   'category_code': 'enterprise',
#   'founded_year': 2008,
#   'total_money_raised': '$500k',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.073003, 37.400465]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb02760a'),
#   'name': 'Parascale',
#   'category_code': 'network_hosting',
#   'founded_year': 2005,
#   'total_money_raised': '$11.4M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.05074, 37.316653]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb02760b'),
#   'name': 'OleOle',
#   'category_code': 'network_hosting',
#   'founded_year': 2006,
#   'total_money_raised': '$5M',
#   'geolocation': {'type': 'Point', 'coordinates': [-118.409161, 34.067153]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb02760c'),
#   'name': 'Aprius',
#   'category_code': 'hardware',
#   'founded_year': 2006,
#   'total_money_raised': '$22M',
#   'geolocation': {'type': 'Point', 'coordinates': [-117.5357108, 47.6409655]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb02760d'),
#   'name': 'NextBio',
#   'category_code': 'enterprise',
#   'founded_year': 2004,
#   'total_money_raised': '$16.1M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.05074, 37.316653]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb02760e'),
#   'name': 'Aquantia',
#   'category_code': 'semiconductor',
#   'founded_year': 2004,
#   'total_money_raised': '$138M',
#   'geolocation': {'type': 'Point', 'coordinates': [-121.9175461, 37.4130233]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb02760f'),
#   'name': 'Zoosk',
#   'category_code': 'social',
#   'founded_year': 2007,
#   'total_money_raised': '$61.6M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.4099154, 37.7726402]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb027610'),
#   'name': 'ClearContext',
#   'category_code': 'software',
#   'founded_year': 2003,
#   'total_money_raised': '$500k',
#   'geolocation': {'type': 'Point', 'coordinates': [-104.9832304, 39.6523451]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb027611'),
#   'name': 'Transpera',
#   'category_code': 'mobile',
#   'founded_year': 2007,
#   'total_money_raised': '$19.5M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.405081, 37.785792]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb027612'),
#   'name': 'AirCell',
#   'category_code': 'messaging',
#   'founded_year': 2005,
#   'total_money_raised': '$276M',
#   'geolocation': {'type': 'Point', 'coordinates': [-88.004903, 41.989344]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb027613'),
#   'name': 'GameFly',
#   'category_code': 'games_video',
#   'founded_year': 2002,
#   'total_money_raised': '$10.7M',
#   'geolocation': {'type': 'Point', 'coordinates': [-118.3962622, 33.934558]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb027614'),
#   'name': 'WrapMail',
#   'category_code': 'advertising',
#   'founded_year': 2005,
#   'total_money_raised': '$1.94M',
#   'geolocation': {'type': 'Point', 'coordinates': [-80.143394, 26.119403]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb027615'),
#   'name': 'Sonico',
#   'category_code': 'social',
#   'founded_year': 2007,
#   'total_money_raised': '$6M',
#   'geolocation': {'type': 'Point', 'coordinates': [-58.417309, -34.611781]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb027616'),
#   'name': 'Fliqz',
#   'category_code': 'games_video',
#   'founded_year': 2005,
#   'total_money_raised': '$12.2M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.289498, 37.848641]}},
#  {'_id': ObjectId('5dd5b0ccafee9fc7eb027617'),
#   'name': 'Roku',
#   'category_code': 'hardware',
#   'founded_year': 2002,
#   'total_money_raised': '$127M',
#   'geolocation': {'type': 'Point', 'coordinates': [-122.002271, 37.279969]}},
#  ...]

# %% [markdown]
# # offices, starbucks and vegan restaurants located in New York

# %%
map_city=folium.Map(location=[40.707954, -74.011114], zoom_start=12)

for branch in starbucks:
    folium.Marker(branch['geolocation']['coordinates'][::-1],
                    radius=5000,
                    icon=folium.Icon(icon='cloud',color='red'), 
                   ).add_to(map_city)

for company in mycompanies:
    folium.Marker(company['geolocation']['coordinates'][::-1],
                 radius = 1000, 
                 icon = folium.Icon(icon = 'cloud', color = 'blue'),
                 ).add_to(map_city)

for rest in vegan:
    folium.Marker(rest['geolocation']['coordinates'][::-1],
                 radius = 1000, 
                 icon = folium.Icon(icon = 'cloud', color = 'green'),
                 ).add_to(map_city)

map_city
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map_city.save('map.html')
