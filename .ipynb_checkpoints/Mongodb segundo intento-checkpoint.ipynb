# %%
from pymongo import MongoClient
import pandas as pd
import re
import folium

# %%
def connectCollection(database, collection):
    client = MongoClient()
    db = client[database]
    coll = db[collection]
    return db, coll

# %%
db, coll = connectCollection('companies','companies')
print(coll.json)
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'companies'), 'companies.json')

# %%
companies = list(coll.find({"$and":
                            [{"deadpooled_year":None},
                            {"total_money_raised":{"$exists": True,"$ne":"$0"}},
                            {"offices.latitude": {"$exists": True, "$ne": None}},
                            {"offices.longitude": {"$exists": True, "$ne": None}}]},
                          {"name":1, "founded_year":1, "offices":1, "category_code":1,
                           "total_money_raised":1}))
companies
# Out:
# [{'_id': ObjectId('52cdef7c4bab8bd675297d91'),
#   'name': 'Geni',
#   'category_code': 'web',
#   'founded_year': 2006,
#   'total_money_raised': '$16.5M',
#   'offices': [{'description': 'Headquarters',
#     'address1': '9229 W. Sunset Blvd.',
#     'address2': '',
#     'zip_code': '90069',
#     'city': 'West Hollywood',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 34.090368,
#     'longitude': -118.393064}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297d96'),
#   'name': 'Gizmoz',
#   'category_code': 'web',
#   'founded_year': 2003,
#   'total_money_raised': '$18.1M',
#   'offices': [{'description': None,
#     'address1': None,
#     'address2': None,
#     'zip_code': None,
#     'city': 'Menlo Park',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.48413,
#     'longitude': -122.169472}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297d8d'),
#   'name': 'Digg',
#   'category_code': 'news',
#   'founded_year': 2004,
#   'total_money_raised': '$45M',
#   'offices': [{'description': None,
#     'address1': '135 Mississippi St',
#     'address2': '',
#     'zip_code': '94107',
#     'city': 'San Francisco',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.764726,
#     'longitude': -122.394523}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297d99'),
#   'name': 'Lala',
#   'category_code': 'games_video',
#   'founded_year': None,
#   'total_money_raised': '$44.2M',
#   'offices': [{'description': 'Lala Headquarters',
#     'address1': '209 Hamilton Ave',
#     'address2': 'Suite #200',
#     'zip_code': '94301',
#     'city': 'Palo Alto',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.451151,
#     'longitude': -122.154369}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297d98'),
#   'name': 'Slacker',
#   'category_code': 'music',
#   'founded_year': 2006,
#   'total_money_raised': '$73.1M',
#   'offices': [{'description': '',
#     'address1': '16935 W. Bernardo Dr. Suite 101',
#     'address2': '',
#     'zip_code': '92127',
#     'city': 'San Diego',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 33.022176,
#     'longitude': -117.081406}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297d9c'),
#   'name': 'MeetMoi',
#   'category_code': 'social',
#   'founded_year': 2007,
#   'total_money_raised': '$5.58M',
#   'offices': [{'description': None,
#     'address1': '',
#     'address2': '',
#     'zip_code': '',
#     'city': 'New York City',
#     'state_code': 'NY',
#     'country_code': 'USA',
#     'latitude': 40.757929,
#     'longitude': -73.985506}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297d9d'),
#   'name': 'Joost',
#   'category_code': 'games_video',
#   'founded_year': 2006,
#   'total_money_raised': '$45M',
#   'offices': [{'description': '',
#     'address1': '100 5th Ave Fl 6',
#     'address2': '',
#     'zip_code': '10011-6903',
#     'city': 'New York',
#     'state_code': 'NY',
#     'country_code': 'USA',
#     'latitude': 40.7464969,
#     'longitude': -74.0094471}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297d97'),
#   'name': 'Scribd',
#   'category_code': 'news',
#   'founded_year': 2007,
#   'total_money_raised': '$25.8M',
#   'offices': [{'description': 'HQ',
#     'address1': '539 Bryant Street',
#     'address2': '',
#     'zip_code': '94107',
#     'city': 'San Francisco',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.789634,
#     'longitude': -122.404052}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297da1'),
#   'name': 'Plaxo',
#   'category_code': 'web',
#   'founded_year': 2002,
#   'total_money_raised': '$28.3M',
#   'offices': [{'description': 'HQ',
#     'address1': '1050 Enterprise Way, 5th floor',
#     'address2': '',
#     'zip_code': '94089',
#     'city': 'Sunnyvale',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.387845,
#     'longitude': -122.055197}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297d94'),
#   'name': 'Twitter',
#   'category_code': 'social',
#   'founded_year': 2006,
#   'total_money_raised': '$1.16B',
#   'offices': [{'description': '',
#     'address1': '1355 Market St.',
#     'address2': '',
#     'zip_code': '94103',
#     'city': 'San Francisco',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.7768052,
#     'longitude': -122.4169244}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297d8e'),
#   'name': 'Facebook',
#   'category_code': 'social',
#   'founded_year': 2004,
#   'total_money_raised': '$2.43B',
#   'offices': [{'description': 'Headquarters',
#     'address1': '1601 Willow Road',
#     'address2': '',
#     'zip_code': '94025',
#     'city': 'Menlo Park',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.41605,
#     'longitude': -122.151801},
#    {'description': 'Europe HQ',
#     'address1': '',
#     'address2': '',
#     'zip_code': '',
#     'city': 'Dublin',
#     'state_code': None,
#     'country_code': 'IRL',
#     'latitude': 53.344104,
#     'longitude': -6.267494},
#    {'description': 'New York',
#     'address1': '340 Madison Ave',
#     'address2': '',
#     'zip_code': '10017',
#     'city': 'New York',
#     'state_code': 'NY',
#     'country_code': 'USA',
#     'latitude': 40.7557162,
#     'longitude': -73.9792469}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297da4'),
#   'name': 'Powerset',
#   'category_code': 'search',
#   'founded_year': 2006,
#   'total_money_raised': '$22.5M',
#   'offices': [{'description': None,
#     'address1': '475 Brannan St',
#     'address2': '',
#     'zip_code': '94107',
#     'city': 'San Francisco',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.778613,
#     'longitude': -122.395289}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297da5'),
#   'name': 'Technorati',
#   'category_code': 'advertising',
#   'founded_year': 2002,
#   'total_money_raised': '$32.1M',
#   'offices': [{'description': '',
#     'address1': '360 Post St. Ste. 1100',
#     'address2': '',
#     'zip_code': '94108',
#     'city': 'San Francisco',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.779558,
#     'longitude': -122.393041}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297d9b'),
#   'name': 'eBay',
#   'category_code': 'web',
#   'founded_year': 1995,
#   'total_money_raised': '$6.7M',
#   'offices': [{'description': 'Headquarters',
#     'address1': '2145 Hamilton Avenue',
#     'address2': '',
#     'zip_code': '95125',
#     'city': 'San Jose',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.295005,
#     'longitude': -121.930035}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297dab'),
#   'name': 'Kyte',
#   'category_code': 'games_video',
#   'founded_year': 2006,
#   'total_money_raised': '$23.4M',
#   'offices': [{'description': None,
#     'address1': '442 Post Street',
#     'address2': '10th Floor',
#     'zip_code': '94102',
#     'city': 'San Francisco',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.788482,
#     'longitude': -122.409173}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297da9'),
#   'name': 'Mahalo',
#   'category_code': 'web',
#   'founded_year': 2007,
#   'total_money_raised': '$21M',
#   'offices': [{'description': '',
#     'address1': '3525 Eastham Dr.',
#     'address2': '',
#     'zip_code': '90232',
#     'city': 'Culver City',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 34.017606,
#     'longitude': -118.487267}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297dac'),
#   'name': 'Veoh',
#   'category_code': 'games_video',
#   'founded_year': 2004,
#   'total_money_raised': '$69.8M',
#   'offices': [{'description': '',
#     'address1': '10180 Telesis Court Suite',
#     'address2': 'Suite  400',
#     'zip_code': '92121',
#     'city': 'San Diego',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 32.902266,
#     'longitude': -117.20834}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297db0'),
#   'name': 'Info',
#   'category_code': 'web',
#   'founded_year': None,
#   'total_money_raised': '$8.4M',
#   'offices': [{'description': None,
#     'address1': '180 North Stetson Avenue',
#     'address2': 'Suite 3500',
#     'zip_code': '60601',
#     'city': 'Chicago',
#     'state_code': 'IL',
#     'country_code': 'USA',
#     'latitude': 41.885619,
#     'longitude': -87.622309}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297db1'),
#   'name': 'JotSpot',
#   'category_code': 'web',
#   'founded_year': None,
#   'total_money_raised': '$5.2M',
#   'offices': [{'description': None,
#     'address1': '',
#     'address2': '',
#     'zip_code': '',
#     'city': 'Palo Alto',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.437328,
#     'longitude': -122.159928}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297daf'),
#   'name': 'Jingle Networks',
#   'category_code': 'mobile',
#   'founded_year': 2005,
#   'total_money_raised': '$88.7M',
#   'offices': [{'description': '',
#     'address1': '475 Park Ave South',
#     'address2': '10th Floor',
#     'zip_code': '10016',
#     'city': 'New York',
#     'state_code': 'NY',
#     'country_code': 'USA',
#     'latitude': 37.480999,
#     'longitude': -122.173887}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297db5'),
#   'name': 'LifeLock',
#   'category_code': 'security',
#   'founded_year': 2005,
#   'total_money_raised': '$178M',
#   'offices': [{'description': '',
#     'address1': '60 E. Rio Salado Pkwy, Suite 400',
#     'address2': '',
#     'zip_code': '85281',
#     'city': 'Tempe',
#     'state_code': 'AZ',
#     'country_code': 'USA',
#     'latitude': 33.429859,
#     'longitude': -111.938739}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297db2'),
#   'name': 'Meetup',
#   'category_code': 'web',
#   'founded_year': 2002,
#   'total_money_raised': '$18.3M',
#   'offices': [{'description': None,
#     'address1': '632 Broadway',
#     'address2': '10th Floor',
#     'zip_code': '10012',
#     'city': 'New York',
#     'state_code': 'NY',
#     'country_code': 'USA',
#     'latitude': 40.72604,
#     'longitude': -73.995722}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297db9'),
#   'name': 'Prosper',
#   'category_code': 'finance',
#   'founded_year': 2006,
#   'total_money_raised': '$120M',
#   'offices': [{'description': '',
#     'address1': '101 2nd Street',
#     'address2': '15th Floor',
#     'zip_code': '94105',
#     'city': 'San Francisco',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.78976,
#     'longitude': -122.402524}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297dbb'),
#   'name': 'Jajah',
#   'category_code': 'mobile',
#   'founded_year': 2005,
#   'total_money_raised': '$33M',
#   'offices': [{'description': 'Jajah HQ',
#     'address1': '2513 Charleston Road',
#     'address2': 'Suite 102',
#     'zip_code': '94043',
#     'city': 'Mountain View',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.4233896,
#     'longitude': -122.0899512}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297dbf'),
#   'name': 'blogTV',
#   'category_code': 'games_video',
#   'founded_year': 2006,
#   'total_money_raised': '$3M',
#   'offices': [{'description': 'Headquarters',
#     'address1': '30 Ben Gurion St.',
#     'address2': '',
#     'zip_code': '52573',
#     'city': 'Ramat Gan',
#     'state_code': None,
#     'country_code': 'ISR',
#     'latitude': 31.046051,
#     'longitude': 34.851612}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297dc0'),
#   'name': 'Livestream',
#   'category_code': 'games_video',
#   'founded_year': 2007,
#   'total_money_raised': '$14.7M',
#   'offices': [{'description': 'Livestream HQ',
#     'address1': '111 8th Avenue, #1509',
#     'address2': '',
#     'zip_code': '10011',
#     'city': 'New York',
#     'state_code': 'NY',
#     'country_code': 'USA',
#     'latitude': 40.726155,
#     'longitude': -73.995625}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297dc2'),
#   'name': 'AdaptiveBlue',
#   'category_code': 'games_video',
#   'founded_year': 2007,
#   'total_money_raised': '$24M',
#   'offices': [{'description': '',
#     'address1': '131 Varick St',
#     'address2': '',
#     'zip_code': '10013',
#     'city': 'NYC',
#     'state_code': 'NY',
#     'country_code': 'USA',
#     'latitude': 40.801358,
#     'longitude': -74.3372}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297dc3'),
#   'name': 'Pando Networks',
#   'category_code': 'games_video',
#   'founded_year': 2004,
#   'total_money_raised': '$11M',
#   'offices': [{'description': None,
#     'address1': '520 Broadway',
#     'address2': '10th Floor',
#     'zip_code': '10012',
#     'city': 'New York',
#     'state_code': 'NY',
#     'country_code': 'USA',
#     'latitude': 40.722655,
#     'longitude': -73.99873}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297dbd'),
#   'name': 'YouTube',
#   'category_code': 'games_video',
#   'founded_year': 2005,
#   'total_money_raised': '$11.5M',
#   'offices': [{'description': 'Corporate Headquarters',
#     'address1': '901 Cherry Ave',
#     'address2': '',
#     'zip_code': '94066',
#     'city': 'San Bruno',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.627971,
#     'longitude': -122.426804}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297dc5'),
#   'name': 'GrandCentral',
#   'category_code': 'mobile',
#   'founded_year': 2006,
#   'total_money_raised': '$4M',
#   'offices': [{'description': None,
#     'address1': '48389 Fremont Blvd., Suite #110',
#     'address2': None,
#     'zip_code': '94538',
#     'city': 'Fremont',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.465645,
#     'longitude': -121.932202}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297dc8'),
#   'name': 'Topix',
#   'category_code': 'web',
#   'founded_year': 2002,
#   'total_money_raised': '$15M',
#   'offices': [{'description': None,
#     'address1': None,
#     'address2': None,
#     'zip_code': '94301',
#     'city': 'Palo Alto',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.44296,
#     'longitude': -122.151198}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297dc9'),
#   'name': 'Jobster',
#   'category_code': 'search',
#   'founded_year': 2004,
#   'total_money_raised': '$52.5M',
#   'offices': [{'description': None,
#     'address1': '3131 Elliott Avenue Suite 600',
#     'address2': None,
#     'zip_code': '98121',
#     'city': 'Seattle',
#     'state_code': 'WA',
#     'country_code': 'USA',
#     'latitude': 47.617682,
#     'longitude': -122.357242}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297dcd'),
#   'name': 'CriticalMetrics',
#   'category_code': 'web',
#   'founded_year': 2007,
#   'total_money_raised': '$100k',
#   'offices': [{'description': None,
#     'address1': None,
#     'address2': None,
#     'zip_code': None,
#     'city': None,
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.269175,
#     'longitude': -119.306607}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297dcf'),
#   'name': 'Spock',
#   'category_code': 'search',
#   'founded_year': 2006,
#   'total_money_raised': '$7M',
#   'offices': [{'description': 'QLL COMMUNICATIONS',
#     'address1': 'P.O. BOX 150',
#     'address2': '',
#     'zip_code': '13457',
#     'city': 'SCHUYLER LAKE',
#     'state_code': 'NY',
#     'country_code': 'USA',
#     'latitude': 37.488336,
#     'longitude': -122.217964}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297dcb'),
#   'name': 'Revision3',
#   'category_code': 'games_video',
#   'founded_year': 2005,
#   'total_money_raised': '$9M',
#   'offices': [{'description': 'HQ',
#     'address1': '2415 3rd St',
#     'address2': '',
#     'zip_code': '94107',
#     'city': 'San Francisco',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.757758,
#     'longitude': -122.388243}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297dd0'),
#   'name': 'Wize',
#   'category_code': 'ecommerce',
#   'founded_year': 2006,
#   'total_money_raised': '$4.99M',
#   'offices': [{'description': '',
#     'address1': '1110 Burlingame Ave',
#     'address2': 'Suite 300',
#     'zip_code': '94010',
#     'city': 'Burlingame',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.559287,
#     'longitude': -122.302262}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297dd1'),
#   'name': 'SodaHead',
#   'category_code': 'web',
#   'founded_year': 2007,
#   'total_money_raised': '$12.7M',
#   'offices': [{'description': '',
#     'address1': '16161 Ventura Blvd.',
#     'address2': 'Suite C PMB 461',
#     'zip_code': '91436',
#     'city': 'Encino',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.269175,
#     'longitude': -119.306607}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297dd3'),
#   'name': 'iSkoot',
#   'category_code': 'mobile',
#   'founded_year': 2005,
#   'total_money_raised': '$32.2M',
#   'offices': [{'description': None,
#     'address1': None,
#     'address2': None,
#     'zip_code': None,
#     'city': 'Cambridge',
#     'state_code': 'MA',
#     'country_code': 'USA',
#     'latitude': 42.375392,
#     'longitude': -71.118487},
#    {'description': 'iSkoot HQ',
#     'address1': '501 2nd Street',
#     'address2': 'Suite 216',
#     'zip_code': '94107',
#     'city': 'San Francisco',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.780134,
#     'longitude': -122.396744}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297dd2'),
#   'name': 'CastTV',
#   'category_code': 'games_video',
#   'founded_year': 2006,
#   'total_money_raised': '$3.1M',
#   'offices': [{'description': None,
#     'address1': '374 Brannan St.',
#     'address2': None,
#     'zip_code': '94107',
#     'city': 'San Francisco',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.780716,
#     'longitude': -122.393913}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297dd8'),
#   'name': 'Funny Or Die',
#   'category_code': 'games_video',
#   'founded_year': 2007,
#   'total_money_raised': '$18M',
#   'offices': [{'description': 'Head Quarters',
#     'address1': '167 2nd Ave',
#     'address2': '',
#     'zip_code': '94401',
#     'city': 'San Mateo',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.421621,
#     'longitude': -122.137444}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297ddb'),
#   'name': 'MeeVee',
#   'category_code': 'games_video',
#   'founded_year': 2000,
#   'total_money_raised': '$25M',
#   'offices': [{'description': None,
#     'address1': '500 Airport Blvd., Suite 400',
#     'address2': None,
#     'zip_code': '94010',
#     'city': 'Burlingame',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.590339,
#     'longitude': -122.341715}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297de6'),
#   'name': 'Wakoopa',
#   'category_code': 'web',
#   'founded_year': 2007,
#   'total_money_raised': '$1M',
#   'offices': [{'description': 'Arts & Crafts',
#     'address1': 'Damrak 70, 254',
#     'address2': '',
#     'zip_code': '1012LM',
#     'city': 'Amsterdam',
#     'state_code': None,
#     'country_code': 'NLD',
#     'latitude': 52.3745228,
#     'longitude': 4.8948623}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297de0'),
#   'name': 'Yelp',
#   'category_code': 'search',
#   'founded_year': 2004,
#   'total_money_raised': '$90M',
#   'offices': [{'description': '',
#     'address1': '706 Mission Street',
#     'address2': '7th Floor',
#     'zip_code': '94103',
#     'city': 'San Francisco',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.786183,
#     'longitude': -122.402195}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297da2'),
#   'name': 'Cisco',
#   'category_code': 'network_hosting',
#   'founded_year': 1984,
#   'total_money_raised': '$2.5M',
#   'offices': [{'description': 'Headquarters',
#     'address1': '170 West Tasman Dr.',
#     'address2': '',
#     'zip_code': '95134',
#     'city': 'San Jose',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.408802,
#     'longitude': -121.95377}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297deb'),
#   'name': 'SideStep',
#   'category_code': 'web',
#   'founded_year': 1999,
#   'total_money_raised': '$32M',
#   'offices': [{'description': None,
#     'address1': '2980 Bowers Ave.',
#     'address2': None,
#     'zip_code': '95051',
#     'city': 'Santa Clara',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.374998,
#     'longitude': -121.977853}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297ded'),
#   'name': 'Farecast',
#   'category_code': 'search',
#   'founded_year': 2003,
#   'total_money_raised': '$20.6M',
#   'offices': [{'description': None,
#     'address1': '200 West Thomas Street, Suite 300',
#     'address2': '',
#     'zip_code': '98119',
#     'city': 'Seattle',
#     'state_code': 'WA',
#     'country_code': 'USA',
#     'latitude': 47.620982,
#     'longitude': -122.359397}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297df2'),
#   'name': 'Pageflakes',
#   'category_code': 'web',
#   'founded_year': 2006,
#   'total_money_raised': '$4.1M',
#   'offices': [{'description': None,
#     'address1': '795 Folsom St',
#     'address2': '1st Floor',
#     'zip_code': '94114',
#     'city': 'San Francisco',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.758113,
#     'longitude': -122.414689}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297df0'),
#   'name': 'RockYou',
#   'category_code': 'games_video',
#   'founded_year': 2005,
#   'total_money_raised': '$136M',
#   'offices': [{'description': '',
#     'address1': '585 Broadway',
#     'address2': 'Suite A',
#     'zip_code': '94063',
#     'city': 'Redwood City',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.484619,
#     'longitude': -122.206893}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297def'),
#   'name': 'KickApps',
#   'category_code': 'enterprise',
#   'founded_year': 2004,
#   'total_money_raised': '$32M',
#   'offices': [{'description': 'Headquarters',
#     'address1': '26 W 17th Street',
#     'address2': '2nd Floor',
#     'zip_code': '10011',
#     'city': 'New York',
#     'state_code': 'NY',
#     'country_code': 'USA',
#     'latitude': 40.7516611,
#     'longitude': -73.9843328},
#    {'description': 'Los Angeles Office',
#     'address1': '1212 Abbott Kinney Blvd',
#     'address2': 'Suite B',
#     'zip_code': '90291',
#     'city': 'Venice',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 33.991101,
#     'longitude': -118.468707},
#    {'description': 'San Francisco Office',
#     'address1': '607 Market St',
#     'address2': 'Suite 5',
#     'zip_code': '94105',
#     'city': 'San Francisco',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.7891086,
#     'longitude': -122.4016144},
#    {'description': 'UK Office',
#     'address1': '212 Picadilly',
#     'address2': '',
#     'zip_code': 'W1J 9HF',
#     'city': 'London',
#     'state_code': None,
#     'country_code': 'GBR',
#     'latitude': 51.5094731,
#     'longitude': -0.1356235}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297dfb'),
#   'name': 'WeFi',
#   'category_code': 'mobile',
#   'founded_year': 2006,
#   'total_money_raised': '$10M',
#   'offices': [{'description': None,
#     'address1': '12587 Fair Lakes Circle',
#     'address2': 'Suite 252',
#     'zip_code': '22033',
#     'city': 'Fairfax',
#     'state_code': 'VA',
#     'country_code': 'USA',
#     'latitude': 37.09024,
#     'longitude': -95.712891}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297e00'),
#   'name': 'TVtrip',
#   'category_code': 'web',
#   'founded_year': 2007,
#   'total_money_raised': '$13.8M',
#   'offices': [{'description': None,
#     'address1': '',
#     'address2': '',
#     'zip_code': '',
#     'city': 'Paris',
#     'state_code': None,
#     'country_code': 'FRA',
#     'latitude': 48.856667,
#     'longitude': 2.350987}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297dfe'),
#   'name': 'FeedBurner',
#   'category_code': 'web',
#   'founded_year': 2004,
#   'total_money_raised': '$8M',
#   'offices': [{'description': None,
#     'address1': '20 W Kinzie',
#     'address2': '9th Floor',
#     'zip_code': '60610',
#     'city': 'Chicago',
#     'state_code': 'IL',
#     'country_code': 'USA',
#     'latitude': 41.889474,
#     'longitude': -87.628912}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297e01'),
#   'name': 'Zazzle',
#   'category_code': 'ecommerce',
#   'founded_year': 1999,
#   'total_money_raised': '$46M',
#   'offices': [{'description': '',
#     'address1': '1800 Seaport',
#     'address2': '',
#     'zip_code': '94063',
#     'city': 'Redwood City',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.5108541,
#     'longitude': -122.2013557}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297dff'),
#   'name': 'TheFind',
#   'category_code': 'ecommerce',
#   'founded_year': 2006,
#   'total_money_raised': '$26M',
#   'offices': [{'description': '',
#     'address1': '310 Villa Street',
#     'address2': '',
#     'zip_code': '94041',
#     'city': 'Mountain View',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.391502,
#     'longitude': -122.073463}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297e02'),
#   'name': 'Dogster',
#   'category_code': 'web',
#   'founded_year': 2004,
#   'total_money_raised': '$1M',
#   'offices': [{'description': None,
#     'address1': '555 De Haro Street, #350',
#     'address2': '',
#     'zip_code': '',
#     'city': 'San Francisco',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.762681,
#     'longitude': -122.400909}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297e08'),
#   'name': 'Loomia',
#   'category_code': 'web',
#   'founded_year': 2004,
#   'total_money_raised': '$7.5M',
#   'offices': [{'description': None,
#     'address1': '900 Kearny St, Suite 299',
#     'address2': None,
#     'zip_code': '94133',
#     'city': 'San Francisco',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.796396,
#     'longitude': -122.404869}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297df7'),
#   'name': 'Bebo',
#   'category_code': 'web',
#   'founded_year': 2005,
#   'total_money_raised': '$15M',
#   'offices': [{'description': '',
#     'address1': '425 Bush Street',
#     'address2': 'Suite 200',
#     'zip_code': '94108',
#     'city': 'San Francisco',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.782103,
#     'longitude': -122.401116}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297e0d'),
#   'name': 'FlickIM',
#   'category_code': 'mobile',
#   'founded_year': 2006,
#   'total_money_raised': '$1.6M',
#   'offices': [{'description': 'HQ',
#     'address1': '2030 Addison St.',
#     'address2': 'Suite 620',
#     'zip_code': '',
#     'city': 'Berkeley',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.870744,
#     'longitude': -122.269259}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297e0b'),
#   'name': 'Newsvine',
#   'category_code': 'web',
#   'founded_year': 2005,
#   'total_money_raised': '$1.25M',
#   'offices': [{'description': None,
#     'address1': '101 Elliott Ave. West',
#     'address2': 'Suite 120',
#     'zip_code': '98119',
#     'city': 'Seattle',
#     'state_code': 'WA',
#     'country_code': 'USA',
#     'latitude': 47.618599,
#     'longitude': -122.358484}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297e0f'),
#   'name': 'Terabitz',
#   'category_code': 'web',
#   'founded_year': 2006,
#   'total_money_raised': '$10M',
#   'offices': [{'description': 'HQ',
#     'address1': '5 Palo Alto Sq Ste 220',
#     'address2': '',
#     'zip_code': '94306-2123',
#     'city': 'Palo Alto',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.437328,
#     'longitude': -122.159928}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297e0a'),
#   'name': 'Eventbrite',
#   'category_code': 'web',
#   'founded_year': 2006,
#   'total_money_raised': '$140M',
#   'offices': [{'description': 'HQ',
#     'address1': '651 Brannan',
#     'address2': 'Suite 110',
#     'zip_code': '94107',
#     'city': 'San Francisco',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.779507,
#     'longitude': -122.39071}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297e11'),
#   'name': 'iLike',
#   'category_code': 'games_video',
#   'founded_year': 2002,
#   'total_money_raised': '$16.5M',
#   'offices': [{'description': None,
#     'address1': '1605 Boylston Ave, Suite 202',
#     'address2': '',
#     'zip_code': '98122',
#     'city': 'Seattle',
#     'state_code': 'WA',
#     'country_code': 'USA',
#     'latitude': 47.615313,
#     'longitude': -122.323408}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297da3'),
#   'name': 'Yahoo!',
#   'category_code': 'web',
#   'founded_year': 1994,
#   'total_money_raised': '$6.8M',
#   'offices': [{'description': None,
#     'address1': '701 First Avenue',
#     'address2': '',
#     'zip_code': '94089',
#     'city': 'Sunnyvale',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.418531,
#     'longitude': -122.025485}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297e17'),
#   'name': 'Kaboodle',
#   'category_code': 'ecommerce',
#   'founded_year': 2005,
#   'total_money_raised': '$5M',
#   'offices': [{'description': '',
#     'address1': '640 W. California Ave.',
#     'address2': 'Suite 220',
#     'zip_code': '94041',
#     'city': 'Sunnyvale',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.382162,
#     'longitude': -122.036301}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297e1a'),
#   'name': 'Wink',
#   'category_code': 'search',
#   'founded_year': 2004,
#   'total_money_raised': '$6.2M',
#   'offices': [{'description': '',
#     'address1': '',
#     'address2': '',
#     'zip_code': '94041',
#     'city': 'Mountain View',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.40047,
#     'longitude': -122.072981}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297e15'),
#   'name': 'Conduit',
#   'category_code': 'advertising',
#   'founded_year': 2005,
#   'total_money_raised': '$110M',
#   'offices': [{'description': '',
#     'address1': '950 Tower Lane',
#     'address2': 'Suite 1788',
#     'zip_code': '94404',
#     'city': 'Foster City',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.561877,
#     'longitude': -122.325248}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297e18'),
#   'name': 'GigaOM',
#   'category_code': 'news',
#   'founded_year': 2006,
#   'total_money_raised': '$14.3M',
#   'offices': [{'description': None,
#     'address1': '',
#     'address2': '',
#     'zip_code': '',
#     'city': 'San Francisco',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.775196,
#     'longitude': -122.419204},
#    {'description': '',
#     'address1': '',
#     'address2': '',
#     'zip_code': '',
#     'city': 'New York',
#     'state_code': 'NY',
#     'country_code': 'USA',
#     'latitude': 40.7143528,
#     'longitude': -74.0059731}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297e10'),
#   'name': 'Box',
#   'category_code': 'network_hosting',
#   'founded_year': 2005,
#   'total_money_raised': '$409M',
#   'offices': [{'description': 'HQ',
#     'address1': '4440 El Camino Real',
#     'address2': '',
#     'zip_code': '94022',
#     'city': 'Los Altos',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.425801,
#     'longitude': -122.143701}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297e0c'),
#   'name': 'LinkedIn',
#   'category_code': 'social',
#   'founded_year': 2003,
#   'total_money_raised': '$200M',
#   'offices': [{'description': 'HQ',
#     'address1': '2029 Stierlin Ct',
#     'address2': '',
#     'zip_code': '94043',
#     'city': 'Mountain View',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.423258,
#     'longitude': -122.073635}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297e19'),
#   'name': 'Redfin',
#   'category_code': 'real_estate',
#   'founded_year': 2004,
#   'total_money_raised': '$96.8M',
#   'offices': [{'description': '',
#     'address1': '2025 1st Ave',
#     'address2': 'Suite 600',
#     'zip_code': '98121',
#     'city': 'Seattle',
#     'state_code': 'WA',
#     'country_code': 'USA',
#     'latitude': 47.603122,
#     'longitude': -122.333253}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297e20'),
#   'name': 'Zvents',
#   'category_code': 'web',
#   'founded_year': 2005,
#   'total_money_raised': '$31.2M',
#   'offices': [{'description': None,
#     'address1': '1875 South Grant Street',
#     'address2': 'Suite 800',
#     'zip_code': None,
#     'city': 'San Mateo',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.553121,
#     'longitude': -122.301534}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297e1d'),
#   'name': 'Seesmic',
#   'category_code': 'web',
#   'founded_year': 2007,
#   'total_money_raised': '$16M',
#   'offices': [{'description': '',
#     'address1': '1550 Bryant Street',
#     'address2': 'Suite 890',
#     'zip_code': '94103',
#     'city': 'San Francisco',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.775196,
#     'longitude': -122.419204}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297e14'),
#   'name': 'Carbonite',
#   'category_code': 'network_hosting',
#   'founded_year': 2006,
#   'total_money_raised': '$66M',
#   'offices': [{'description': 'Headquarters',
#     'address1': '',
#     'address2': '',
#     'zip_code': '02116',
#     'city': 'Boston',
#     'state_code': 'MA',
#     'country_code': 'USA',
#     'latitude': 42.350571,
#     'longitude': -71.076869}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297e25'),
#   'name': 'Oodle',
#   'category_code': 'social',
#   'founded_year': 2004,
#   'total_money_raised': '$23.1M',
#   'offices': [{'description': None,
#     'address1': '60 E. 3rd Ave.',
#     'address2': 'Suite 410',
#     'zip_code': '94410',
#     'city': 'San Mateo',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.563585,
#     'longitude': -122.324621}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297e27'),
#   'name': 'Simply Hired',
#   'category_code': 'search',
#   'founded_year': 2004,
#   'total_money_raised': '$22.3M',
#   'offices': [{'description': 'HQ',
#     'address1': '370 San Aleso Ave',
#     'address2': 'Ste. 200',
#     'zip_code': '94085',
#     'city': 'Sunnyvale',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.4219165,
#     'longitude': -122.0780632}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297e26'),
#   'name': 'oDesk',
#   'category_code': 'web',
#   'founded_year': 2005,
#   'total_money_raised': '$44M',
#   'offices': [{'description': '',
#     'address1': '901 Marshall Street',
#     'address2': 'Suite 200',
#     'zip_code': '94063',
#     'city': 'Redwood City',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.479952,
#     'longitude': -122.178557}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297e29'),
#   'name': 'Scripps Networks Interactive',
#   'category_code': 'web',
#   'founded_year': 1994,
#   'total_money_raised': '$10M',
#   'offices': [{'description': None,
#     'address1': 'Scripps Networks',
#     'address2': 'P.O. Box 51850',
#     'zip_code': '37950',
#     'city': 'Knoxville',
#     'state_code': 'TN',
#     'country_code': 'USA',
#     'latitude': 37.09024,
#     'longitude': -95.712891}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297e28'),
#   'name': 'ooma',
#   'category_code': 'hardware',
#   'founded_year': 2004,
#   'total_money_raised': '$81.3M',
#   'offices': [{'description': '',
#     'address1': '1840 Embarcadero Road',
#     'address2': '',
#     'zip_code': '94303',
#     'city': 'Palo Alto',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.451958,
#     'longitude': -122.116026}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297e30'),
#   'name': 'GoingOn',
#   'category_code': 'software',
#   'founded_year': 2008,
#   'total_money_raised': '$8.5M',
#   'offices': [{'description': 'GoingOn Networks, Inc.',
#     'address1': '450 Sansome Street',
#     'address2': '12th Floor',
#     'zip_code': '94111',
#     'city': 'San Francisco',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.782263,
#     'longitude': -122.392142}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297e31'),
#   'name': 'Flixster',
#   'category_code': 'web',
#   'founded_year': 2006,
#   'total_money_raised': '$7.18M',
#   'offices': [{'description': '',
#     'address1': '208 Utah St',
#     'address2': '',
#     'zip_code': '94103',
#     'city': 'San Francisco',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.766909,
#     'longitude': -122.406676}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297e34'),
#   'name': 'Piczo',
#   'category_code': 'network_hosting',
#   'founded_year': 1990,
#   'total_money_raised': '$11M',
#   'offices': [{'description': None,
#     'address1': '150 California Street',
#     'address2': 'Suite 1000',
#     'zip_code': '94111',
#     'city': 'San Francisco',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.793703,
#     'longitude': -122.398479}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297e3a'),
#   'name': 'Spreadshirt',
#   'category_code': 'advertising',
#   'founded_year': 2002,
#   'total_money_raised': '$12.7M',
#   'offices': [{'description': None,
#     'address1': '211 Fort Pitt Blvd',
#     'address2': '2nd Floor',
#     'zip_code': '15222',
#     'city': 'Pittsburgh',
#     'state_code': 'PA',
#     'country_code': 'USA',
#     'latitude': 40.437985,
#     'longitude': -80.004195}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297e3d'),
#   'name': 'IceRocket',
#   'category_code': 'search',
#   'founded_year': 2004,
#   'total_money_raised': '$300k',
#   'offices': [{'description': None,
#     'address1': None,
#     'address2': None,
#     'zip_code': None,
#     'city': 'Dallas',
#     'state_code': 'TX',
#     'country_code': 'USA',
#     'latitude': 32.781078,
#     'longitude': -96.797111}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297e3e'),
#   'name': 'spigit',
#   'category_code': 'software',
#   'founded_year': 2006,
#   'total_money_raised': '$55.6M',
#   'offices': [{'description': '',
#     'address1': '311 Ray Street',
#     'address2': '',
#     'zip_code': '94566',
#     'city': 'Pleasanton',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.6637279,
#     'longitude': -121.8731805},
#    {'description': 'One Freedom Drive',
#     'address1': '11951 Freedom Drive',
#     'address2': '13 FL',
#     'zip_code': '20190',
#     'city': 'Reston',
#     'state_code': 'VA',
#     'country_code': 'USA',
#     'latitude': 38.9590083,
#     'longitude': -77.3592746},
#    {'description': '',
#     'address1': '10 Margaret Street',
#     'address2': '',
#     'zip_code': 'W1W 8RL',
#     'city': 'London',
#     'state_code': None,
#     'country_code': 'GBR',
#     'latitude': 51.5170385,
#     'longitude': -0.1394759}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297e3b'),
#   'name': 'Socialtext',
#   'category_code': 'enterprise',
#   'founded_year': 2002,
#   'total_money_raised': '$46.8M',
#   'offices': [{'description': None,
#     'address1': '655 High Street',
#     'address2': None,
#     'zip_code': '94301',
#     'city': 'Palo Alto',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.442949,
#     'longitude': -122.1615}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297e3c'),
#   'name': 'Bazaarvoice',
#   'category_code': 'software',
#   'founded_year': 2005,
#   'total_money_raised': '$131M',
#   'offices': [{'description': 'Head Office',
#     'address1': '3900 N Capital of Texas Hwy',
#     'address2': '',
#     'zip_code': '78746',
#     'city': 'Austin',
#     'state_code': 'TX',
#     'country_code': 'USA',
#     'latitude': 30.407545,
#     'longitude': -97.717667}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297e40'),
#   'name': 'PowerReviews',
#   'category_code': 'social',
#   'founded_year': None,
#   'total_money_raised': '$40.1M',
#   'offices': [{'description': 'US Office',
#     'address1': '22 4th Street',
#     'address2': '6th Floor',
#     'zip_code': '94103',
#     'city': 'San Francisco',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.779558,
#     'longitude': -122.393041},
#    {'description': 'UK Office',
#     'address1': '145-157 St John Street',
#     'address2': '2nd Floor',
#     'zip_code': 'EC1V 4PY',
#     'city': 'London',
#     'state_code': None,
#     'country_code': 'GBR',
#     'latitude': 51.527099,
#     'longitude': -0.104408}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297e44'),
#   'name': 'hi5',
#   'category_code': 'games_video',
#   'founded_year': 2003,
#   'total_money_raised': '$52M',
#   'offices': [{'description': '',
#     'address1': '55 Second Street',
#     'address2': 'Suite 400',
#     'zip_code': '94105',
#     'city': 'San Francisco',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.788668,
#     'longitude': -122.400558}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297e47'),
#   'name': 'ScanScout',
#   'category_code': 'advertising',
#   'founded_year': 2005,
#   'total_money_raised': '$17.5M',
#   'offices': [{'description': 'Headquarters',
#     'address1': '295 Devonshire Street, 4th floor',
#     'address2': '',
#     'zip_code': '02110',
#     'city': 'Boston',
#     'state_code': 'MA',
#     'country_code': 'USA',
#     'latitude': 42.340889,
#     'longitude': -71.051931},
#    {'description': 'New York Office',
#     'address1': '450 Seventh Ave, Ste 209',
#     'address2': '',
#     'zip_code': '10011',
#     'city': 'New York',
#     'state_code': 'NY',
#     'country_code': 'USA',
#     'latitude': 40.739833,
#     'longitude': -73.993158},
#    {'description': 'Los Angeles Office',
#     'address1': '11601 Wilshire Blvd',
#     'address2': '',
#     'zip_code': '90025',
#     'city': 'Los Angeles',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 34.050887,
#     'longitude': -118.459995}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297e4f'),
#   'name': 'introNetworks',
#   'category_code': 'web',
#   'founded_year': 2003,
#   'total_money_raised': '$2.7M',
#   'offices': [{'description': 'Corporate Headquarters',
#     'address1': '1280 Coast Village Circle, Suite B',
#     'address2': '',
#     'zip_code': '93108',
#     'city': 'Montecito',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 34.42071,
#     'longitude': -119.641821}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297e4b'),
#   'name': 'Jaxtr',
#   'category_code': 'mobile',
#   'founded_year': 2005,
#   'total_money_raised': '$21.5M',
#   'offices': [{'description': None,
#     'address1': '855 Oak Grove Ave.',
#     'address2': 'Suite 100',
#     'zip_code': '94025',
#     'city': 'Menlo Park',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.451026,
#     'longitude': -122.18676}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297e46'),
#   'name': 'Tagged',
#   'category_code': 'social',
#   'founded_year': 2004,
#   'total_money_raised': '$28.7M',
#   'offices': [{'description': 'San Francisco, USA',
#     'address1': 'P.O. Box 193152',
#     'address2': '',
#     'zip_code': '94119-3152',
#     'city': 'San Francisco',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.7753,
#     'longitude': -122.4186}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297e51'),
#   'name': 'Going',
#   'category_code': 'web',
#   'founded_year': None,
#   'total_money_raised': '$5M',
#   'offices': [{'description': None,
#     'address1': '8 Winter St.',
#     'address2': '6th Floor',
#     'zip_code': '02108',
#     'city': 'Boston',
#     'state_code': 'MA',
#     'country_code': 'USA',
#     'latitude': 42.355672,
#     'longitude': -71.060864}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297e4d'),
#   'name': 'NetSuite',
#   'category_code': 'enterprise',
#   'founded_year': 1998,
#   'total_money_raised': '$1.5M',
#   'offices': [{'description': None,
#     'address1': '2955 Campus Drive, Suite 100',
#     'address2': '',
#     'zip_code': '94403',
#     'city': 'San Mateo',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.536172,
#     'longitude': -122.327323}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297e54'),
#   'name': 'Respectance',
#   'category_code': 'web',
#   'founded_year': 2006,
#   'total_money_raised': '$1.75M',
#   'offices': [{'description': '',
#     'address1': '',
#     'address2': '',
#     'zip_code': '',
#     'city': 'San Mateo',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.55909,
#     'longitude': -122.321836}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297e5c'),
#   'name': 'Kiptronic',
#   'category_code': 'advertising',
#   'founded_year': 2005,
#   'total_money_raised': '$7.3M',
#   'offices': [{'description': '',
#     'address1': '300 Montgomery St.',
#     'address2': 'Ste. 860',
#     'zip_code': '94104',
#     'city': 'San Francisco',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.792394,
#     'longitude': -122.402349}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297e5a'),
#   'name': 'Grockit',
#   'category_code': 'social',
#   'founded_year': 2006,
#   'total_money_raised': '$44.7M',
#   'offices': [{'description': '',
#     'address1': '500 Third Street',
#     'address2': 'Suite 260',
#     'zip_code': '94107',
#     'city': 'San Francisco',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.775196,
#     'longitude': -122.419204}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297e58'),
#   'name': 'eBuddy',
#   'category_code': 'messaging',
#   'founded_year': 2003,
#   'total_money_raised': '€11.5M',
#   'offices': [{'description': 'Global Headquarters',
#     'address1': 'Keizersgracht 585',
#     'address2': '',
#     'zip_code': '1017 DR',
#     'city': 'Amsterdam',
#     'state_code': None,
#     'country_code': 'NLD',
#     'latitude': 52.3640933,
#     'longitude': 4.8919457},
#    {'description': 'US Headquarters',
#     'address1': '555 Post St.',
#     'address2': '',
#     'zip_code': '94102',
#     'city': 'San Francisco',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.787683,
#     'longitude': -122.410943},
#    {'description': 'Singapore office',
#     'address1': '',
#     'address2': '',
#     'zip_code': '',
#     'city': 'Singapore',
#     'state_code': None,
#     'country_code': 'SGP',
#     'latitude': 51.500152,
#     'longitude': -0.126236}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297e63'),
#   'name': 'Phonezoo',
#   'category_code': 'web',
#   'founded_year': 2006,
#   'total_money_raised': '$2.06M',
#   'offices': [{'description': '',
#     'address1': '1270 Oakmead Pkwy, Suite 214',
#     'address2': '',
#     'zip_code': '94085',
#     'city': 'Sunnyvale',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.386376,
#     'longitude': -121.991471}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297e61'),
#   'name': 'Vuze',
#   'category_code': 'games_video',
#   'founded_year': 2005,
#   'total_money_raised': '$34M',
#   'offices': [{'description': 'Headquarters',
#     'address1': '4 W. 4th Ave',
#     'address2': '',
#     'zip_code': '94402',
#     'city': 'San Mateo',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.4858654,
#     'longitude': -122.2262606}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297e66'),
#   'name': 'Wishpot',
#   'category_code': 'ecommerce',
#   'founded_year': 2006,
#   'total_money_raised': '$1.3M',
#   'offices': [{'description': 'Headquarters',
#     'address1': '911 Western Ave.',
#     'address2': 'Suite 420',
#     'zip_code': '98104',
#     'city': 'Seattle',
#     'state_code': 'WA',
#     'country_code': 'USA',
#     'latitude': 47.620716,
#     'longitude': -122.347533}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297e6b'),
#   'name': 'PodTech',
#   'category_code': 'games_video',
#   'founded_year': 2005,
#   'total_money_raised': '$7.5M',
#   'offices': [{'description': None,
#     'address1': '1801 Page Mill Rd - Suite 400',
#     'address2': None,
#     'zip_code': '94304',
#     'city': 'Palo Alto',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.408256,
#     'longitude': -122.154176}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297e6c'),
#   'name': 'NowPublic',
#   'category_code': 'web',
#   'founded_year': 2005,
#   'total_money_raised': '$12M',
#   'offices': [{'description': '',
#     'address1': '576 Seymour Street',
#     'address2': 'Suite 204',
#     'zip_code': '',
#     'city': 'Vancouver',
#     'state_code': None,
#     'country_code': 'CAN',
#     'latitude': 49.283376,
#     'longitude': -123.103986}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297e6e'),
#   'name': 'Crackle',
#   'category_code': 'games_video',
#   'founded_year': 2004,
#   'total_money_raised': '$1.75M',
#   'offices': [{'description': '',
#     'address1': '10202 W. Washington Blvd',
#     'address2': 'SPP 1127b',
#     'zip_code': '90232',
#     'city': 'Culver City',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 34.017506,
#     'longitude': -118.401579}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297e6d'),
#   'name': 'PayScale',
#   'category_code': 'software',
#   'founded_year': 1999,
#   'total_money_raised': '$31.1M',
#   'offices': [{'description': '',
#     'address1': '542 First Ave South',
#     'address2': 'Suite 400',
#     'zip_code': '98104',
#     'city': 'Seattle',
#     'state_code': 'WA',
#     'country_code': 'USA',
#     'latitude': 47.5999337,
#     'longitude': -122.3276962}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297e75'),
#   'name': 'IntenseDebate',
#   'category_code': 'web',
#   'founded_year': 2006,
#   'total_money_raised': '$515k',
#   'offices': [{'description': None,
#     'address1': None,
#     'address2': None,
#     'zip_code': None,
#     'city': 'Boulder',
#     'state_code': 'CO',
#     'country_code': 'USA',
#     'latitude': 40.010492,
#     'longitude': -105.276843}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297e78'),
#   'name': 'Rebtel',
#   'category_code': 'mobile',
#   'founded_year': 2006,
#   'total_money_raised': '$20M',
#   'offices': [{'description': 'Headquarters',
#     'address1': 'Fabrikorvagen 4',
#     'address2': '',
#     'zip_code': '131 52',
#     'city': 'Nacka Strand',
#     'state_code': None,
#     'country_code': 'SWE',
#     'latitude': 59.3167843,
#     'longitude': 18.1582777}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297e77'),
#   'name': 'Reddit',
#   'category_code': 'web',
# ...
#     'latitude': 37.4027811,
#     'longitude': -122.1441615}]},
#  {'_id': ObjectId('52cdef7d4bab8bd675298dbd'),
#   'name': 'CrimeReports',
#   'category_code': 'web',
#   'founded_year': 2007,
#   'total_money_raised': '$7.2M',
#   'offices': [{'description': '',
#     'address1': '2015 South 1100 East',
#     'address2': '',
#     'zip_code': '84106',
#     'city': 'Salt Lake City',
#     'state_code': 'UT',
#     'country_code': 'USA',
#     'latitude': 40.726342,
#     'longitude': -111.858835}]},
#  {'_id': ObjectId('52cdef7d4bab8bd675298db0'),
#   'name': 'Zenoss',
#   'category_code': 'software',
#   'founded_year': 2005,
#   'total_money_raised': '$45.6M',
#   'offices': [{'description': 'World Headquarters',
#     'address1': '275 West Street, Suite 204',
#     'address2': '',
#     'zip_code': '21401',
#     'city': 'Annapolis',
#     'state_code': 'MD',
#     'country_code': 'USA',
#     'latitude': 38.97639,
#     'longitude': -76.503171},
#    {'description': 'Development & Marketing',
#     'address1': '4807 Spicewood Springs Rd',
#     'address2': 'Building 4, Suite 201',
#     'zip_code': '78759',
#     'city': 'Austin',
#     'state_code': 'TX',
#     'country_code': 'USA',
#     'latitude': 30.379593,
#     'longitude': -97.765313}]},
#  {'_id': ObjectId('52cdef7d4bab8bd675298dc8'),
#   'name': 'Dreamsoft Technologies',
#   'category_code': 'software',
#   'founded_year': 2007,
#   'total_money_raised': '$100k',
#   'offices': [{'description': 'Manchester Office',
#     'address1': 'Rochdale',
#     'address2': '',
#     'zip_code': '',
#     'city': '',
#     'state_code': None,
#     'country_code': 'GBR',
#     'latitude': 53.616352,
#     'longitude': -2.15871}]},
#  {'_id': ObjectId('52cdef7d4bab8bd675298dcc'),
#   'name': 'Titan Gaming',
#   'category_code': 'games_video',
#   'founded_year': 2010,
#   'total_money_raised': '$1M',
#   'offices': [{'description': 'Santa Monica Office',
#     'address1': '1351 4th Street, 4th floor',
#     'address2': '',
#     'zip_code': '90401',
#     'city': 'Santa Monica',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 53.544711,
#     'longitude': -113.515769}]},
#  {'_id': ObjectId('52cdef7d4bab8bd675298ddd'),
#   'name': 'gAuto',
#   'category_code': 'ecommerce',
#   'founded_year': 2008,
#   'total_money_raised': '$350k',
#   'offices': [{'description': 'Headquarters',
#     'address1': '6619 N Scottsdale Road',
#     'address2': '',
#     'zip_code': '85250',
#     'city': 'Scottsdale',
#     'state_code': 'AZ',
#     'country_code': 'USA',
#     'latitude': 33.533027,
#     'longitude': -111.923849}]},
#  {'_id': ObjectId('52cdef7d4bab8bd675298de2'),
#   'name': 'Bandsintown',
#   'category_code': 'music',
#   'founded_year': 2007,
#   'total_money_raised': '$375k',
#   'offices': [{'description': 'San Diego Office',
#     'address1': '800 W Ivy Street, Unit C',
#     'address2': '',
#     'zip_code': '92101',
#     'city': 'San Diego',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 42.35888,
#     'longitude': -71.05682},
#    {'description': 'New York Headquarters',
#     'address1': '215 Lexington Ave',
#     'address2': '',
#     'zip_code': '10016',
#     'city': 'New York',
#     'state_code': 'NY',
#     'country_code': 'USA',
#     'latitude': 40.745337,
#     'longitude': -73.980128}]},
#  {'_id': ObjectId('52cdef7d4bab8bd675298de3'),
#   'name': 'Optaros',
#   'category_code': 'consulting',
#   'founded_year': 2004,
#   'total_money_raised': '$38.5M',
#   'offices': [{'description': 'World Headquarters',
#     'address1': '10 Milk St.',
#     'address2': '11th floor',
#     'zip_code': '02108',
#     'city': 'Boston',
#     'state_code': 'MA',
#     'country_code': 'USA',
#     'latitude': 42.356812,
#     'longitude': -71.058185}]},
#  {'_id': ObjectId('52cdef7d4bab8bd675298df0'),
#   'name': 'NetSpend',
#   'category_code': 'other',
#   'founded_year': 1999,
#   'total_money_raised': '$5.33M',
#   'offices': [{'description': 'HQ',
#     'address1': 'PO Box 2136',
#     'address2': '',
#     'zip_code': '78768-2136',
#     'city': 'Austin',
#     'state_code': 'TX',
#     'country_code': 'USA',
#     'latitude': 30.2667,
#     'longitude': -97.7428}]},
#  {'_id': ObjectId('52cdef7d4bab8bd675298de8'),
#   'name': 'iPling',
#   'category_code': 'mobile',
#   'founded_year': 2007,
#   'total_money_raised': '$700k',
#   'offices': [{'description': 'Main Office',
#     'address1': 'One Market Street',
#     'address2': 'Spear Tower, 36th Floor',
#     'zip_code': '94105',
#     'city': 'San Francisco',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.791391,
#     'longitude': -122.402859}]},
#  {'_id': ObjectId('52cdef7d4bab8bd675298dfc'),
#   'name': 'LabPixies',
#   'category_code': 'web',
#   'founded_year': 2006,
#   'total_money_raised': '$1M',
#   'offices': [{'description': '',
#     'address1': '',
#     'address2': '',
#     'zip_code': '',
#     'city': 'Tel Aviv',
#     'state_code': None,
#     'country_code': 'ISR',
#     'latitude': 32.0554,
#     'longitude': 34.7595}]},
#  {'_id': ObjectId('52cdef7d4bab8bd675298e07'),
#   'name': 'Intacct',
#   'category_code': 'enterprise',
#   'founded_year': 1999,
#   'total_money_raised': '$64.8M',
#   'offices': [{'description': 'Headquarters',
#     'address1': '150 Almaden Blvd.',
#     'address2': 'Suite 1500',
#     'zip_code': '95113',
#     'city': 'San Jose',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.332948,
#     'longitude': -121.89053}]},
#  {'_id': ObjectId('52cdef7d4bab8bd675298e15'),
#   'name': 'Boxee',
#   'category_code': 'software',
#   'founded_year': 2004,
#   'total_money_raised': '$26.5M',
#   'offices': [{'description': 'Israeli Headquarters',
#     'address1': '',
#     'address2': '',
#     'zip_code': '',
#     'city': 'Tel Aviv',
#     'state_code': None,
#     'country_code': 'ISR',
#     'latitude': 32.0554,
#     'longitude': 34.7595},
#    {'description': 'US Headquarters',
#     'address1': '122 West 26th Street',
#     'address2': '8th Floor',
#     'zip_code': '10001',
#     'city': 'New York',
#     'state_code': 'NY',
#     'country_code': 'USA',
#     'latitude': 40.745064,
#     'longitude': -73.992637}]},
#  {'_id': ObjectId('52cdef7d4bab8bd675298e1a'),
#   'name': 'Aurora Biofuels',
#   'category_code': 'cleantech',
#   'founded_year': 2007,
#   'total_money_raised': '$102M',
#   'offices': [{'description': 'Corporate Headquarters',
#     'address1': '3325 Investment Boulevard',
#     'address2': 'Hayward,',
#     'zip_code': '94545',
#     'city': '',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.6266932,
#     'longitude': -122.1169032},
#    {'description': None,
#     'address1': None,
#     'address2': None,
#     'zip_code': None,
#     'city': 'Hayward',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.6688205,
#     'longitude': -122.0807964}]},
#  {'_id': ObjectId('52cdef7d4bab8bd675298e2c'),
#   'name': 'Bambuser',
#   'category_code': 'mobile',
#   'founded_year': 2007,
#   'total_money_raised': '$2.5M',
#   'offices': [{'description': 'Headqurter',
#     'address1': '',
#     'address2': '',
#     'zip_code': '',
#     'city': 'Stockholm',
#     'state_code': None,
#     'country_code': 'SWE',
#     'latitude': 59.332788,
#     'longitude': 18.064488}]},
#  {'_id': ObjectId('52cdef7d4bab8bd675298e47'),
#   'name': 'GeoMe',
#   'category_code': 'mobile',
#   'founded_year': 2007,
#   'total_money_raised': '€300k',
#   'offices': [{'description': 'HQ',
#     'address1': 'Rambla de Catalunya 77, 1B',
#     'address2': '',
#     'zip_code': '08007',
#     'city': 'Barcelona',
#     'state_code': None,
#     'country_code': 'ESP',
#     'latitude': 41.387411,
#     'longitude': 2.168518}]},
#  {'_id': ObjectId('52cdef7d4bab8bd675298e55'),
#   'name': 'Channel Intelligence',
#   'category_code': 'web',
#   'founded_year': 1999,
#   'total_money_raised': '$3.01M',
#   'offices': [{'description': 'Corporate Headquarters',
#     'address1': '1180 Celebration Blvd.',
#     'address2': 'Suite 101',
#     'zip_code': '34747',
#     'city': 'Celebration',
#     'state_code': 'FL',
#     'country_code': 'USA',
#     'latitude': 28.321337,
#     'longitude': -81.552229},
#    {'description': 'UK Office',
#     'address1': '59-60 Thames Street',
#     'address2': 'Windsor Berkshire',
#     'zip_code': 'SL4 1TX',
#     'city': 'London',
#     'state_code': None,
#     'country_code': 'GBR',
#     'latitude': 51.500152,
#     'longitude': -0.126236}]},
#  {'_id': ObjectId('52cdef7d4bab8bd675298e65'),
#   'name': 'Vigster',
#   'category_code': 'games_video',
#   'founded_year': None,
#   'total_money_raised': '£50k',
#   'offices': [{'description': 'London Office',
#     'address1': '',
#     'address2': '',
#     'zip_code': '',
#     'city': 'London',
#     'state_code': None,
#     'country_code': 'GBR',
#     'latitude': 51.500152,
#     'longitude': -0.126236}]},
#  {'_id': ObjectId('52cdef7d4bab8bd675298e61'),
#   'name': 'Razz',
#   'category_code': 'software',
#   'founded_year': 2002,
#   'total_money_raised': '$10M',
#   'offices': [{'description': '',
#     'address1': '208 Utah Street',
#     'address2': 'Suite 210',
#     'zip_code': '94103',
#     'city': 'San Francisco',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.766909,
#     'longitude': -122.406676}]},
#  {'_id': ObjectId('52cdef7d4bab8bd675298e66'),
#   'name': 'Xcerion',
#   'category_code': 'enterprise',
#   'founded_year': 2001,
#   'total_money_raised': '$15.3M',
#   'offices': [{'description': 'Xcerion AB',
#     'address1': 'Drottninggatan 23',
#     'address2': '',
#     'zip_code': '58225',
#     'city': 'Linkoping',
#     'state_code': None,
#     'country_code': 'SWE',
#     'latitude': 58.408922,
#     'longitude': 15.626481}]},
#  {'_id': ObjectId('52cdef7d4bab8bd675298e64'),
#   'name': 'InsideView',
#   'category_code': 'enterprise',
#   'founded_year': 2005,
#   'total_money_raised': '$56.5M',
#   'offices': [{'description': 'Headquarters',
#     'address1': '444 De Haro Street',
#     'address2': 'Suite 210',
#     'zip_code': '94107',
#     'city': 'San Francisco',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.764169,
#     'longitude': -122.402021}]},
#  {'_id': ObjectId('52cdef7d4bab8bd675298e8c'),
#   'name': 'Lat49',
#   'category_code': 'advertising',
#   'founded_year': 2007,
#   'total_money_raised': '$3.8M',
#   'offices': [{'description': "Lat49's Geo-location",
#     'address1': '555 W Hastings',
#     'address2': 'Floor 11',
#     'zip_code': 'V6B 5L1',
#     'city': 'Vancouver, BC',
#     'state_code': None,
#     'country_code': 'CAN',
#     'latitude': 49.275332,
#     'longitude': -123.120893}]},
#  {'_id': ObjectId('52cdef7d4bab8bd675298e90'),
#   'name': 'Clickability',
#   'category_code': 'enterprise',
#   'founded_year': 1999,
#   'total_money_raised': '$11.5M',
#   'offices': [{'description': 'Headquarters',
#     'address1': '300 California Street',
#     'address2': '2nd Floor',
#     'zip_code': '94104',
#     'city': 'San Francisco',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.7932747,
#     'longitude': -122.399929}]},
#  {'_id': ObjectId('52cdef7d4bab8bd675298e94'),
#   'name': 'Celsias',
#   'category_code': 'public_relations',
#   'founded_year': 2006,
#   'total_money_raised': '$500k',
#   'offices': [{'description': 'Headquarters',
#     'address1': '2 Woodward Street',
#     'address2': 'Level 7',
#     'zip_code': '6011',
#     'city': 'Wellington',
#     'state_code': None,
#     'country_code': 'NZL',
#     'latitude': -41.282064,
#     'longitude': 174.775566}]},
#  {'_id': ObjectId('52cdef7d4bab8bd675298e9e'),
#   'name': 'LoudClick',
#   'category_code': 'software',
#   'founded_year': 2006,
#   'total_money_raised': '$600k',
#   'offices': [{'description': 'MN',
#     'address1': '1911 Suburban Ave #351',
#     'address2': '',
#     'zip_code': '55119',
#     'city': 'St Paul',
#     'state_code': 'MN',
#     'country_code': 'USA',
#     'latitude': 44.86495,
#     'longitude': -93.288479}]},
#  {'_id': ObjectId('52cdef7d4bab8bd675298e9a'),
#   'name': 'Jibe Mobile',
#   'category_code': 'mobile',
#   'founded_year': 2006,
#   'total_money_raised': '$9.1M',
#   'offices': [{'description': 'Headquarters',
#     'address1': '990 N Rengstorff Ave',
#     'address2': '',
#     'zip_code': '94043',
#     'city': 'Mountain View',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.4186097,
#     'longitude': -122.0937686}]},
#  {'_id': ObjectId('52cdef7d4bab8bd675298ea5'),
#   'name': 'HIRO Media',
#   'category_code': 'advertising',
#   'founded_year': 2004,
#   'total_money_raised': '$5M',
#   'offices': [{'description': 'Corporate Headquarters',
#     'address1': '',
#     'address2': '',
#     'zip_code': '',
#     'city': 'Tel Aviv',
#     'state_code': None,
#     'country_code': 'ISR',
#     'latitude': 32.0554,
#     'longitude': 34.7595}]},
#  {'_id': ObjectId('52cdef7d4bab8bd675298e9d'),
#   'name': 'Ziplocal',
#   'category_code': 'search',
#   'founded_year': 2006,
#   'total_money_raised': 'C$15.3M',
#   'offices': [{'description': 'Toronto Office',
#     'address1': '197 Spadina Ave',
#     'address2': 'Suite 200',
#     'zip_code': 'M5T 2C8',
#     'city': 'Toronto',
#     'state_code': None,
#     'country_code': 'CAN',
#     'latitude': 43.650105,
#     'longitude': -79.396805},
#    {'description': 'Montreal Office',
#     'address1': '980 rue St-Antoine',
#     'address2': 'Bureau 310',
#     'zip_code': 'H3C 1A8',
#     'city': 'Montreal',
#     'state_code': None,
#     'country_code': 'CAN',
#     'latitude': 45.498179,
#     'longitude': -73.565316}]},
#  {'_id': ObjectId('52cdef7d4bab8bd675298eb0'),
#   'name': 'SpikeSource',
#   'category_code': 'software',
#   'founded_year': 2004,
#   'total_money_raised': '$68M',
#   'offices': [{'description': 'Corporate Headquarters',
#     'address1': '450 Clyde Ave',
#     'address2': '',
#     'zip_code': '94043',
#     'city': 'Mountain View',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.510805,
#     'longitude': -122.203744}]},
#  {'_id': ObjectId('52cdef7d4bab8bd675298eb6'),
#   'name': 'Blueprint Software Systems',
#   'category_code': 'enterprise',
#   'founded_year': 2004,
#   'total_money_raised': '$30.2M',
#   'offices': [{'description': '',
#     'address1': '20 Toronto Street, 11th Floor',
#     'address2': '',
#     'zip_code': 'M5C 2B8',
#     'city': 'Toronto',
#     'state_code': None,
#     'country_code': 'CAN',
#     'latitude': 43.65101,
#     'longitude': -79.381254}]},
#  {'_id': ObjectId('52cdef7d4bab8bd675298eba'),
#   'name': 'Idea Shower',
#   'category_code': 'public_relations',
#   'founded_year': 2007,
#   'total_money_raised': '$2.3M',
#   'offices': [{'description': 'HQ',
#     'address1': '',
#     'address2': '',
#     'zip_code': '',
#     'city': 'Minneapolis',
#     'state_code': 'MN',
#     'country_code': 'USA',
#     'latitude': 44.977482,
#     'longitude': -93.264351}]},
#  {'_id': ObjectId('52cdef7d4bab8bd675298e81'),
#   'name': 'Bootup Labs',
#   'category_code': 'consulting',
#   'founded_year': 2008,
#   'total_money_raised': 'C$350k',
#   'offices': [{'description': '',
#     'address1': '163 West Hastings Street',
#     'address2': 'Suite 200',
#     'zip_code': 'V6B 1H5',
#     'city': 'Vancouver',
#     'state_code': None,
#     'country_code': 'CAN',
#     'latitude': 49.2846085,
#     'longitude': -123.110394}]},
#  {'_id': ObjectId('52cdef7d4bab8bd675298ec3'),
#   'name': 'CrestaTech',
#   'category_code': 'software',
#   'founded_year': 2005,
#   'total_money_raised': '$20.9M',
#   'offices': [{'description': 'World Headquarters',
#     'address1': '3900 Freedom Circle,',
#     'address2': 'Suite 201',
#     'zip_code': '95054',
#     'city': 'Santa Clara',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.383368,
#     'longitude': -121.980186}]},
#  {'_id': ObjectId('52cdef7d4bab8bd675298ed2'),
#   'name': 'Pixy Ltd',
#   'category_code': 'web',
#   'founded_year': 2006,
#   'total_money_raised': '£50k',
#   'offices': [{'description': '',
#     'address1': '2a Bracken Road',
#     'address2': '',
#     'zip_code': 'SL6 3EF',
#     'city': 'Maidenhead',
#     'state_code': None,
#     'country_code': 'GBR',
#     'latitude': 51.508466,
#     'longitude': -0.742987}]},
#  {'_id': ObjectId('52cdef7d4bab8bd675298ed9'),
#   'name': 'ITN',
#   'category_code': 'software',
#   'founded_year': None,
#   'total_money_raised': '€700k',
#   'offices': [{'description': '',
#     'address1': '82, rue Saint-Lazare',
#     'address2': '',
#     'zip_code': '75009',
#     'city': 'Paris',
#     'state_code': None,
#     'country_code': 'FRA',
#     'latitude': 48.8759918,
#     'longitude': 2.3295866}]},
#  ...]

# %%
print(len(companies))
# Out:
# 2690

# %%
companies1 = pd.DataFrame(companies)
companies1.head()
# Out:
#                         _id     name category_code  founded_year  \
# 0  52cdef7c4bab8bd675297d91     Geni           web        2006.0
# 1  52cdef7c4bab8bd675297d96   Gizmoz           web        2003.0
# 2  52cdef7c4bab8bd675297d8d     Digg          news        2004.0
# 3  52cdef7c4bab8bd675297d99     Lala   games_video           NaN
# 4  52cdef7c4bab8bd675297d98  Slacker         music        2006.0
#
#   total_money_raised                                            offices
# 0             $16.5M  [{'description': 'Headquarters', 'address1': '...
# 1             $18.1M  [{'description': None, 'address1': None, 'addr...
# 2               $45M  [{'description': None, 'address1': '135 Missis...
# 3             $44.2M  [{'description': 'Lala Headquarters', 'address...
# 4             $73.1M  [{'description': '', 'address1': '16935 W. Ber...

# %%
def getLocation(companies):
    location =[]
    for i in range(len(companies['offices'])):
        longitude = companies['offices'][i]['longitude']
        latitude = companies['offices'][i]['latitude']
        loc = {
            'type':'Point',
            'coordinates':[longitude, latitude]
        }
        location.append(loc)
    return location

# %%
for cp in companies:
    value = {"$set": {'location':getLocation(cp)}}
    coll.update_one(cp, value)

# %%
companies[0]['location'][0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-96-475ef5143761> in <module>
# ----> 1 companies[0]['location'][0]
#
# KeyError: 'location'
