# %%
from pymongo import MongoClient
import pandas as pd
import re
import folium

# %%
def connectCollection(database, collection):
    client = MongoClient()
    db = client[database]
    coll = db[collection]
    return db, coll

# %%
db, coll = connectCollection('companies','companies')
print(coll.json)
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'companies'), 'companies.json')

# %%
extraer = [
    { "$unwind": "$offices"},
    {"$match": {"$and":
            [{"founded_year": {"$gte": 2009}},
             {"deadpooled_year": None},
             {"total_money_raised": {"$exists": True, "$ne": "$0"}},
             {"offices.latitude": {"$exists": True, "$ne": None}},
             {"offices.longitude": {"$exists": True, "$ne": None}}]}}]

oficinas_fuera = list(coll.aggregate(extraer))


print(oficinas_fuera[0])
# Out:
# {'_id': ObjectId('52cdef7c4bab8bd675297f94'), 'name': 'PeekYou', 'permalink': 'peekyou', 'crunchbase_url': 'http://www.crunchbase.com/company/peekyou', 'homepage_url': 'http://www.peekyou.com', 'blog_url': 'http://www.peekyou.biz', 'blog_feed_url': 'http://blog.peekyou.com/feed/', 'twitter_username': 'peekyou', 'category_code': 'search', 'number_of_employees': 20, 'founded_year': 2012, 'founded_month': 11, 'founded_day': 2, 'deadpooled_year': None, 'deadpooled_month': None, 'deadpooled_day': None, 'deadpooled_url': None, 'tag_list': 'social-crm, database, peekyou, peoplesearch, engine, people, search, directory, social, google', 'alias_list': None, 'email_address': 'info@peekyou.com', 'phone_number': '', 'description': '', 'created_at': 'Fri Aug 31 12:46:53 UTC 2007', 'updated_at': 'Wed Jul 10 10:13:16 UTC 2013', 'overview': '<p>PeekYou places the individual at the center of the Internet. For every public weblink, PeekYou tries to answer the question, &#8220;Who made it?&#8221; or, where applicable, &#8220;Whom is it about?&#8221; So far, we&#8217;ve answered those questions for a billion links and counting. Our patented technology analyzes content from over sixty social sites, news sources, homepages and blog platforms and identifies the actual people behind it, combining their scattered digital footprints into a comprehensive record of their online identity.</p>\n\n<p>Google calculates the likelihood of any link being associated to a keyword. PeekYou calculates the likelihood of any link being associated to an individual.</p>\n\n<p>The company was founded in 2006 by Michael Hussey and is headquartered in New York City.</p>', 'image': {'available_sizes': [[[150, 36], 'assets/images/resized/0011/9733/119733v6-max-150x150.png'], [[250, 61], 'assets/images/resized/0011/9733/119733v6-max-250x250.png'], [[413, 101], 'assets/images/resized/0011/9733/119733v6-max-450x450.png']], 'attribution': None}, 'products': [{'name': 'PeekYou.com', 'permalink': 'peekyou'}, {'name': 'PeekAnalytics', 'permalink': 'peekanalytics'}, {'name': 'PeekAPI', 'permalink': 'peekapi'}], 'relationships': [{'is_past': False, 'title': 'Chairman of the Board', 'person': {'first_name': 'Kimberley', 'last_name': 'Partoll', 'permalink': 'kimberley-partoll'}}, {'is_past': False, 'title': 'CEO/Founder', 'person': {'first_name': 'Michael', 'last_name': 'Hussey', 'permalink': 'michael-hussey'}}, {'is_past': False, 'title': 'CTO', 'person': {'first_name': 'Venky', 'last_name': 'Someswaran', 'permalink': 'venky-someswaran'}}, {'is_past': False, 'title': 'CIO', 'person': {'first_name': 'Pavel', 'last_name': 'Baranov', 'permalink': 'pavel-baranov'}}, {'is_past': False, 'title': 'VP of Operations', 'person': {'first_name': 'Chris', 'last_name': 'Klipple', 'permalink': 'chris-klipple'}}, {'is_past': False, 'title': 'Lead Developer', 'person': {'first_name': 'Eray', 'last_name': 'Cetiner', 'permalink': 'eray-cetiner'}}, {'is_past': False, 'title': 'Director', 'person': {'first_name': 'Baldev', 'last_name': 'Duggal', 'permalink': 'baldev-duggal'}}, {'is_past': False, 'title': 'President', 'person': {'first_name': 'Tom', 'last_name': 'Lynch', 'permalink': 'tom-lynch'}}, {'is_past': False, 'title': 'Advisor', 'person': {'first_name': 'Andy', 'last_name': 'Tuck', 'permalink': 'andy-tuck'}}, {'is_past': False, 'title': 'Advisor', 'person': {'first_name': 'Marshall', 'last_name': 'Sponder', 'permalink': 'marshall-sponder'}}, {'is_past': False, 'title': 'Lead Developer', 'person': {'first_name': 'Dasara', 'last_name': 'Kushi', 'permalink': 'dasara-kushi'}}, {'is_past': False, 'title': 'Art Director', 'person': {'first_name': 'Lane', 'last_name': 'Gillespie', 'permalink': 'lane-gillespie'}}, {'is_past': False, 'title': 'Investment Banker', 'person': {'first_name': 'Phil', 'last_name': 'Fresen', 'permalink': 'phil-fresen'}}, {'is_past': False, 'title': 'Developer', 'person': {'first_name': 'Oleg', 'last_name': 'Borkov', 'permalink': 'oleg-borkov'}}, {'is_past': False, 'title': 'Board ...

# %%
def getLocation(companies):
    for i in range(len(companies['offices'])):
        longitude = companies['offices']['longitude']
        latitude = companies['offices']['latitude']
        loc = {
            'type':'Point',
            'coordinates':[longitude, latitude]
        }
        return loc

# %%
getLocation(oficinas_fuera[1])
# Out:
# {'type': 'Point', 'coordinates': [-111.9035, 33.8171]}

# %%
for cp in oficinas_fuera:
    value = {"$set": {'geolocation':getLocation(cp)}}
    coll.update_one(cp, value)

# %%
print(oficinas_fuera[0])
# Out:
# {'_id': ObjectId('52cdef7c4bab8bd675297f94'), 'name': 'PeekYou', 'permalink': 'peekyou', 'crunchbase_url': 'http://www.crunchbase.com/company/peekyou', 'homepage_url': 'http://www.peekyou.com', 'blog_url': 'http://www.peekyou.biz', 'blog_feed_url': 'http://blog.peekyou.com/feed/', 'twitter_username': 'peekyou', 'category_code': 'search', 'number_of_employees': 20, 'founded_year': 2012, 'founded_month': 11, 'founded_day': 2, 'deadpooled_year': None, 'deadpooled_month': None, 'deadpooled_day': None, 'deadpooled_url': None, 'tag_list': 'social-crm, database, peekyou, peoplesearch, engine, people, search, directory, social, google', 'alias_list': None, 'email_address': 'info@peekyou.com', 'phone_number': '', 'description': '', 'created_at': 'Fri Aug 31 12:46:53 UTC 2007', 'updated_at': 'Wed Jul 10 10:13:16 UTC 2013', 'overview': '<p>PeekYou places the individual at the center of the Internet. For every public weblink, PeekYou tries to answer the question, &#8220;Who made it?&#8221; or, where applicable, &#8220;Whom is it about?&#8221; So far, we&#8217;ve answered those questions for a billion links and counting. Our patented technology analyzes content from over sixty social sites, news sources, homepages and blog platforms and identifies the actual people behind it, combining their scattered digital footprints into a comprehensive record of their online identity.</p>\n\n<p>Google calculates the likelihood of any link being associated to a keyword. PeekYou calculates the likelihood of any link being associated to an individual.</p>\n\n<p>The company was founded in 2006 by Michael Hussey and is headquartered in New York City.</p>', 'image': {'available_sizes': [[[150, 36], 'assets/images/resized/0011/9733/119733v6-max-150x150.png'], [[250, 61], 'assets/images/resized/0011/9733/119733v6-max-250x250.png'], [[413, 101], 'assets/images/resized/0011/9733/119733v6-max-450x450.png']], 'attribution': None}, 'products': [{'name': 'PeekYou.com', 'permalink': 'peekyou'}, {'name': 'PeekAnalytics', 'permalink': 'peekanalytics'}, {'name': 'PeekAPI', 'permalink': 'peekapi'}], 'relationships': [{'is_past': False, 'title': 'Chairman of the Board', 'person': {'first_name': 'Kimberley', 'last_name': 'Partoll', 'permalink': 'kimberley-partoll'}}, {'is_past': False, 'title': 'CEO/Founder', 'person': {'first_name': 'Michael', 'last_name': 'Hussey', 'permalink': 'michael-hussey'}}, {'is_past': False, 'title': 'CTO', 'person': {'first_name': 'Venky', 'last_name': 'Someswaran', 'permalink': 'venky-someswaran'}}, {'is_past': False, 'title': 'CIO', 'person': {'first_name': 'Pavel', 'last_name': 'Baranov', 'permalink': 'pavel-baranov'}}, {'is_past': False, 'title': 'VP of Operations', 'person': {'first_name': 'Chris', 'last_name': 'Klipple', 'permalink': 'chris-klipple'}}, {'is_past': False, 'title': 'Lead Developer', 'person': {'first_name': 'Eray', 'last_name': 'Cetiner', 'permalink': 'eray-cetiner'}}, {'is_past': False, 'title': 'Director', 'person': {'first_name': 'Baldev', 'last_name': 'Duggal', 'permalink': 'baldev-duggal'}}, {'is_past': False, 'title': 'President', 'person': {'first_name': 'Tom', 'last_name': 'Lynch', 'permalink': 'tom-lynch'}}, {'is_past': False, 'title': 'Advisor', 'person': {'first_name': 'Andy', 'last_name': 'Tuck', 'permalink': 'andy-tuck'}}, {'is_past': False, 'title': 'Advisor', 'person': {'first_name': 'Marshall', 'last_name': 'Sponder', 'permalink': 'marshall-sponder'}}, {'is_past': False, 'title': 'Lead Developer', 'person': {'first_name': 'Dasara', 'last_name': 'Kushi', 'permalink': 'dasara-kushi'}}, {'is_past': False, 'title': 'Art Director', 'person': {'first_name': 'Lane', 'last_name': 'Gillespie', 'permalink': 'lane-gillespie'}}, {'is_past': False, 'title': 'Investment Banker', 'person': {'first_name': 'Phil', 'last_name': 'Fresen', 'permalink': 'phil-fresen'}}, {'is_past': False, 'title': 'Developer', 'person': {'first_name': 'Oleg', 'last_name': 'Borkov', 'permalink': 'oleg-borkov'}}, {'is_past': False, 'title': 'Board ...

# %%
companies_df = pd.DataFrame(oficinas_fuera)

companies_df
# Out:
#                           _id           name      permalink  \
# 0    52cdef7c4bab8bd675297f94        PeekYou        peekyou
# 1    52cdef7c4bab8bd675297f9e          GENWI          genwi
# 2    52cdef7c4bab8bd675297fec          Fixya          fixya
# 3    52cdef7c4bab8bd6752981d8      Widgetbox      widgetbox
# 4    52cdef7c4bab8bd6752981dc     RazorGator     razorgator
# ..                        ...            ...            ...
# 101  52cdef7f4bab8bd67529c2d0         Delphi         delphi
# 102  52cdef7f4bab8bd67529c343  ChallengePost  challengepost
# 103  52cdef7f4bab8bd67529c448        Teambox        teambox
# 104  52cdef7f4bab8bd67529c6b6     Tiny Speck     tiny-speck
# 105  52cdef7f4bab8bd67529c6e4         Getyoo         getyoo
#
#                                       crunchbase_url  \
# 0          http://www.crunchbase.com/company/peekyou
# 1            http://www.crunchbase.com/company/genwi
# 2            http://www.crunchbase.com/company/fixya
# 3        http://www.crunchbase.com/company/widgetbox
# 4       http://www.crunchbase.com/company/razorgator
# ..                                               ...
# 101         http://www.crunchbase.com/company/delphi
# 102  http://www.crunchbase.com/company/challengepost
# 103        http://www.crunchbase.com/company/teambox
# 104     http://www.crunchbase.com/company/tiny-speck
# 105         http://www.crunchbase.com/company/getyoo
#
#                      homepage_url                       blog_url  \
# 0          http://www.peekyou.com         http://www.peekyou.biz
# 1            http://www.genwi.com          http://blog.genwi.com
# 2            http://www.fixya.com         http://blog.muktar.com
# 3            http://widgetbox.com
# 4           http://razorgator.com
# ..                            ...                            ...
# 101         http://www.delphi.com
# 102  http://www.challengepost.com  http://blog.challengepost.com
# 103        http://www.teambox.com        http://teambox.com/blog
# 104          http://tinyspeck.com
# 105         http://www.getyoo.com      http://getyoo.tumblr.com/
#
#                        blog_feed_url twitter_username category_code  \
# 0      http://blog.peekyou.com/feed/          peekyou        search
# 1                                               genwi        mobile
# 2       http://blog.muktar.com/feed/          MUaliyu           web
# 3    http://blog.widgetbox.com/feed/        widgetbox         other
# 4                                          Razorgator     ecommerce
# ..                               ...              ...           ...
# 101                                        DelphiAuto     cleantech
# 102                                     challengepost           web
# 103                                       teambox_app           web
# 104                                           slackhq   games_video
# 105     http://getyoo.tumblr.com/rss           getyoo        mobile
#
#      number_of_employees  ...  \
# 0                   20.0  ...
# 1                   25.0  ...
# 2                   30.0  ...
# 3                   30.0  ...
# 4                    NaN  ...
# ..                   ...  ...
# 101                  NaN  ...
# 102                 17.0  ...
# 103                 35.0  ...
# 104                 45.0  ...
# 105                 10.0  ...
#
#                                           acquisitions  \
# 0                                                   []
# 1                                                   []
# 2                                                   []
# 3                                                   []
# 4                                                   []
# ..                                                 ...
# 101                                                 []
# 102                                                 []
# 103  [{'price_amount': None, 'price_currency_code':...
# 104                                                 []
# 105                                                 []
#
#                                                offices  \
# 0    {'description': None, 'address1': None, 'addre...
# 1    {'description': '', 'address1': '4966 El Camin...
# 2    {'description': '', 'address1': 'One Franklin ...
# 3    {'description': None, 'address1': None, 'addre...
# 4    {'description': None, 'address1': '11150 Santa...
# ..                                                 ...
# 101  {'description': '', 'address1': '5725 Delphi D...
# 102  {'description': '', 'address1': '425 West 13th...
# 103  {'description': 'Barcelona Office', 'address1'...
# 104  {'description': '', 'address1': '163 Hastings ...
# 105  {'description': 'HQ', 'address1': 'Rue des Tan...
#
#                                             milestones   ipo  \
# 0    [{'id': 18106, 'description': 'Launched in Ste...  None
# 1    [{'id': 14542, 'description': 'Rahul Patel, fo...  None
# 2                                                   []  None
# 3    [{'id': 1669, 'description': 'Widgetizing The ...  None
# 4                                                   []  None
# ..                                                 ...   ...
# 101                                                 []  None
# 102                                                 []  None
# 103  [{'id': 23211, 'description': 'Teambox hires D...  None
# 104                                                 []  None
# 105                                                 []  None
#
#                                           video_embeds  \
# 0    [{'embed_code': '<object width="420" height="2...
# 1                                                   []
# 2    [{'embed_code': '<div style="width:320px;"><di...
# 3                                                   []
# 4                                                   []
# ..                                                 ...
# 101                                                 []
# 102                                                 []
# 103  [{'embed_code': '<iframe src="">Teambox online...
# 104                                                 []
# 105  [{'embed_code': '<object width="448" height="2...
#
#                                            screenshots  \
# 0                                                   []
# 1    [{'available_sizes': [[[150, 96], 'assets/imag...
# 2                                                   []
# 3    [{'available_sizes': [[[100, 75], 'assets/imag...
# 4                                                   []
# ..                                                 ...
# 101  [{'available_sizes': [[[150, 75], 'assets/imag...
# 102  [{'available_sizes': [[[150, 136], 'assets/ima...
# 103  [{'available_sizes': [[[150, 83], 'assets/imag...
# 104  [{'available_sizes': [[[150, 73], 'assets/imag...
# 105  [{'available_sizes': [[[150, 93], 'assets/imag...
#
#                                         external_links  \
# 0    [{'external_url': 'http://www.webmetricsguru.c...
# 1    [{'external_url': 'http://iSites.us', 'title':...
# 2    [{'external_url': 'http://www.vccafe.com/2009/...
# 3                                                   []
# 4                                                   []
# ..                                                 ...
# 101                                                 []
# 102                                                 []
# 103                                                 []
# 104                                                 []
# 105  [{'external_url': 'http://www.youtube.com/watc...
#
#                                               partners  \
# 0                                                   []
# 1                                                   []
# 2                                                   []
# 3                                                   []
# 4                                                   []
# ..                                                 ...
# 101                                                 []
# 102                                                 []
# 103  [{'partner_name': 'AngelList', 'homepage_url':...
# 104                                                 []
# 105                                                 []
#
#                                               location  \
# 0    [{'type': 'Point', 'coordinates': [-73.985506,...
# 1    [{'type': 'Point', 'coordinates': [-111.9035, ...
# 2    [{'type': 'Point', 'coordinates': [-122.323895...
# 3    [{'type': 'Point', 'coordinates': [-122.398599...
# 4    [{'type': 'Point', 'coordinates': [-118.445243...
# ..                                                 ...
# 101  [{'type': 'Point', 'coordinates': [-83.16134, ...
# 102  [{'type': 'Point', 'coordinates': [-74.00717, ...
# 103                                                NaN
# 104  [{'type': 'Point', 'coordinates': [-123.109217...
# 105  [{'type': 'Point', 'coordinates': [4.3464721, ...
#
#                                            geolocation
# 0    {'type': 'Point', 'coordinates': [-73.985506, ...
# 1    {'type': 'Point', 'coordinates': [-111.9035, 3...
# 2    {'type': 'Point', 'coordinates': [-122.323895,...
# 3    {'type': 'Point', 'coordinates': [-122.398599,...
# 4    {'type': 'Point', 'coordinates': [-118.445243,...
# ..                                                 ...
# 101  {'type': 'Point', 'coordinates': [-83.16134, 4...
# 102  {'type': 'Point', 'coordinates': [-74.00717, 4...
# 103  {'type': 'Point', 'coordinates': [2.1920231, 4...
# 104  {'type': 'Point', 'coordinates': [-123.109217,...
# 105  {'type': 'Point', 'coordinates': [4.3464721, 5...
#
# [106 rows x 44 columns]

# %%
print(len(companies_df))
# Out:
# 106

# %%
companies_df = companies_df[["name","category_code","founded_year","total_money_raised","geolocation"]]

companies_df.head()
# Out:
#          name category_code  founded_year total_money_raised  \
# 0     PeekYou        search          2012             $1.83M
# 1       GENWI        mobile          2010              $7.1M
# 2       Fixya           web          2013                $8M
# 3   Widgetbox         other          2012             $14.5M
# 4  RazorGator     ecommerce          2011             $58.8M
#
#                                          geolocation
# 0  {'type': 'Point', 'coordinates': [-73.985506, ...
# 1  {'type': 'Point', 'coordinates': [-111.9035, 3...
# 2  {'type': 'Point', 'coordinates': [-122.323895,...
# 3  {'type': 'Point', 'coordinates': [-122.398599,...
# 4  {'type': 'Point', 'coordinates': [-118.445243,...

# %%
companies_df['category_code'].value_counts()
# Out:
# web                15
# games_video        14
# software           14
# advertising        14
# enterprise          9
# mobile              8
# travel              5
# ecommerce           5
# biotech             4
# social              2
# search              2
# cleantech           2
# other               2
# education           2
# hardware            2
# medical             1
# fashion             1
# network_hosting     1
# security            1
# analytics           1
# messaging           1
# Name: category_code, dtype: int64

# %%
companies_df.total_money_raised = companies_df.total_money_raised.str.replace(r'(\d+)([A-Za-z])', r'\1 \2')

companies_df.head()
# Out:
#          name category_code  founded_year total_money_raised  \
# 0     PeekYou        search          2012            $1.83 M
# 1       GENWI        mobile          2010             $7.1 M
# 2       Fixya           web          2013               $8 M
# 3   Widgetbox         other          2012            $14.5 M
# 4  RazorGator     ecommerce          2011            $58.8 M
#
#                                          geolocation
# 0  {'type': 'Point', 'coordinates': [-73.985506, ...
# 1  {'type': 'Point', 'coordinates': [-111.9035, 3...
# 2  {'type': 'Point', 'coordinates': [-122.323895,...
# 3  {'type': 'Point', 'coordinates': [-122.398599,...
# 4  {'type': 'Point', 'coordinates': [-118.445243,...

# %%
companies_df = companies_df[['M' in x for x in companies_df['total_money_raised']]]
companies_df
# Out:
#               name category_code  founded_year total_money_raised  \
# 0          PeekYou        search          2012            $1.83 M
# 1            GENWI        mobile          2010             $7.1 M
# 2            Fixya           web          2013               $8 M
# 3        Widgetbox         other          2012            $14.5 M
# 4       RazorGator     ecommerce          2011            $58.8 M
# ..             ...           ...           ...                ...
# 101         Delphi     cleantech          2009               $8 M
# 102  ChallengePost           web          2009             $4.6 M
# 103        Teambox           web          2009            $6.75 M
# 104     Tiny Speck   games_video          2009            $17.2 M
# 105         Getyoo        mobile          2009            €1.13 M
#
#                                            geolocation
# 0    {'type': 'Point', 'coordinates': [-73.985506, ...
# 1    {'type': 'Point', 'coordinates': [-111.9035, 3...
# 2    {'type': 'Point', 'coordinates': [-122.323895,...
# 3    {'type': 'Point', 'coordinates': [-122.398599,...
# 4    {'type': 'Point', 'coordinates': [-118.445243,...
# ..                                                 ...
# 101  {'type': 'Point', 'coordinates': [-83.16134, 4...
# 102  {'type': 'Point', 'coordinates': [-74.00717, 4...
# 103  {'type': 'Point', 'coordinates': [2.1920231, 4...
# 104  {'type': 'Point', 'coordinates': [-123.109217,...
# 105  {'type': 'Point', 'coordinates': [4.3464721, 5...
#
# [82 rows x 5 columns]

# %%
companies_df1 = companies_df.reset_index()
companies_df1
# Out:
#     index           name category_code  founded_year total_money_raised  \
# 0       0        PeekYou        search          2012            $1.83 M
# 1       1          GENWI        mobile          2010             $7.1 M
# 2       2          Fixya           web          2013               $8 M
# 3       3      Widgetbox         other          2012            $14.5 M
# 4       4     RazorGator     ecommerce          2011            $58.8 M
# ..    ...            ...           ...           ...                ...
# 77    101         Delphi     cleantech          2009               $8 M
# 78    102  ChallengePost           web          2009             $4.6 M
# 79    103        Teambox           web          2009            $6.75 M
# 80    104     Tiny Speck   games_video          2009            $17.2 M
# 81    105         Getyoo        mobile          2009            €1.13 M
#
#                                           geolocation
# 0   {'type': 'Point', 'coordinates': [-73.985506, ...
# 1   {'type': 'Point', 'coordinates': [-111.9035, 3...
# 2   {'type': 'Point', 'coordinates': [-122.323895,...
# 3   {'type': 'Point', 'coordinates': [-122.398599,...
# 4   {'type': 'Point', 'coordinates': [-118.445243,...
# ..                                                ...
# 77  {'type': 'Point', 'coordinates': [-83.16134, 4...
# 78  {'type': 'Point', 'coordinates': [-74.00717, 4...
# 79  {'type': 'Point', 'coordinates': [2.1920231, 4...
# 80  {'type': 'Point', 'coordinates': [-123.109217,...
# 81  {'type': 'Point', 'coordinates': [4.3464721, 5...
#
# [82 rows x 6 columns]
